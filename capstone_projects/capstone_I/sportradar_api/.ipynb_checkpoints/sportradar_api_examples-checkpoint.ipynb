# %% [markdown]
# ### Collection of tests and examples to become familiar with Sportradar API.
#
# Links:
# https://developer.sportradar.com/files/2017_Sportradar_MLB_Statistics_Summary.pdf
# https://developer.sportradar.com/files/2017_Sportradar_MLB_Statistics_Feeds.pdf

# %%
# 90-day Free Trial (start-date = 9/9/2018)
filename = 'api_key'

# using function from "Keeping API Keys Secret.ipynb"
# by https://github.com/dylburger
def get_file_contents(filename):
    """ Given a filename,
        return the contents of that file
    """
    try:
        with open(filename, 'r') as f:
            # It's assumed our file contains a single line,
            # with our API key
            return f.read().strip()
    except FileNotFoundError:
        print("'%s' file not found" % filename)

my_api_key = get_file_contents(filename)

# %% [markdown]
# #### Import packages
#
# * http.client - required for Sportradar API to make HTTP requests
# * json - required to save and load JSON files extracted from Sportradar
# * numpy & pandas - required for data wrangling and cleaning

# %%
import http.client
import time
import json
from pandas.io.json import json_normalize
import numpy as np
import pandas as pd

# %% [markdown]
# #### MLB API Map
# https://developer.sportradar.com/
#
# To best utilize the **MLB API**, several parameters are required to create the API calls. The map below illustrates how to obtain the parameters needed.
#
# The **primary feeds** require only a `date` or `season` to call the endpoints. Those feeds provide `Game`, `Team`, or `Player Id's` which can be used to generate the `game`, `team`, and `player` feeds. All of the other feeds require no variables.
#
# ![image.png](attachment:image.png)
# <center> image source: https://developer.sportradar.com/docs/read/baseball/MLB_v65 </center>

# %% [markdown]
# ## Objective:  Gather Pitching Stats for MLB Starting Pitchers for 2016 - 2018 Seasons
#
# * Get Team IDs using Primary Feed (League Schedules)
# * Using Team IDs, get Player IDs for Pitchers

# %% [markdown]
# #### Collect 2017 MLB League Schedule and Save Results

# %%
# request string to access primary feed (league schedule) combined with api key
#request_2017_sched = "/mlb/trial/v6.5/en/games/2017/REG/schedule.json?api_key=" + my_api_key

# send request to sportradar server using the HTTP request url.
conn = http.client.HTTPSConnection("api.sportradar.us")
conn.request("GET", request_2017_sched)

# get response from server and store HTTPResponse instance
res = conn.getresponse()

# read response body and decode possible UTF-8 signature 
# at the beginning of some files
#json_2017_data = json.loads(res.read().decode("utf-8"))

# %%
# write results to json output file
with open('league_schedule_2017.json', 'w') as outfile:
    json.dump(json_2017_data, outfile)

# %% [markdown]
# #### Collect 2016 MLB League Schedule and Save Results

# %%
# request string to access primary feed (league schedule) combined with api key
#request_2016_sched = "/mlb/trial/v6.5/en/games/2016/REG/schedule.json?api_key=" + my_api_key

# send request to sportradar server using the HTTP request url.
conn = http.client.HTTPSConnection("api.sportradar.us")
conn.request("GET", request_2016_sched)

# get response from server and store HTTPResponse instance
res = conn.getresponse()

# read response body and decode possible UTF-8 signature 
# at the beginning of some files
#json_2016_data = json.loads(res.read().decode("utf-8"))

# %%
# write results to json output file
with open('league_schedule_2016.json', 'w') as outfile:
    json.dump(json_2016_data, outfile)

# %% [markdown]
# #### Open JSON files to collect Team IDs and Game IDs

# %%
# open json file and use list comprehension to extract list of entries
path = 'league_schedule_2016.json'
entries_2016 = [json.loads(line) for line in open(path)]

# %%
# create dataframe from set of entries
df_2016 = pd.DataFrame(entries_2016[0]['games'])

# %%
# show summary of dataframe
df_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2431 entries, 0 to 2430
# Data columns (total 15 columns):
# attendance     2429 non-null float64
# away           2431 non-null object
# away_team      2431 non-null object
# broadcast      2431 non-null object
# coverage       2431 non-null object
# day_night      2431 non-null object
# duration       2429 non-null object
# game_number    2431 non-null int64
# home           2431 non-null object
# home_team      2431 non-null object
# id             2431 non-null object
# rescheduled    26 non-null object
# scheduled      2431 non-null object
# status         2431 non-null object
# venue          2431 non-null object
# dtypes: float64(1), int64(1), object(13)
# memory usage: 285.0+ KB

# %%
# open json file and use list comprehension to extract list of entries
path = 'league_schedule_2017.json'
entries_2017 = [json.loads(line) for line in open(path)]
entries_2017
# Out:
# [{'league': {'alias': 'MLB',
#    'name': 'Major League Baseball',
#    'id': '2fa448bc-fc17-4d3d-be03-e60e080fdc26'},
#   'season': {'id': 'a0d35b04-59fb-465a-8dce-f2c0894e753c',
#    'year': 2017,
#    'type': 'REG'},
#   'games': [{'id': '00404c04-9cbc-423f-ac20-0b6127998052',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'D',
#     'scheduled': '2017-04-06T17:10:00+00:00',
#     'home_team': 'aa34e0ed-f342-4ec6-b774-c79b47b60e2d',
#     'away_team': '833a51a9-0d84-410f-bd77-da08c3e5e26e',
#     'attendance': 16078,
#     'duration': '3:14',
#     'venue': {'name': 'Target Field',
#      'market': 'Minnesota',
#      'capacity': 39021,
#      'surface': 'grass',
#      'address': '353 N 5th Street',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'zip': '55403',
#      'country': 'USA',
#      'id': '302f8dcd-eed6-4b83-8609-81548d51e955'},
#     'home': {'name': 'Twins',
#      'market': 'Minnesota',
#      'abbr': 'MIN',
#      'id': 'aa34e0ed-f342-4ec6-b774-c79b47b60e2d'},
#     'away': {'name': 'Royals',
#      'market': 'Kansas City',
#      'abbr': 'KC',
#      'id': '833a51a9-0d84-410f-bd77-da08c3e5e26e'},
#     'broadcast': {'network': 'FS-N'}},
#    {'id': '005fd5fc-098b-40f9-835b-8518b1063727',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'N',
#     'scheduled': '2017-05-17T00:05:00+00:00',
#     'home_team': '55714da8-fcaf-4574-8443-59bfb511a524',
#     'away_team': 'c874a065-c115-4e7d-b0f0-235584fb0e6f',
#     'attendance': 40653,
#     'duration': '3:07',
#     'venue': {'name': 'Wrigley Field',
#      'market': 'Chicago',
#      'capacity': 41072,
#      'surface': 'grass',
#      'address': '1060 West Addison Street',
#      'city': 'Chicago',
#      'state': 'IL',
#      'zip': '60613',
#      'country': 'USA',
#      'id': '53f8eb0d-a361-4a7a-930b-2f8735ea0698'},
#     'home': {'name': 'Cubs',
#      'market': 'Chicago',
#      'abbr': 'CHC',
#      'id': '55714da8-fcaf-4574-8443-59bfb511a524'},
#     'away': {'name': 'Reds',
#      'market': 'Cincinnati',
#      'abbr': 'CIN',
#      'id': 'c874a065-c115-4e7d-b0f0-235584fb0e6f'},
#     'broadcast': {'network': 'FS-OH'}},
#    {'id': '006a5b3a-3c40-46d0-ad1f-6f880c0e0576',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'N',
#     'scheduled': '2017-09-30T23:10:00+00:00',
#     'home_team': '80715d0d-0d2a-450f-a970-1b9a3b18c7e7',
#     'away_team': '47f490cd-2f58-4ef7-9dfd-2ad6ba6c1ae8',
#     'attendance': 33173,
#     'duration': '3:13',
#     'venue': {'name': 'Progressive Field',
#      'market': 'Cleveland',
#      'capacity': 35051,
#      'surface': 'grass',
#      'address': '2401 Ontario Street',
#      'city': 'Cleveland',
#      'state': 'OH',
#      'zip': '44115',
#      'country': 'USA',
#      'id': '2b0ccd49-4d87-4996-ac4d-27ffc7ee4c16'},
#     'home': {'name': 'Indians',
#      'market': 'Cleveland',
#      'abbr': 'CLE',
#      'id': '80715d0d-0d2a-450f-a970-1b9a3b18c7e7'},
#     'away': {'name': 'White Sox',
#      'market': 'Chicago',
#      'abbr': 'CWS',
#      'id': '47f490cd-2f58-4ef7-9dfd-2ad6ba6c1ae8'},
#     'broadcast': {'network': 'SportsTime Ohio'}},
#    {'id': '006f561d-60f9-4e02-a7f0-9e6df9572d21',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'N',
#     'scheduled': '2017-05-06T00:40:00+00:00',
#     'home_team': '29dd9a87-5bcc-4774-80c3-7f50d985068b',
#     'away_team': '25507be1-6a68-4267-bd82-e097d94b359b',
#     'attendance': 30030,
#     'duration': '2:56',
#     'venue': {'name': 'Coors Field',
#      'market': 'Colorado',
#      'capacity': 50398,
#      'surface': 'grass',
#      'address': '2001 Blake Street',
#      'city': 'Denver',
#      'state': 'CO',
#      'zip': '80205',
#      'country': 'USA',
#      'id': '85dd5cd6-7324-4b52-a1cc-68f816d0cdce'},
#     'home': {'name': 'Rockies',
#      'market': 'Colorado',
#      'abbr': 'COL',
#      'id': '29dd9a87-5bcc-4774-80c3-7f50d985068b'},
#     'away': {'name': 'Diamondbacks',
#      'market': 'Arizona',
#      'abbr': 'ARI',
#      'id': '25507be1-6a68-4267-bd82-e097d94b359b'},
#     'broadcast': {'network': 'ROOT RM'}},
#    {'id': '00727465-5308-44b1-89d5-a57db2b57ab7',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'N',
#     'scheduled': '2017-05-19T23:10:00+00:00',
#     'home_team': 'c874a065-c115-4e7d-b0f0-235584fb0e6f',
#     'away_team': '29dd9a87-5bcc-4774-80c3-7f50d985068b',
#     'attendance': 23184,
#     'duration': '3:38',
#     'venue': {'name': 'Great American Ball Park',
#      'market': 'Cincinnati',
#      'capacity': 42319,
#      'surface': 'grass',
#      'address': '100 Joe Nuxhall Way',
#      'city': 'Cincinnati',
#      'state': 'OH',
#      'zip': '45202',
#      'country': 'USA',
#      'id': 'f102d8fb-de67-4b86-9053-8b55f578d45c'},
#     'home': {'name': 'Reds',
#      'market': 'Cincinnati',
#      'abbr': 'CIN',
#      'id': 'c874a065-c115-4e7d-b0f0-235584fb0e6f'},
#     'away': {'name': 'Rockies',
#      'market': 'Colorado',
#      'abbr': 'COL',
#      'id': '29dd9a87-5bcc-4774-80c3-7f50d985068b'},
#     'broadcast': {'network': 'FS-OH'}},
#    {'id': '00731764-7106-4f6d-9a6e-f95d7c35abdc',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'N',
#     'scheduled': '2017-09-05T23:10:00+00:00',
#     'home_team': '93941372-eb4c-4c40-aced-fe3267174393',
#     'away_team': '1d678440-b4b1-4954-9b39-70afb3ebbcfa',
#     'attendance': 33009,
#     'duration': '6:00',
#     'venue': {'name': 'Fenway Park',
#      'market': 'Boston',
#      'capacity': 37499,
#      'surface': 'grass',
#      'address': '4 Yawkey Way',
#      'city': 'Boston',
#      'state': 'MA',
#      'zip': '02215',
#      'country': 'USA',
#      'id': 'b27b0dc5-c2c5-401d-b8b9-a6a2dbc225e5'},
#     'home': {'name': 'Red Sox',
#      'market': 'Boston',
#      'abbr': 'BOS',
#      'id': '93941372-eb4c-4c40-aced-fe3267174393'},
#     'away': {'name': 'Blue Jays',
#      'market': 'Toronto',
#      'abbr': 'TOR',
#      'id': '1d678440-b4b1-4954-9b39-70afb3ebbcfa'},
#     'broadcast': {'network': 'NESN'}},
#    {'id': '0080a499-fddb-4e8b-9c4c-563362af51eb',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'D',
#     'scheduled': '2017-07-19T16:10:00+00:00',
#     'home_team': '12079497-e414-450a-8bf2-29f91de646bf',
#     'away_team': '55714da8-fcaf-4574-8443-59bfb511a524',
#     'attendance': 40054,
#     'duration': '3:05',
#     'venue': {'name': 'SunTrust Park',
#      'market': 'Atlanta',
#      'capacity': 41500,
#      'surface': 'grass',
#      'address': '755 Battery Avenue',
#      'city': 'Atlanta',
#      'state': 'GA',
#      'zip': '30339',
#      'country': 'USA',
#      'id': '3ca8b577-5844-42ed-81a5-bd5d5cbe350c'},
#     'home': {'name': 'Braves',
#      'market': 'Atlanta',
#      'abbr': 'ATL',
#      'id': '12079497-e414-450a-8bf2-29f91de646bf'},
#     'away': {'name': 'Cubs',
#      'market': 'Chicago',
#      'abbr': 'CHC',
#      'id': '55714da8-fcaf-4574-8443-59bfb511a524'},
#     'broadcast': {'network': 'FS-SE'}},
#    {'id': '00bc5438-2941-45cd-ab2b-4d5aebbcc326',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'N',
#     'scheduled': '2017-06-23T23:10:00+00:00',
#     'home_team': '03556285-bdbb-4576-a06d-42f71f46ddc5',
#     'away_team': '55714da8-fcaf-4574-8443-59bfb511a524',
#     'attendance': 24684,
#     'duration': '2:30',
#     'venue': {'name': 'Marlins Park',
#      'market': 'Miami',
#      'capacity': 36742,
#      'surface': 'grass',
#      'address': '501 Marlins Way',
#      'city': 'Miami',
#      'state': 'FL',
#      'zip': '33125',
#      'country': 'USA',
#      'id': 'd5a66fb3-ff26-4f36-910c-3df5cedb36b3'},
#     'home': {'name': 'Marlins',
#      'market': 'Miami',
#      'abbr': 'MIA',
#      'id': '03556285-bdbb-4576-a06d-42f71f46ddc5'},
#     'away': {'name': 'Cubs',
#      'market': 'Chicago',
#      'abbr': 'CHC',
#      'id': '55714da8-fcaf-4574-8443-59bfb511a524'},
#     'broadcast': {'network': 'FS-FL'}},
#    {'id': '00c14bf0-58ce-49a5-9a92-d11e5b4e1040',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'D',
#     'scheduled': '2017-07-30T20:40:00+00:00',
#     'home_team': 'd52d5339-cbdd-43f3-9dfa-a42fd588b9a3',
#     'away_team': '481dfe7e-5dab-46ab-a49f-9dcc2b6e2cfd',
#     'attendance': 30267,
#     'duration': '2:49',
#     'venue': {'name': 'PETCO Park',
#      'market': 'San Diego',
#      'capacity': 42302,
#      'surface': 'grass',
#      'address': '100 Park Blvd.',
#      'city': 'San Diego',
#      'state': 'CA',
#      'zip': '92101',
#      'country': 'USA',
#      'id': '0ab45d79-5475-4308-9f94-74b0c185ee6f'},
#     'home': {'name': 'Padres',
#      'market': 'San Diego',
#      'abbr': 'SD',
#      'id': 'd52d5339-cbdd-43f3-9dfa-a42fd588b9a3'},
#     'away': {'name': 'Pirates',
#      'market': 'Pittsburgh',
#      'abbr': 'PIT',
#      'id': '481dfe7e-5dab-46ab-a49f-9dcc2b6e2cfd'},
#     'broadcast': {'network': 'FS-SD'}},
#    {'id': '00cec290-dae6-43b5-bbd1-2044cda8135c',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'N',
#     'scheduled': '2017-06-28T23:10:00+00:00',
#     'home_team': '575c19b7-4052-41c2-9f0a-1c5813d02f99',
#     'away_team': '833a51a9-0d84-410f-bd77-da08c3e5e26e',
#     'attendance': 29614,
#     'duration': '2:46',
#     'venue': {'name': 'Comerica Park',
#      'market': 'Detroit',
#      'capacity': 41681,
#      'surface': 'grass',
#      'address': '2100 Woodward Avenue',
#      'city': 'Detroit',
#      'state': 'MI',
#      'zip': '48226',
#      'country': 'USA',
#      'id': 'ef9a5eef-06c6-4963-ac70-7fd02c8c8d42'},
#     'home': {'name': 'Tigers',
#      'market': 'Detroit',
#      'abbr': 'DET',
#      'id': '575c19b7-4052-41c2-9f0a-1c5813d02f99'},
#     'away': {'name': 'Royals',
#      'market': 'Kansas City',
#      'abbr': 'KC',
#      'id': '833a51a9-0d84-410f-bd77-da08c3e5e26e'},
#     'broadcast': {'network': 'FS-D'}},
#    {'id': '0112c09b-d036-4615-8226-9356c32c05a8',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'N',
#     'scheduled': '2017-04-27T02:07:00+00:00',
#     'home_team': '4f735188-37c8-473d-ae32-1f7e34ccf892',
#     'away_team': '27a59d3b-ff7c-48ea-b016-4798f560f5e1',
#     'attendance': 30248,
#     'duration': '3:30',
#     'venue': {'name': 'Angel Stadium of Anaheim',
#      'market': 'Los Angeles',
#      'capacity': 43250,
#      'surface': 'grass',
#      'address': '2000 Gene Autry Way',
#      'city': 'Anaheim',
#      'state': 'CA',
#      'zip': '92806',
#      'country': 'USA',
#      'id': '60732da9-ad03-4feb-9a36-aee3e98c7a2b'},
#     'home': {'name': 'Angels',
#      'market': 'Los Angeles',
#      'abbr': 'LAA',
#      'id': '4f735188-37c8-473d-ae32-1f7e34ccf892'},
#     'away': {'name': 'Athletics',
#      'market': 'Oakland',
#      'abbr': 'OAK',
#      'id': '27a59d3b-ff7c-48ea-b016-4798f560f5e1'},
#     'broadcast': {'network': 'FS-W'}},
#    {'id': '0169c147-d922-4837-9c9d-61cf496bae34',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'D',
#     'scheduled': '2017-09-14T17:35:00+00:00',
#     'home_team': '93941372-eb4c-4c40-aced-fe3267174393',
#     'away_team': '27a59d3b-ff7c-48ea-b016-4798f560f5e1',
#     'attendance': 35470,
#     'duration': '3:19',
#     'venue': {'name': 'Fenway Park',
#      'market': 'Boston',
#      'capacity': 37499,
#      'surface': 'grass',
#      'address': '4 Yawkey Way',
#      'city': 'Boston',
#      'state': 'MA',
#      'zip': '02215',
#      'country': 'USA',
#      'id': 'b27b0dc5-c2c5-401d-b8b9-a6a2dbc225e5'},
#     'home': {'name': 'Red Sox',
#      'market': 'Boston',
#      'abbr': 'BOS',
#      'id': '93941372-eb4c-4c40-aced-fe3267174393'},
#     'away': {'name': 'Athletics',
#      'market': 'Oakland',
#      'abbr': 'OAK',
#      'id': '27a59d3b-ff7c-48ea-b016-4798f560f5e1'},
#     'broadcast': {'network': 'NESN'}},
#    {'id': '01977a92-a967-473a-8f93-89b82cf04fe6',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'N',
#     'scheduled': '2017-08-13T01:10:00+00:00',
#     'home_team': 'ef64da7f-cfaf-4300-87b0-9313386b977c',
#     'away_team': 'd52d5339-cbdd-43f3-9dfa-a42fd588b9a3',
#     'attendance': 53230,
#     'duration': '3:36',
#     'venue': {'name': 'Dodger Stadium',
#      'market': 'Los Angeles',
#      'capacity': 56000,
#      'surface': 'grass',
#      'address': '1000 Vin Scully Avenue',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'zip': '90012',
#      'country': 'USA',
#      'id': '66a19c3d-24fe-477d-bee7-c6ef1b98352f'},
#     'home': {'name': 'Dodgers',
#      'market': 'Los Angeles',
#      'abbr': 'LAD',
#      'id': 'ef64da7f-cfaf-4300-87b0-9313386b977c'},
#     'away': {'name': 'Padres',
#      'market': 'San Diego',
#      'abbr': 'SD',
#      'id': 'd52d5339-cbdd-43f3-9dfa-a42fd588b9a3'},
#     'broadcast': {'network': 'FS-SD'}},
#    {'id': '01b93490-a1fb-4673-8c78-f24929c61c03',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'N',
#     'scheduled': '2017-07-15T23:05:00+00:00',
#     'home_team': '75729d34-bca7-4a0f-b3df-6f26c6ad3719',
#     'away_team': '55714da8-fcaf-4574-8443-59bfb511a524',
#     'attendance': 40258,
#     'duration': '3:02',
#     'venue': {'name': 'Oriole Park at Camden Yards',
#      'market': 'Baltimore',
#      'capacity': 45971,
#      'surface': 'grass',
#      'address': '333 West Camden Street',
#      'city': 'Baltimore',
#      'state': 'MD',
#      'zip': '21201',
#      'country': 'USA',
#      'id': '434aa63c-1049-4a54-a6bc-3790c7772ee1'},
#     'home': {'name': 'Orioles',
#      'market': 'Baltimore',
#      'abbr': 'BAL',
#      'id': '75729d34-bca7-4a0f-b3df-6f26c6ad3719'},
#     'away': {'name': 'Cubs',
#      'market': 'Chicago',
#      'abbr': 'CHC',
#      'id': '55714da8-fcaf-4574-8443-59bfb511a524'},
#     'broadcast': {'network': 'MASN'}},
#    {'id': '01e02126-eae1-4ae2-8d0a-def996c38a92',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'D',
#     'scheduled': '2017-06-22T19:35:00+00:00',
#     'home_team': '27a59d3b-ff7c-48ea-b016-4798f560f5e1',
#     'away_team': 'eb21dadd-8f10-4095-8bf3-dfb3b779f107',
#     'attendance': 18747,
#     'duration': '3:24',
#     'venue': {'name': 'Oakland-Alameda County Coliseum',
#      'market': 'Oakland',
#      'capacity': 37090,
#      'surface': 'grass',
#      'address': '7000 Coliseum Way',
#      'city': 'Oakland',
#      'state': 'CA',
#      'zip': '94621',
#      'country': 'USA',
#      'id': '48cbd35a-d932-4a75-beab-067bfbacfc26'},
#     'home': {'name': 'Athletics',
#      'market': 'Oakland',
#      'abbr': 'OAK',
#      'id': '27a59d3b-ff7c-48ea-b016-4798f560f5e1'},
#     'away': {'name': 'Astros',
#      'market': 'Houston',
#      'abbr': 'HOU',
#      'id': 'eb21dadd-8f10-4095-8bf3-dfb3b779f107'},
#     'broadcast': {'network': 'MLBN'}},
#    {'id': '0211515e-a902-420a-b19f-92b916dcccbb',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'N',
#     'scheduled': '2017-04-23T00:10:00+00:00',
#     'home_team': '25507be1-6a68-4267-bd82-e097d94b359b',
#     'away_team': 'ef64da7f-cfaf-4300-87b0-9313386b977c',
#     'attendance': 36294,
#     'duration': '3:20',
#     'venue': {'name': 'Chase Field',
#      'market': 'Arizona',
#      'capacity': 48633,
#      'surface': 'grass',
#      'address': '401 East Jefferson Street',
#      'city': 'Phoenix',
#      'state': 'AZ',
#      'zip': '85004',
#      'country': 'USA',
#      'id': 'bf05de0d-7ced-4a19-8e17-2bbd985f8a92'},
#     'home': {'name': 'Diamondbacks',
#      'market': 'Arizona',
#      'abbr': 'ARI',
#      'id': '25507be1-6a68-4267-bd82-e097d94b359b'},
#     'away': {'name': 'Dodgers',
#      'market': 'Los Angeles',
#      'abbr': 'LAD',
#      'id': 'ef64da7f-cfaf-4300-87b0-9313386b977c'},
#     'broadcast': {'network': 'FS-AZ'}},
#    {'id': '0219cfaf-ab5a-4033-92bd-0326881a9e42',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'N',
#     'scheduled': '2017-09-16T23:10:00+00:00',
#     'home_team': 'aa34e0ed-f342-4ec6-b774-c79b47b60e2d',
#     'away_team': '1d678440-b4b1-4954-9b39-70afb3ebbcfa',
#     'attendance': 29917,
#     'duration': '2:50',
#     'venue': {'name': 'Target Field',
#      'market': 'Minnesota',
#      'capacity': 39021,
#      'surface': 'grass',
#      'address': '353 N 5th Street',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'zip': '55403',
#      'country': 'USA',
#      'id': '302f8dcd-eed6-4b83-8609-81548d51e955'},
#     'home': {'name': 'Twins',
#      'market': 'Minnesota',
#      'abbr': 'MIN',
#      'id': 'aa34e0ed-f342-4ec6-b774-c79b47b60e2d'},
#     'away': {'name': 'Blue Jays',
#      'market': 'Toronto',
#      'abbr': 'TOR',
#      'id': '1d678440-b4b1-4954-9b39-70afb3ebbcfa'},
#     'broadcast': {'network': 'FS-N'}},
#    {'id': '0222bd4f-77b6-4982-ab51-7d890a3f481a',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'N',
#     'scheduled': '2017-09-12T23:07:00+00:00',
#     'home_team': '1d678440-b4b1-4954-9b39-70afb3ebbcfa',
#     'away_team': '75729d34-bca7-4a0f-b3df-6f26c6ad3719',
#     'attendance': 29055,
#     'duration': '2:40',
#     'venue': {'name': 'Rogers Centre',
#      'market': 'Toronto',
#      'capacity': 49282,
#      'surface': 'turf',
#      'address': 'One Blue Jays Way',
#      'city': 'Toronto',
#      'state': 'ON',
#      'zip': 'M5V1J3',
#      'country': 'CANADA',
#      'id': '84d72338-2173-4a90-9d25-99adc6c86f4b'},
#     'home': {'name': 'Blue Jays',
#      'market': 'Toronto',
#      'abbr': 'TOR',
#      'id': '1d678440-b4b1-4954-9b39-70afb3ebbcfa'},
#     'away': {'name': 'Orioles',
#      'market': 'Baltimore',
#      'abbr': 'BAL',
#      'id': '75729d34-bca7-4a0f-b3df-6f26c6ad3719'},
#     'broadcast': {'network': 'SNET'}},
#    {'id': '02324c19-f609-4bd1-8ddc-34eaea8af81b',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'N',
#     'scheduled': '2017-09-20T02:15:00+00:00',
#     'home_team': 'a7723160-10b7-4277-a309-d8dd95a8ae65',
#     'away_team': '29dd9a87-5bcc-4774-80c3-7f50d985068b',
#     'attendance': 40686,
#     'duration': '2:57',
#     'venue': {'name': 'AT&T Park',
#      'market': 'San Francisco',
#      'capacity': 41915,
#      'surface': 'grass',
#      'address': '24 Willie Mays Plaza',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'zip': '94107',
#      'country': 'USA',
#      'id': '2d7542f5-7b80-49f7-9b24-c53ffdc75af6'},
#     'home': {'name': 'Giants',
#      'market': 'San Francisco',
#      'abbr': 'SF',
#      'id': 'a7723160-10b7-4277-a309-d8dd95a8ae65'},
#     'away': {'name': 'Rockies',
#      'market': 'Colorado',
#      'abbr': 'COL',
#      'id': '29dd9a87-5bcc-4774-80c3-7f50d985068b'},
#     'broadcast': {'network': 'CSN-BA'}},
#    {'id': '0242261d-78be-4a36-ab91-eb448276a23c',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'N',
#     'scheduled': '2017-06-23T23:10:00+00:00',
#     'home_team': '80715d0d-0d2a-450f-a970-1b9a3b18c7e7',
#     'away_team': 'aa34e0ed-f342-4ec6-b774-c79b47b60e2d',
#     'attendance': 31725,
#     'duration': '3:11',
#     'venue': {'name': 'Progressive Field',
#      'market': 'Cleveland',
#      'capacity': 35051,
#      'surface': 'grass',
#      'address': '2401 Ontario Street',
#      'city': 'Cleveland',
#      'state': 'OH',
#      'zip': '44115',
#      'country': 'USA',
#      'id': '2b0ccd49-4d87-4996-ac4d-27ffc7ee4c16'},
#     'home': {'name': 'Indians',
#      'market': 'Cleveland',
#      'abbr': 'CLE',
#      'id': '80715d0d-0d2a-450f-a970-1b9a3b18c7e7'},
#     'away': {'name': 'Twins',
#      'market': 'Minnesota',
#      'abbr': 'MIN',
#      'id': 'aa34e0ed-f342-4ec6-b774-c79b47b60e2d'},
#     'broadcast': {'network': 'SportsTime Ohio'}},
#    {'id': '02661ef0-945c-43a2-90d5-55df86d7d349',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'D',
#     'scheduled': '2017-05-04T19:40:00+00:00',
#     'home_team': 'd52d5339-cbdd-43f3-9dfa-a42fd588b9a3',
#     'away_team': '29dd9a87-5bcc-4774-80c3-7f50d985068b',
#     'attendance': 16356,
#     'duration': '4:13',
#     'venue': {'name': 'PETCO Park',
#      'market': 'San Diego',
#      'capacity': 42302,
#      'surface': 'grass',
#      'address': '100 Park Blvd.',
#      'city': 'San Diego',
#      'state': 'CA',
#      'zip': '92101',
#      'country': 'USA',
#      'id': '0ab45d79-5475-4308-9f94-74b0c185ee6f'},
#     'home': {'name': 'Padres',
#      'market': 'San Diego',
#      'abbr': 'SD',
#      'id': 'd52d5339-cbdd-43f3-9dfa-a42fd588b9a3'},
#     'away': {'name': 'Rockies',
#      'market': 'Colorado',
#      'abbr': 'COL',
#      'id': '29dd9a87-5bcc-4774-80c3-7f50d985068b'},
#     'broadcast': {'network': 'FS-SD'}},
#    {'id': '02668a25-6f97-4808-9949-262527449840',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'D',
#     'scheduled': '2017-07-23T17:35:00+00:00',
#     'home_team': '75729d34-bca7-4a0f-b3df-6f26c6ad3719',
#     'away_team': 'eb21dadd-8f10-4095-8bf3-dfb3b779f107',
#     'attendance': 21533,
#     'duration': '3:24',
#     'venue': {'name': 'Oriole Park at Camden Yards',
#      'market': 'Baltimore',
#      'capacity': 45971,
#      'surface': 'grass',
#      'address': '333 West Camden Street',
#      'city': 'Baltimore',
#      'state': 'MD',
#      'zip': '21201',
#      'country': 'USA',
#      'id': '434aa63c-1049-4a54-a6bc-3790c7772ee1'},
#     'home': {'name': 'Orioles',
#      'market': 'Baltimore',
#      'abbr': 'BAL',
#      'id': '75729d34-bca7-4a0f-b3df-6f26c6ad3719'},
#     'away': {'name': 'Astros',
#      'market': 'Houston',
#      'abbr': 'HOU',
#      'id': 'eb21dadd-8f10-4095-8bf3-dfb3b779f107'},
#     'broadcast': {'network': 'MASN'}},
#    {'id': '02b310a6-82de-4e9c-90a0-70c08dccb973',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'N',
#     'scheduled': '2017-06-28T02:10:00+00:00',
#     'home_team': '43a39081-52b4-4f93-ad29-da7f329ea960',
#     'away_team': '2142e1ba-3b40-445c-b8bb-f1f8b1054220',
#     'attendance': 22648,
#     'duration': '3:02',
#     'venue': {'name': 'Safeco Field',
#      'market': 'Seattle',
#      'capacity': 47476,
#      'surface': 'grass',
#      'address': '1516 First Avenue South',
#      'city': 'Seattle',
#      'state': 'WA',
#      'zip': '98134',
#      'country': 'USA',
#      'id': 'f1c03dac-3c0f-437c-a325-8d5702cd321a'},
#     'home': {'name': 'Mariners',
#      'market': 'Seattle',
#      'abbr': 'SEA',
#      'id': '43a39081-52b4-4f93-ad29-da7f329ea960'},
#     'away': {'name': 'Phillies',
#      'market': 'Philadelphia',
#      'abbr': 'PHI',
#      'id': '2142e1ba-3b40-445c-b8bb-f1f8b1054220'},
#     'broadcast': {'network': 'ROOT NW'}},
#    {'id': '02e44b26-7505-4bf6-9e4e-54db49146159',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'N',
#     'scheduled': '2017-06-09T23:10:00+00:00',
#     'home_team': 'bdc11650-6f74-49c4-875e-778aeb7632d9',
#     'away_team': '27a59d3b-ff7c-48ea-b016-4798f560f5e1',
#     'attendance': 13153,
#     'duration': '3:16',
#     'venue': {'name': 'Tropicana Field',
#      'market': 'Tampa Bay',
#      'capacity': 31042,
#      'surface': 'turf',
#      'address': 'One Tropicana Drive',
#      'city': 'St. Petersburg',
#      'state': 'FL',
#      'zip': '33705',
#      'country': 'USA',
#      'id': '3aaaf4af-0f8c-49c1-8bf1-1780bb5a5f5c'},
#     'home': {'name': 'Rays',
#      'market': 'Tampa Bay',
#      'abbr': 'TB',
#      'id': 'bdc11650-6f74-49c4-875e-778aeb7632d9'},
#     'away': {'name': 'Athletics',
#      'market': 'Oakland',
#      'abbr': 'OAK',
#      'id': '27a59d3b-ff7c-48ea-b016-4798f560f5e1'},
#     'broadcast': {'network': 'SUN'}},
#    {'id': '030843af-2b8c-4abb-9578-601cb0e84047',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'N',
#     'scheduled': '2017-09-30T02:07:00+00:00',
#     'home_team': '4f735188-37c8-473d-ae32-1f7e34ccf892',
#     'away_team': '43a39081-52b4-4f93-ad29-da7f329ea960',
#     'attendance': 35106,
#     'duration': '3:01',
#     'venue': {'name': 'Angel Stadium of Anaheim',
#      'market': 'Los Angeles',
#      'capacity': 43250,
#      'surface': 'grass',
#      'address': '2000 Gene Autry Way',
#      'city': 'Anaheim',
#      'state': 'CA',
#      'zip': '92806',
#      'country': 'USA',
#      'id': '60732da9-ad03-4feb-9a36-aee3e98c7a2b'},
#     'home': {'name': 'Angels',
#      'market': 'Los Angeles',
#      'abbr': 'LAA',
#      'id': '4f735188-37c8-473d-ae32-1f7e34ccf892'},
#     'away': {'name': 'Mariners',
#      'market': 'Seattle',
#      'abbr': 'SEA',
#      'id': '43a39081-52b4-4f93-ad29-da7f329ea960'},
#     'broadcast': {'network': 'FS-W'}},
#    {'id': '034d17c1-1450-481c-a011-b3c60fb7aab6',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'D',
#     'scheduled': '2017-06-04T17:10:00+00:00',
#     'home_team': 'c874a065-c115-4e7d-b0f0-235584fb0e6f',
#     'away_team': '12079497-e414-450a-8bf2-29f91de646bf',
#     'attendance': 26227,
#     'duration': '3:23',
#     'venue': {'name': 'Great American Ball Park',
#      'market': 'Cincinnati',
#      'capacity': 42319,
#      'surface': 'grass',
#      'address': '100 Joe Nuxhall Way',
#      'city': 'Cincinnati',
#      'state': 'OH',
#      'zip': '45202',
#      'country': 'USA',
#      'id': 'f102d8fb-de67-4b86-9053-8b55f578d45c'},
#     'home': {'name': 'Reds',
#      'market': 'Cincinnati',
#      'abbr': 'CIN',
#      'id': 'c874a065-c115-4e7d-b0f0-235584fb0e6f'},
#     'away': {'name': 'Braves',
#      'market': 'Atlanta',
#      'abbr': 'ATL',
#      'id': '12079497-e414-450a-8bf2-29f91de646bf'},
#     'broadcast': {'network': 'FS-OH'}},
#    {'id': '036673b5-c485-42e6-903a-34e686b02ac5',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'N',
#     'scheduled': '2017-08-08T23:05:00+00:00',
#     'home_team': 'd89bed32-3aee-4407-99e3-4103641b999a',
#     'away_team': '03556285-bdbb-4576-a06d-42f71f46ddc5',
#     'attendance': 25406,
#     'duration': '3:07',
#     'venue': {'name': 'Nationals Park',
#      'market': 'Washington',
#      'capacity': 41418,
#      'surface': 'grass',
#      'address': '1500 South Capitol Street SE',
#      'city': 'Washington',
#      'state': 'DC',
#      'zip': '20003',
#      'country': 'USA',
#      'id': 'bb062fb1-e268-412e-b3d2-2ddb6acc1822'},
#     'home': {'name': 'Nationals',
#      'market': 'Washington',
#      'abbr': 'WSH',
#      'id': 'd89bed32-3aee-4407-99e3-4103641b999a'},
#     'away': {'name': 'Marlins',
#      'market': 'Miami',
#      'abbr': 'MIA',
#      'id': '03556285-bdbb-4576-a06d-42f71f46ddc5'},
#     'broadcast': {'network': 'FS-FL'}},
#    {'id': '03ab374a-b252-4536-a5b6-d89aa8d9d5e6',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'D',
#     'scheduled': '2017-08-22T20:05:00+00:00',
#     'home_team': '2142e1ba-3b40-445c-b8bb-f1f8b1054220',
#     'away_team': '03556285-bdbb-4576-a06d-42f71f46ddc5',
#     'duration': '3:06',
#     'venue': {'name': 'Citizens Bank Park',
#      'market': 'Philadelphia',
#      'capacity': 43651,
#      'surface': 'grass',
#      'address': 'One Citizens Bank Way',
#      'city': 'Philadelphia',
#      'state': 'PA',
#      'zip': '19148',
#      'country': 'USA',
#      'id': 'b4186004-b6d0-42e7-8dc1-82ef0d946ecc'},
#     'home': {'name': 'Phillies',
#      'market': 'Philadelphia',
#      'abbr': 'PHI',
#      'id': '2142e1ba-3b40-445c-b8bb-f1f8b1054220'},
#     'away': {'name': 'Marlins',
#      'market': 'Miami',
#      'abbr': 'MIA',
#      'id': '03556285-bdbb-4576-a06d-42f71f46ddc5'},
#     'broadcast': {'network': 'FS-FL'}},
#    {'id': '03c187d2-366f-453d-b32b-d537a4935679',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'N',
#     'scheduled': '2017-05-27T00:10:00+00:00',
#     'home_team': 'eb21dadd-8f10-4095-8bf3-dfb3b779f107',
#     'away_team': '75729d34-bca7-4a0f-b3df-6f26c6ad3719',
#     'attendance': 31380,
#     'duration': '2:31',
#     'venue': {'name': 'Minute Maid Park',
#      'market': 'Houston',
#      'capacity': 42060,
#      'surface': 'grass',
#      'address': '501 Crawford Street',
#      'city': 'Houston',
#      'state': 'TX',
#      'zip': '77002',
#      'country': 'USA',
#      'id': 'f0600f04-1386-4c61-a412-804960c46cb1'},
#     'home': {'name': 'Astros',
#      'market': 'Houston',
#      'abbr': 'HOU',
#      'id': 'eb21dadd-8f10-4095-8bf3-dfb3b779f107'},
#     'away': {'name': 'Orioles',
#      'market': 'Baltimore',
#      'abbr': 'BAL',
#      'id': '75729d34-bca7-4a0f-b3df-6f26c6ad3719'},
#     'broadcast': {'network': 'ROOT SW'}},
#    {'id': '03c58c70-eb47-4ed0-8f07-dde6cea139e6',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'D',
#     'scheduled': '2017-05-27T20:10:00+00:00',
#     'home_team': 'dcfd5266-00ce-442c-bc09-264cd20cf455',
#     'away_team': '25507be1-6a68-4267-bd82-e097d94b359b',
#     'attendance': 29746,
#     'duration': '2:52',
#     'venue': {'name': 'Miller Park',
#      'market': 'Milwaukee',
#      'capacity': 41900,
#      'surface': 'grass',
#      'address': 'One Brewers Way',
#      'city': 'Milwaukee',
#      'state': 'WI',
#      'zip': '53214',
#      'country': 'USA',
#      'id': '3d13c8a7-283f-482b-ade1-441e25b6465d'},
#     'home': {'name': 'Brewers',
#      'market': 'Milwaukee',
#      'abbr': 'MIL',
#      'id': 'dcfd5266-00ce-442c-bc09-264cd20cf455'},
#     'away': {'name': 'Diamondbacks',
#      'market': 'Arizona',
#      'abbr': 'ARI',
#      'id': '25507be1-6a68-4267-bd82-e097d94b359b'},
#     'broadcast': {'network': 'FS-WI'}},
#    {'id': '03e5ccf5-7a0a-499a-b892-6d00f4f3befa',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'N',
#     'scheduled': '2017-08-21T23:35:00+00:00',
#     'home_team': '12079497-e414-450a-8bf2-29f91de646bf',
#     'away_team': '43a39081-52b4-4f93-ad29-da7f329ea960',
#     'attendance': 21284,
#     'duration': '2:59',
#     'venue': {'name': 'SunTrust Park',
#      'market': 'Atlanta',
#      'capacity': 41500,
#      'surface': 'grass',
#      'address': '755 Battery Avenue',
#      'city': 'Atlanta',
#      'state': 'GA',
#      'zip': '30339',
#      'country': 'USA',
#      'id': '3ca8b577-5844-42ed-81a5-bd5d5cbe350c'},
#     'home': {'name': 'Braves',
#      'market': 'Atlanta',
#      'abbr': 'ATL',
#      'id': '12079497-e414-450a-8bf2-29f91de646bf'},
#     'away': {'name': 'Mariners',
#      'market': 'Seattle',
#      'abbr': 'SEA',
#      'id': '43a39081-52b4-4f93-ad29-da7f329ea960'},
#     'broadcast': {'network': 'FS-SE'}},
#    {'id': '041990a6-5ac0-42f5-ae2a-a71855650597',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'N',
#     'scheduled': '2017-07-06T00:40:00+00:00',
#     'home_team': '29dd9a87-5bcc-4774-80c3-7f50d985068b',
#     'away_team': 'c874a065-c115-4e7d-b0f0-235584fb0e6f',
#     'attendance': 32188,
#     'duration': '3:24',
#     'venue': {'name': 'Coors Field',
#      'market': 'Colorado',
#      'capacity': 50398,
#      'surface': 'grass',
#      'address': '2001 Blake Street',
#      'city': 'Denver',
#      'state': 'CO',
#      'zip': '80205',
#      'country': 'USA',
#      'id': '85dd5cd6-7324-4b52-a1cc-68f816d0cdce'},
#     'home': {'name': 'Rockies',
#      'market': 'Colorado',
#      'abbr': 'COL',
#      'id': '29dd9a87-5bcc-4774-80c3-7f50d985068b'},
#     'away': {'name': 'Reds',
#      'market': 'Cincinnati',
#      'abbr': 'CIN',
#      'id': 'c874a065-c115-4e7d-b0f0-235584fb0e6f'},
#     'broadcast': {'network': 'FS-OH'}},
#    {'id': '041d56e8-a4ce-4051-91d9-e285767b7c4a',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'N',
#     'scheduled': '2017-08-11T01:40:00+00:00',
#     'home_team': '25507be1-6a68-4267-bd82-e097d94b359b',
#     'away_team': 'ef64da7f-cfaf-4300-87b0-9313386b977c',
#     'attendance': 31396,
#     'duration': '3:37',
#     'venue': {'name': 'Chase Field',
#      'market': 'Arizona',
#      'capacity': 48633,
#      'surface': 'grass',
#      'address': '401 East Jefferson Street',
#      'city': 'Phoenix',
#      'state': 'AZ',
#      'zip': '85004',
#      'country': 'USA',
#      'id': 'bf05de0d-7ced-4a19-8e17-2bbd985f8a92'},
#     'home': {'name': 'Diamondbacks',
#      'market': 'Arizona',
#      'abbr': 'ARI',
#      'id': '25507be1-6a68-4267-bd82-e097d94b359b'},
#     'away': {'name': 'Dodgers',
#      'market': 'Los Angeles',
#      'abbr': 'LAD',
#      'id': 'ef64da7f-cfaf-4300-87b0-9313386b977c'},
#     'broadcast': {'network': 'FS-AZ'}},
#    {'id': '041ec3c3-6b99-435a-9286-e6eebab08038',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'N',
#     'scheduled': '2017-09-19T23:10:00+00:00',
#     'home_team': '03556285-bdbb-4576-a06d-42f71f46ddc5',
#     'away_team': 'f246a5e5-afdb-479c-9aaa-c68beeda7af6',
#     'attendance': 16405,
#     'duration': '3:22',
#     'venue': {'name': 'Marlins Park',
#      'market': 'Miami',
#      'capacity': 36742,
#      'surface': 'grass',
#      'address': '501 Marlins Way',
#      'city': 'Miami',
#      'state': 'FL',
#      'zip': '33125',
#      'country': 'USA',
#      'id': 'd5a66fb3-ff26-4f36-910c-3df5cedb36b3'},
#     'home': {'name': 'Marlins',
#      'market': 'Miami',
#      'abbr': 'MIA',
#      'id': '03556285-bdbb-4576-a06d-42f71f46ddc5'},
#     'away': {'name': 'Mets',
#      'market': 'New York',
#      'abbr': 'NYM',
#      'id': 'f246a5e5-afdb-479c-9aaa-c68beeda7af6'},
#     'broadcast': {'network': 'FS-FL'}},
#    {'id': '044492cf-f268-4a37-86a8-107a370fb4b8',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'N',
#     'scheduled': '2017-05-22T23:05:00+00:00',
#     'home_team': '2142e1ba-3b40-445c-b8bb-f1f8b1054220',
#     'away_team': '29dd9a87-5bcc-4774-80c3-7f50d985068b',
#     'attendance': 21251,
#     'duration': '3:03',
#     'venue': {'name': 'Citizens Bank Park',
#      'market': 'Philadelphia',
#      'capacity': 43651,
#      'surface': 'grass',
#      'address': 'One Citizens Bank Way',
#      'city': 'Philadelphia',
#      'state': 'PA',
#      'zip': '19148',
#      'country': 'USA',
#      'id': 'b4186004-b6d0-42e7-8dc1-82ef0d946ecc'},
#     'home': {'name': 'Phillies',
#      'market': 'Philadelphia',
#      'abbr': 'PHI',
#      'id': '2142e1ba-3b40-445c-b8bb-f1f8b1054220'},
#     'away': {'name': 'Rockies',
#      'market': 'Colorado',
#      'abbr': 'COL',
#      'id': '29dd9a87-5bcc-4774-80c3-7f50d985068b'},
#     'broadcast': {'network': 'ROOT RM'}},
#    {'id': '044acd03-7d87-4e36-b3a4-1e5a8cbe2bb5',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'N',
#     'scheduled': '2017-07-09T02:10:00+00:00',
#     'home_team': '43a39081-52b4-4f93-ad29-da7f329ea960',
#     'away_team': '27a59d3b-ff7c-48ea-b016-4798f560f5e1',
#     'attendance': 28694,
#     'duration': '2:54',
#     'venue': {'name': 'Safeco Field',
#      'market': 'Seattle',
#      'capacity': 47476,
#      'surface': 'grass',
#      'address': '1516 First Avenue South',
#      'city': 'Seattle',
#      'state': 'WA',
#      'zip': '98134',
#      'country': 'USA',
#      'id': 'f1c03dac-3c0f-437c-a325-8d5702cd321a'},
#     'home': {'name': 'Mariners',
#      'market': 'Seattle',
#      'abbr': 'SEA',
#      'id': '43a39081-52b4-4f93-ad29-da7f329ea960'},
#     'away': {'name': 'Athletics',
#      'market': 'Oakland',
#      'abbr': 'OAK',
#      'id': '27a59d3b-ff7c-48ea-b016-4798f560f5e1'},
#     'broadcast': {'network': 'ROOT NW'}},
#    {'id': '04960d93-27d8-4351-b797-4ef09e7997b3',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'N',
#     'scheduled': '2017-05-14T00:10:00+00:00',
#     'home_team': '25507be1-6a68-4267-bd82-e097d94b359b',
#     'away_team': '481dfe7e-5dab-46ab-a49f-9dcc2b6e2cfd',
#     'attendance': 31673,
#     'duration': '3:00',
#     'venue': {'name': 'Chase Field',
#      'market': 'Arizona',
#      'capacity': 48633,
#      'surface': 'grass',
#      'address': '401 East Jefferson Street',
#      'city': 'Phoenix',
#      'state': 'AZ',
#      'zip': '85004',
#      'country': 'USA',
#      'id': 'bf05de0d-7ced-4a19-8e17-2bbd985f8a92'},
#     'home': {'name': 'Diamondbacks',
#      'market': 'Arizona',
#      'abbr': 'ARI',
#      'id': '25507be1-6a68-4267-bd82-e097d94b359b'},
#     'away': {'name': 'Pirates',
#      'market': 'Pittsburgh',
#      'abbr': 'PIT',
#      'id': '481dfe7e-5dab-46ab-a49f-9dcc2b6e2cfd'},
#     'broadcast': {'network': 'FS-AZ'}},
#    {'id': '04e1944e-9f77-4af7-843a-2d07a08ca1f7',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'N',
#     'scheduled': '2017-09-30T23:10:00+00:00',
#     'home_team': 'aa34e0ed-f342-4ec6-b774-c79b47b60e2d',
#     'away_team': '575c19b7-4052-41c2-9f0a-1c5813d02f99',
#     'attendance': 35515,
#     'duration': '2:59',
#     'venue': {'name': 'Target Field',
#      'market': 'Minnesota',
#      'capacity': 39021,
#      'surface': 'grass',
#      'address': '353 N 5th Street',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'zip': '55403',
#      'country': 'USA',
#      'id': '302f8dcd-eed6-4b83-8609-81548d51e955'},
#     'home': {'name': 'Twins',
#      'market': 'Minnesota',
#      'abbr': 'MIN',
#      'id': 'aa34e0ed-f342-4ec6-b774-c79b47b60e2d'},
#     'away': {'name': 'Tigers',
#      'market': 'Detroit',
#      'abbr': 'DET',
#      'id': '575c19b7-4052-41c2-9f0a-1c5813d02f99'},
#     'broadcast': {'network': 'FS-N'}},
#    {'id': '04f09d7e-1a22-4796-b2e6-c2ed8b653444',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'N',
#     'scheduled': '2017-05-20T02:10:00+00:00',
#     'home_team': 'd52d5339-cbdd-43f3-9dfa-a42fd588b9a3',
#     'away_team': '25507be1-6a68-4267-bd82-e097d94b359b',
#     'attendance': 22187,
#     'duration': '3:12',
#     'venue': {'name': 'PETCO Park',
#      'market': 'San Diego',
#      'capacity': 42302,
#      'surface': 'grass',
#      'address': '100 Park Blvd.',
#      'city': 'San Diego',
#      'state': 'CA',
#      'zip': '92101',
#      'country': 'USA',
#      'id': '0ab45d79-5475-4308-9f94-74b0c185ee6f'},
#     'home': {'name': 'Padres',
#      'market': 'San Diego',
#      'abbr': 'SD',
#      'id': 'd52d5339-cbdd-43f3-9dfa-a42fd588b9a3'},
#     'away': {'name': 'Diamondbacks',
#      'market': 'Arizona',
#      'abbr': 'ARI',
#      'id': '25507be1-6a68-4267-bd82-e097d94b359b'},
#     'broadcast': {'network': 'FS-SD'}},
#    {'id': '052bb0a2-24ab-4736-b97a-8548f2e0f833',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'D',
#     'scheduled': '2017-04-19T18:20:00+00:00',
#     'home_team': '55714da8-fcaf-4574-8443-59bfb511a524',
#     'away_team': 'dcfd5266-00ce-442c-bc09-264cd20cf455',
#     'attendance': 34864,
#     'duration': '3:30',
#     'venue': {'name': 'Wrigley Field',
#      'market': 'Chicago',
#      'capacity': 41072,
#      'surface': 'grass',
#      'address': '1060 West Addison Street',
#      'city': 'Chicago',
#      'state': 'IL',
#      'zip': '60613',
#      'country': 'USA',
#      'id': '53f8eb0d-a361-4a7a-930b-2f8735ea0698'},
#     'home': {'name': 'Cubs',
#      'market': 'Chicago',
#      'abbr': 'CHC',
#      'id': '55714da8-fcaf-4574-8443-59bfb511a524'},
#     'away': {'name': 'Brewers',
#      'market': 'Milwaukee',
#      'abbr': 'MIL',
#      'id': 'dcfd5266-00ce-442c-bc09-264cd20cf455'},
#     'broadcast': {'network': 'MLBN'}},
#    {'id': '0568e182-7342-4224-9932-160be71ef432',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'N',
#     'scheduled': '2017-07-29T23:15:00+00:00',
#     'home_team': '44671792-dc02-4fdd-a5ad-f5f17edaa9d7',
#     'away_team': '25507be1-6a68-4267-bd82-e097d94b359b',
#     'attendance': 48052,
#     'duration': '3:12',
#     'venue': {'name': 'Busch Stadium',
#      'market': 'St. Louis',
#      'capacity': 43975,
#      'surface': 'grass',
#      'address': '700 Clark Street',
#      'city': 'St. Louis',
#      'state': 'MO',
#      'zip': '63102',
#      'country': 'USA',
#      'id': '83cc591a-1096-4383-a6ca-e2bd6f8db629'},
#     'home': {'name': 'Cardinals',
#      'market': 'St. Louis',
#      'abbr': 'STL',
#      'id': '44671792-dc02-4fdd-a5ad-f5f17edaa9d7'},
#     'away': {'name': 'Diamondbacks',
#      'market': 'Arizona',
#      'abbr': 'ARI',
#      'id': '25507be1-6a68-4267-bd82-e097d94b359b'},
#     'broadcast': {'network': 'FS-MW'}},
#    {'id': '057e5ddd-3a1a-48dc-94ad-e41e3703dc74',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'N',
#     'scheduled': '2017-05-19T23:35:00+00:00',
#     'home_team': '12079497-e414-450a-8bf2-29f91de646bf',
#     'away_team': 'd89bed32-3aee-4407-99e3-4103641b999a',
#     'attendance': 35369,
#     'duration': '3:32',
#     'venue': {'name': 'SunTrust Park',
#      'market': 'Atlanta',
#      'capacity': 41500,
#      'surface': 'grass',
#      'address': '755 Battery Avenue',
#      'city': 'Atlanta',
#      'state': 'GA',
#      'zip': '30339',
#      'country': 'USA',
#      'id': '3ca8b577-5844-42ed-81a5-bd5d5cbe350c'},
#     'home': {'name': 'Braves',
#      'market': 'Atlanta',
#      'abbr': 'ATL',
#      'id': '12079497-e414-450a-8bf2-29f91de646bf'},
#     'away': {'name': 'Nationals',
#      'market': 'Washington',
#      'abbr': 'WSH',
#      'id': 'd89bed32-3aee-4407-99e3-4103641b999a'},
#     'broadcast': {'network': 'FS-SO'}},
#    {'id': '0590e337-b38f-41dc-b347-a8ee4298bc84',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'D',
#     'scheduled': '2017-07-30T18:10:00+00:00',
#     'home_team': '47f490cd-2f58-4ef7-9dfd-2ad6ba6c1ae8',
#     'away_team': '80715d0d-0d2a-450f-a970-1b9a3b18c7e7',
#     'attendance': 28152,
#     'duration': '2:56',
#     'venue': {'name': 'Guaranteed Rate Field',
#      'market': 'Chicago',
#      'capacity': 40615,
#      'surface': 'grass',
#      'address': '333 West 35th Street',
#      'city': 'Chicago',
#      'state': 'IL',
#      'zip': '60616',
#      'country': 'USA',
#      'id': '4a550fc1-c03d-4294-b63a-30ff197bedc4'},
#     'home': {'name': 'White Sox',
#      'market': 'Chicago',
#      'abbr': 'CWS',
#      'id': '47f490cd-2f58-4ef7-9dfd-2ad6ba6c1ae8'},
#     'away': {'name': 'Indians',
#      'market': 'Cleveland',
#      'abbr': 'CLE',
#      'id': '80715d0d-0d2a-450f-a970-1b9a3b18c7e7'},
#     'broadcast': {'network': 'WGN'}},
#    {'id': '05cf748f-6b1f-40cb-94a6-951f3ed72629',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'D',
#     'scheduled': '2017-04-11T17:10:00+00:00',
#     'home_team': '575c19b7-4052-41c2-9f0a-1c5813d02f99',
#     'away_team': 'aa34e0ed-f342-4ec6-b774-c79b47b60e2d',
#     'attendance': 21237,
#     'duration': '2:39',
#     'venue': {'name': 'Comerica Park',
#      'market': 'Detroit',
#      'capacity': 41681,
#      'surface': 'grass',
#      'address': '2100 Woodward Avenue',
#      'city': 'Detroit',
#      'state': 'MI',
#      'zip': '48226',
#      'country': 'USA',
#      'id': 'ef9a5eef-06c6-4963-ac70-7fd02c8c8d42'},
#     'home': {'name': 'Tigers',
#      'market': 'Detroit',
#      'abbr': 'DET',
#      'id': '575c19b7-4052-41c2-9f0a-1c5813d02f99'},
#     'away': {'name': 'Twins',
#      'market': 'Minnesota',
#      'abbr': 'MIN',
#      'id': 'aa34e0ed-f342-4ec6-b774-c79b47b60e2d'},
#     'broadcast': {'network': 'FS-DET'}},
#    {'id': '06147cda-e7ff-414d-8096-dcc80172d008',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'N',
#     'scheduled': '2017-04-04T23:10:00+00:00',
#     'home_team': 'bdc11650-6f74-49c4-875e-778aeb7632d9',
#     'away_team': 'a09ec676-f887-43dc-bbb3-cf4bbaee9a18',
#     'attendance': 19366,
#     'duration': '3:07',
#     'venue': {'name': 'Tropicana Field',
#      'market': 'Tampa Bay',
#      'capacity': 31042,
#      'surface': 'turf',
#      'address': 'One Tropicana Drive',
#      'city': 'St. Petersburg',
#      'state': 'FL',
#      'zip': '33705',
#      'country': 'USA',
#      'id': '3aaaf4af-0f8c-49c1-8bf1-1780bb5a5f5c'},
#     'home': {'name': 'Rays',
#      'market': 'Tampa Bay',
#      'abbr': 'TB',
#      'id': 'bdc11650-6f74-49c4-875e-778aeb7632d9'},
#     'away': {'name': 'Yankees',
#      'market': 'New York',
#      'abbr': 'NYY',
#      'id': 'a09ec676-f887-43dc-bbb3-cf4bbaee9a18'},
#     'broadcast': {'network': 'Fox Sports Sun'}},
#    {'id': '062cd394-c473-4cb1-b316-29e810547f16',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'D',
#     'scheduled': '2017-06-28T19:45:00+00:00',
#     'home_team': 'a7723160-10b7-4277-a309-d8dd95a8ae65',
#     'away_team': '29dd9a87-5bcc-4774-80c3-7f50d985068b',
#     'attendance': 41286,
#     'duration': '3:05',
#     'venue': {'name': 'AT&T Park',
#      'market': 'San Francisco',
#      'capacity': 41915,
#      'surface': 'grass',
#      'address': '24 Willie Mays Plaza',
#      'city': 'San Francisco',
#      'state': 'CA',
#      'zip': '94107',
#      'country': 'USA',
#      'id': '2d7542f5-7b80-49f7-9b24-c53ffdc75af6'},
#     'home': {'name': 'Giants',
#      'market': 'San Francisco',
#      'abbr': 'SF',
#      'id': 'a7723160-10b7-4277-a309-d8dd95a8ae65'},
#     'away': {'name': 'Rockies',
#      'market': 'Colorado',
#      'abbr': 'COL',
#      'id': '29dd9a87-5bcc-4774-80c3-7f50d985068b'},
#     'broadcast': {'network': 'CSN-BA'}},
#    {'id': '0630cdbb-fd04-464c-aa3a-2a429378ac6f',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'N',
#     'scheduled': '2017-07-21T23:05:00+00:00',
#     'home_team': '75729d34-bca7-4a0f-b3df-6f26c6ad3719',
#     'away_team': 'eb21dadd-8f10-4095-8bf3-dfb3b779f107',
#     'attendance': 25784,
#     'duration': '3:02',
#     'venue': {'name': 'Oriole Park at Camden Yards',
#      'market': 'Baltimore',
#      'capacity': 45971,
#      'surface': 'grass',
#      'address': '333 West Camden Street',
#      'city': 'Baltimore',
#      'state': 'MD',
#      'zip': '21201',
#      'country': 'USA',
#      'id': '434aa63c-1049-4a54-a6bc-3790c7772ee1'},
#     'home': {'name': 'Orioles',
#      'market': 'Baltimore',
#      'abbr': 'BAL',
#      'id': '75729d34-bca7-4a0f-b3df-6f26c6ad3719'},
#     'away': {'name': 'Astros',
#      'market': 'Houston',
#      'abbr': 'HOU',
#      'id': 'eb21dadd-8f10-4095-8bf3-dfb3b779f107'},
#     'broadcast': {'network': 'MASN'}},
#    {'id': '06419088-2014-40f6-ad10-f9d7bdc26db5',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'N',
#     'scheduled': '2017-07-14T23:10:00+00:00',
#     'home_team': '03556285-bdbb-4576-a06d-42f71f46ddc5',
#     'away_team': 'ef64da7f-cfaf-4300-87b0-9313386b977c',
#     'attendance': 21858,
#     'duration': '3:00',
#     'venue': {'name': 'Marlins Park',
#      'market': 'Miami',
#      'capacity': 36742,
#      'surface': 'grass',
#      'address': '501 Marlins Way',
#      'city': 'Miami',
#      'state': 'FL',
#      'zip': '33125',
#      'country': 'USA',
#      'id': 'd5a66fb3-ff26-4f36-910c-3df5cedb36b3'},
#     'home': {'name': 'Marlins',
#      'market': 'Miami',
#      'abbr': 'MIA',
#      'id': '03556285-bdbb-4576-a06d-42f71f46ddc5'},
#     'away': {'name': 'Dodgers',
#      'market': 'Los Angeles',
#      'abbr': 'LAD',
#      'id': 'ef64da7f-cfaf-4300-87b0-9313386b977c'},
#     'broadcast': {'network': 'FS-FL'}},
#    {'id': '06452dfb-cbe0-4f2a-aa40-ec0c966a8dc1',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'N',
#     'scheduled': '2017-06-09T23:10:00+00:00',
#     'home_team': '93941372-eb4c-4c40-aced-fe3267174393',
#     'away_team': '575c19b7-4052-41c2-9f0a-1c5813d02f99',
#     'attendance': 36853,
#     'duration': '3:36',
#     'venue': {'name': 'Fenway Park',
#      'market': 'Boston',
#      'capacity': 37499,
#      'surface': 'grass',
#      'address': '4 Yawkey Way',
#      'city': 'Boston',
#      'state': 'MA',
#      'zip': '02215',
#      'country': 'USA',
#      'id': 'b27b0dc5-c2c5-401d-b8b9-a6a2dbc225e5'},
#     'home': {'name': 'Red Sox',
#      'market': 'Boston',
#      'abbr': 'BOS',
#      'id': '93941372-eb4c-4c40-aced-fe3267174393'},
#     'away': {'name': 'Tigers',
#      'market': 'Detroit',
#      'abbr': 'DET',
#      'id': '575c19b7-4052-41c2-9f0a-1c5813d02f99'},
#     'broadcast': {'network': 'FS-D'}},
#    {'id': '0661dff2-972c-4f5b-b452-a53a288a77f3',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'N',
#     'scheduled': '2017-08-05T00:10:00+00:00',
#     'home_team': 'eb21dadd-8f10-4095-8bf3-dfb3b779f107',
#     'away_team': '1d678440-b4b1-4954-9b39-70afb3ebbcfa',
#     'attendance': 39287,
#     'duration': '3:05',
#     'venue': {'name': 'Minute Maid Park',
#      'market': 'Houston',
#      'capacity': 42060,
#      'surface': 'grass',
#      'address': '501 Crawford Street',
#      'city': 'Houston',
#      'state': 'TX',
#      'zip': '77002',
#      'country': 'USA',
#      'id': 'f0600f04-1386-4c61-a412-804960c46cb1'},
#     'home': {'name': 'Astros',
#      'market': 'Houston',
#      'abbr': 'HOU',
#      'id': 'eb21dadd-8f10-4095-8bf3-dfb3b779f107'},
#     'away': {'name': 'Blue Jays',
#      'market': 'Toronto',
#      'abbr': 'TOR',
#      'id': '1d678440-b4b1-4954-9b39-70afb3ebbcfa'},
#     'broadcast': {'network': 'ROOT SW'}},
#    {'id': '0677defa-747e-48c4-b78d-5e75699b33b8',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'D',
#     'scheduled': '2017-06-17T18:10:00+00:00',
# ...
#     'attendance': 20303,
#     'duration': '4:25',
#     'venue': {'name': 'Minute Maid Park',
#      'market': 'Houston',
#      'capacity': 42060,
#      'surface': 'grass',
#      'address': '501 Crawford Street',
#      'city': 'Houston',
#      'state': 'TX',
#      'zip': '77002',
#      'country': 'USA',
#      'id': 'f0600f04-1386-4c61-a412-804960c46cb1'},
#     'home': {'name': 'Astros',
#      'market': 'Houston',
#      'abbr': 'HOU',
#      'id': 'eb21dadd-8f10-4095-8bf3-dfb3b779f107'},
#     'away': {'name': 'Mariners',
#      'market': 'Seattle',
#      'abbr': 'SEA',
#      'id': '43a39081-52b4-4f93-ad29-da7f329ea960'},
#     'broadcast': {'network': 'ROOT SW'}},
#    {'id': '67675023-d401-45d4-baba-048c87fa7975',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'D',
#     'scheduled': '2017-08-31T17:10:00+00:00',
#     'home_team': 'eb21dadd-8f10-4095-8bf3-dfb3b779f107',
#     'away_team': 'd99f919b-1534-4516-8e8a-9cd106c6d8cd',
#     'attendance': 3385,
#     'duration': '3:02',
#     'venue': {'name': 'Tropicana Field',
#      'market': 'Tampa Bay',
#      'capacity': 31042,
#      'surface': 'turf',
#      'address': 'One Tropicana Drive',
#      'city': 'St. Petersburg',
#      'state': 'FL',
#      'zip': '33705',
#      'country': 'USA',
#      'id': '3aaaf4af-0f8c-49c1-8bf1-1780bb5a5f5c'},
#     'home': {'name': 'Astros',
#      'market': 'Houston',
#      'abbr': 'HOU',
#      'id': 'eb21dadd-8f10-4095-8bf3-dfb3b779f107'},
#     'away': {'name': 'Rangers',
#      'market': 'Texas',
#      'abbr': 'TEX',
#      'id': 'd99f919b-1534-4516-8e8a-9cd106c6d8cd'},
#     'broadcast': {'network': 'ROOT Sports SW'}},
#    {'id': '67a1580d-1923-4587-8dd4-393540e6ff98',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'N',
#     'scheduled': '2017-08-03T00:05:00+00:00',
#     'home_team': '55714da8-fcaf-4574-8443-59bfb511a524',
#     'away_team': '25507be1-6a68-4267-bd82-e097d94b359b',
#     'attendance': 41321,
#     'duration': '2:44',
#     'venue': {'name': 'Wrigley Field',
#      'market': 'Chicago',
#      'capacity': 41072,
#      'surface': 'grass',
#      'address': '1060 West Addison Street',
#      'city': 'Chicago',
#      'state': 'IL',
#      'zip': '60613',
#      'country': 'USA',
#      'id': '53f8eb0d-a361-4a7a-930b-2f8735ea0698'},
#     'home': {'name': 'Cubs',
#      'market': 'Chicago',
#      'abbr': 'CHC',
#      'id': '55714da8-fcaf-4574-8443-59bfb511a524'},
#     'away': {'name': 'Diamondbacks',
#      'market': 'Arizona',
#      'abbr': 'ARI',
#      'id': '25507be1-6a68-4267-bd82-e097d94b359b'},
#     'broadcast': {'network': 'FS-AZ'}},
#    {'id': '67f7c380-82b7-46e6-894a-45d72faf3847',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'N',
#     'scheduled': '2017-08-31T23:05:00+00:00',
#     'home_team': 'a09ec676-f887-43dc-bbb3-cf4bbaee9a18',
#     'away_team': '93941372-eb4c-4c40-aced-fe3267174393',
#     'attendance': 43309,
#     'duration': '3:44',
#     'venue': {'name': 'Yankee Stadium',
#      'market': 'New York',
#      'capacity': 49642,
#      'surface': 'grass',
#      'address': 'One East 161st Street',
#      'city': 'Bronx',
#      'state': 'NY',
#      'zip': '10451',
#      'country': 'USA',
#      'id': '706e9828-6687-4ac8-a409-3fb972e8bae9'},
#     'home': {'name': 'Yankees',
#      'market': 'New York',
#      'abbr': 'NYY',
#      'id': 'a09ec676-f887-43dc-bbb3-cf4bbaee9a18'},
#     'away': {'name': 'Red Sox',
#      'market': 'Boston',
#      'abbr': 'BOS',
#      'id': '93941372-eb4c-4c40-aced-fe3267174393'},
#     'broadcast': {'network': 'WPIX'}},
#    {'id': '683ddf25-a2e6-41cb-b972-d072838dca6d',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'D',
#     'scheduled': '2017-04-23T20:10:00+00:00',
#     'home_team': '25507be1-6a68-4267-bd82-e097d94b359b',
#     'away_team': 'ef64da7f-cfaf-4300-87b0-9313386b977c',
#     'attendance': 28704,
#     'duration': '2:54',
#     'venue': {'name': 'Chase Field',
#      'market': 'Arizona',
#      'capacity': 48633,
#      'surface': 'grass',
#      'address': '401 East Jefferson Street',
#      'city': 'Phoenix',
#      'state': 'AZ',
#      'zip': '85004',
#      'country': 'USA',
#      'id': 'bf05de0d-7ced-4a19-8e17-2bbd985f8a92'},
#     'home': {'name': 'Diamondbacks',
#      'market': 'Arizona',
#      'abbr': 'ARI',
#      'id': '25507be1-6a68-4267-bd82-e097d94b359b'},
#     'away': {'name': 'Dodgers',
#      'market': 'Los Angeles',
#      'abbr': 'LAD',
#      'id': 'ef64da7f-cfaf-4300-87b0-9313386b977c'},
#     'broadcast': {'network': 'FS-AZ'}},
#    {'id': '68614ceb-33ef-4b53-9e48-64ec1828abd0',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'D',
#     'scheduled': '2017-05-14T18:15:00+00:00',
#     'home_team': '833a51a9-0d84-410f-bd77-da08c3e5e26e',
#     'away_team': '75729d34-bca7-4a0f-b3df-6f26c6ad3719',
#     'attendance': 30662,
#     'duration': '3:31',
#     'venue': {'name': 'Kauffman Stadium',
#      'market': 'Kansas City',
#      'capacity': 37903,
#      'surface': 'grass',
#      'address': 'One Royal Way',
#      'city': 'Kansas City',
#      'state': 'MO',
#      'zip': '64129',
#      'country': 'USA',
#      'id': '6fca95c9-7f2c-4acb-a9f3-02ef96340d2a'},
#     'home': {'name': 'Royals',
#      'market': 'Kansas City',
#      'abbr': 'KC',
#      'id': '833a51a9-0d84-410f-bd77-da08c3e5e26e'},
#     'away': {'name': 'Orioles',
#      'market': 'Baltimore',
#      'abbr': 'BAL',
#      'id': '75729d34-bca7-4a0f-b3df-6f26c6ad3719'},
#     'broadcast': {'network': 'FS-KC'}},
#    {'id': '6889e77b-c756-4131-a312-13ed7879f98b',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'D',
#     'scheduled': '2017-04-09T18:10:00+00:00',
#     'home_team': 'eb21dadd-8f10-4095-8bf3-dfb3b779f107',
#     'away_team': '833a51a9-0d84-410f-bd77-da08c3e5e26e',
#     'attendance': 32411,
#     'duration': '3:49',
#     'venue': {'name': 'Minute Maid Park',
#      'market': 'Houston',
#      'capacity': 42060,
#      'surface': 'grass',
#      'address': '501 Crawford Street',
#      'city': 'Houston',
#      'state': 'TX',
#      'zip': '77002',
#      'country': 'USA',
#      'id': 'f0600f04-1386-4c61-a412-804960c46cb1'},
#     'home': {'name': 'Astros',
#      'market': 'Houston',
#      'abbr': 'HOU',
#      'id': 'eb21dadd-8f10-4095-8bf3-dfb3b779f107'},
#     'away': {'name': 'Royals',
#      'market': 'Kansas City',
#      'abbr': 'KC',
#      'id': '833a51a9-0d84-410f-bd77-da08c3e5e26e'},
#     'broadcast': {'network': 'FS-KC'}},
#    {'id': '69159801-8733-4315-beb1-85c1ff18da25',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'D',
#     'scheduled': '2017-08-13T17:10:00+00:00',
#     'home_team': '03556285-bdbb-4576-a06d-42f71f46ddc5',
#     'away_team': '29dd9a87-5bcc-4774-80c3-7f50d985068b',
#     'attendance': 20769,
#     'duration': '3:06',
#     'venue': {'name': 'Marlins Park',
#      'market': 'Miami',
#      'capacity': 36742,
#      'surface': 'grass',
#      'address': '501 Marlins Way',
#      'city': 'Miami',
#      'state': 'FL',
#      'zip': '33125',
#      'country': 'USA',
#      'id': 'd5a66fb3-ff26-4f36-910c-3df5cedb36b3'},
#     'home': {'name': 'Marlins',
#      'market': 'Miami',
#      'abbr': 'MIA',
#      'id': '03556285-bdbb-4576-a06d-42f71f46ddc5'},
#     'away': {'name': 'Rockies',
#      'market': 'Colorado',
#      'abbr': 'COL',
#      'id': '29dd9a87-5bcc-4774-80c3-7f50d985068b'},
#     'broadcast': {'network': 'FS-FL'}},
#    {'id': '69264acc-35d4-42d7-960b-ccb624b6db72',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'D',
#     'scheduled': '2017-06-04T17:10:00+00:00',
#     'home_team': '03556285-bdbb-4576-a06d-42f71f46ddc5',
#     'away_team': '25507be1-6a68-4267-bd82-e097d94b359b',
#     'attendance': 20387,
#     'duration': '3:32',
#     'venue': {'name': 'Marlins Park',
#      'market': 'Miami',
#      'capacity': 36742,
#      'surface': 'grass',
#      'address': '501 Marlins Way',
#      'city': 'Miami',
#      'state': 'FL',
#      'zip': '33125',
#      'country': 'USA',
#      'id': 'd5a66fb3-ff26-4f36-910c-3df5cedb36b3'},
#     'home': {'name': 'Marlins',
#      'market': 'Miami',
#      'abbr': 'MIA',
#      'id': '03556285-bdbb-4576-a06d-42f71f46ddc5'},
#     'away': {'name': 'Diamondbacks',
#      'market': 'Arizona',
#      'abbr': 'ARI',
#      'id': '25507be1-6a68-4267-bd82-e097d94b359b'},
#     'broadcast': {'network': 'FS-FL'}},
#    {'id': '699a4432-5294-4c62-bf62-ae079115a66a',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'N',
#     'scheduled': '2017-09-22T23:35:00+00:00',
#     'home_team': 'dcfd5266-00ce-442c-bc09-264cd20cf455',
#     'away_team': '55714da8-fcaf-4574-8443-59bfb511a524',
#     'attendance': 40116,
#     'duration': '4:03',
#     'venue': {'name': 'Miller Park',
#      'market': 'Milwaukee',
#      'capacity': 41900,
#      'surface': 'grass',
#      'address': 'One Brewers Way',
#      'city': 'Milwaukee',
#      'state': 'WI',
#      'zip': '53214',
#      'country': 'USA',
#      'id': '3d13c8a7-283f-482b-ade1-441e25b6465d'},
#     'home': {'name': 'Brewers',
#      'market': 'Milwaukee',
#      'abbr': 'MIL',
#      'id': 'dcfd5266-00ce-442c-bc09-264cd20cf455'},
#     'away': {'name': 'Cubs',
#      'market': 'Chicago',
#      'abbr': 'CHC',
#      'id': '55714da8-fcaf-4574-8443-59bfb511a524'},
#     'broadcast': {'network': 'ESPN'}},
#    {'id': '69a7c04a-c311-4014-aede-90a3565321ca',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'D',
#     'scheduled': '2017-04-07T20:10:00+00:00',
#     'home_team': '29dd9a87-5bcc-4774-80c3-7f50d985068b',
#     'away_team': 'ef64da7f-cfaf-4300-87b0-9313386b977c',
#     'attendance': 49169,
#     'duration': '3:00',
#     'venue': {'name': 'Coors Field',
#      'market': 'Colorado',
#      'capacity': 50398,
#      'surface': 'grass',
#      'address': '2001 Blake Street',
#      'city': 'Denver',
#      'state': 'CO',
#      'zip': '80205',
#      'country': 'USA',
#      'id': '85dd5cd6-7324-4b52-a1cc-68f816d0cdce'},
#     'home': {'name': 'Rockies',
#      'market': 'Colorado',
#      'abbr': 'COL',
#      'id': '29dd9a87-5bcc-4774-80c3-7f50d985068b'},
#     'away': {'name': 'Dodgers',
#      'market': 'Los Angeles',
#      'abbr': 'LAD',
#      'id': 'ef64da7f-cfaf-4300-87b0-9313386b977c'},
#     'broadcast': {'network': 'ROOT RM'}},
#    {'id': '69b001f3-aa16-42de-9d8c-e0ef48a43d15',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'D',
#     'scheduled': '2017-04-16T17:35:00+00:00',
#     'home_team': '12079497-e414-450a-8bf2-29f91de646bf',
#     'away_team': 'd52d5339-cbdd-43f3-9dfa-a42fd588b9a3',
#     'attendance': 37147,
#     'duration': '2:46',
#     'venue': {'name': 'SunTrust Park',
#      'market': 'Atlanta',
#      'capacity': 41500,
#      'surface': 'grass',
#      'address': '755 Battery Avenue',
#      'city': 'Atlanta',
#      'state': 'GA',
#      'zip': '30339',
#      'country': 'USA',
#      'id': '3ca8b577-5844-42ed-81a5-bd5d5cbe350c'},
#     'home': {'name': 'Braves',
#      'market': 'Atlanta',
#      'abbr': 'ATL',
#      'id': '12079497-e414-450a-8bf2-29f91de646bf'},
#     'away': {'name': 'Padres',
#      'market': 'San Diego',
#      'abbr': 'SD',
#      'id': 'd52d5339-cbdd-43f3-9dfa-a42fd588b9a3'},
#     'broadcast': {'network': 'FS-SD'}},
#    {'id': '69bb4972-a215-4fec-bf8a-6113fcd3a366',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'D',
#     'scheduled': '2017-08-16T19:40:00+00:00',
#     'home_team': '43a39081-52b4-4f93-ad29-da7f329ea960',
#     'away_team': '75729d34-bca7-4a0f-b3df-6f26c6ad3719',
#     'attendance': 33448,
#     'duration': '3:13',
#     'venue': {'name': 'Safeco Field',
#      'market': 'Seattle',
#      'capacity': 47476,
#      'surface': 'grass',
#      'address': '1516 First Avenue South',
#      'city': 'Seattle',
#      'state': 'WA',
#      'zip': '98134',
#      'country': 'USA',
#      'id': 'f1c03dac-3c0f-437c-a325-8d5702cd321a'},
#     'home': {'name': 'Mariners',
#      'market': 'Seattle',
#      'abbr': 'SEA',
#      'id': '43a39081-52b4-4f93-ad29-da7f329ea960'},
#     'away': {'name': 'Orioles',
#      'market': 'Baltimore',
#      'abbr': 'BAL',
#      'id': '75729d34-bca7-4a0f-b3df-6f26c6ad3719'},
#     'broadcast': {'network': 'ROOT NW'}},
#    {'id': '69e14052-b83d-452a-9949-63d5ceeb1972',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'N',
#     'scheduled': '2017-09-02T00:10:00+00:00',
#     'home_team': 'dcfd5266-00ce-442c-bc09-264cd20cf455',
#     'away_team': 'd89bed32-3aee-4407-99e3-4103641b999a',
#     'attendance': 40044,
#     'duration': '2:39',
#     'venue': {'name': 'Miller Park',
#      'market': 'Milwaukee',
#      'capacity': 41900,
#      'surface': 'grass',
#      'address': 'One Brewers Way',
#      'city': 'Milwaukee',
#      'state': 'WI',
#      'zip': '53214',
#      'country': 'USA',
#      'id': '3d13c8a7-283f-482b-ade1-441e25b6465d'},
#     'home': {'name': 'Brewers',
#      'market': 'Milwaukee',
#      'abbr': 'MIL',
#      'id': 'dcfd5266-00ce-442c-bc09-264cd20cf455'},
#     'away': {'name': 'Nationals',
#      'market': 'Washington',
#      'abbr': 'WSH',
#      'id': 'd89bed32-3aee-4407-99e3-4103641b999a'},
#     'broadcast': {'network': 'FS-WI'}},
#    {'id': '69f0feb0-3e90-4cf2-b76e-33b11ce67c3e',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'N',
#     'scheduled': '2017-04-07T01:40:00+00:00',
#     'home_team': '25507be1-6a68-4267-bd82-e097d94b359b',
#     'away_team': 'a7723160-10b7-4277-a309-d8dd95a8ae65',
#     'attendance': 15308,
#     'duration': '3:00',
#     'venue': {'name': 'Chase Field',
#      'market': 'Arizona',
#      'capacity': 48633,
#      'surface': 'grass',
#      'address': '401 East Jefferson Street',
#      'city': 'Phoenix',
#      'state': 'AZ',
#      'zip': '85004',
#      'country': 'USA',
#      'id': 'bf05de0d-7ced-4a19-8e17-2bbd985f8a92'},
#     'home': {'name': 'Diamondbacks',
#      'market': 'Arizona',
#      'abbr': 'ARI',
#      'id': '25507be1-6a68-4267-bd82-e097d94b359b'},
#     'away': {'name': 'Giants',
#      'market': 'San Francisco',
#      'abbr': 'SF',
#      'id': 'a7723160-10b7-4277-a309-d8dd95a8ae65'},
#     'broadcast': {'network': 'FS-AZ'}},
#    {'id': '69f2a57a-ead4-4a00-84e6-d86332640da4',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'N',
#     'scheduled': '2017-05-02T02:10:00+00:00',
#     'home_team': 'ef64da7f-cfaf-4300-87b0-9313386b977c',
#     'away_team': 'a7723160-10b7-4277-a309-d8dd95a8ae65',
#     'attendance': 44606,
#     'duration': '2:52',
#     'venue': {'name': 'Dodger Stadium',
#      'market': 'Los Angeles',
#      'capacity': 56000,
#      'surface': 'grass',
#      'address': '1000 Vin Scully Avenue',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'zip': '90012',
#      'country': 'USA',
#      'id': '66a19c3d-24fe-477d-bee7-c6ef1b98352f'},
#     'home': {'name': 'Dodgers',
#      'market': 'Los Angeles',
#      'abbr': 'LAD',
#      'id': 'ef64da7f-cfaf-4300-87b0-9313386b977c'},
#     'away': {'name': 'Giants',
#      'market': 'San Francisco',
#      'abbr': 'SF',
#      'id': 'a7723160-10b7-4277-a309-d8dd95a8ae65'},
#     'broadcast': {'network': 'MLBN'}},
#    {'id': '69fff08e-37b6-4c6c-b27b-a6044ef9f034',
#     'status': 'closed',
#     'coverage': 'full',
#     'game_number': 1,
#     'day_night': 'D',
#     'scheduled': '2017-04-06T19:35:00+00:00',
#     'home_team': '27a59d3b-ff7c-48ea-b016-4798f560f5e1',
#     'away_team': '4f735188-37c8-473d-ae32-1f7e34ccf892',
#     'attendance': 13292,
#     'duration': '2:44',
#     'venue': {'name': 'Oakland-Alameda County Coliseum',
#      'market': 'Oakland',
#      'capacity': 37090,
#      'surface': 'grass',
#      'address': '7000 Coliseum Way',
#      'city': 'Oakland',
#      'state': 'CA',
#      'zip': '94621',
#      'country': 'USA',
#      'id': '48cbd35a-d932-4a75-beab-067bfbacfc26'},
#     'home': {'name': 'Athletics',
#      'market': 'Oakland',
#      'abbr': 'OAK',
#      'id': '27a59d3b-ff7c-48ea-b016-4798f560f5e1'},
#     'away': {'name': 'Angels',
#      'market': 'Los Angeles',
#      'abbr': 'LAA',
#      'id': '4f735188-37c8-473d-ae32-1f7e34ccf892'},
#     'broadcast': {'network': 'CSN-CA'}},
#    ...],
#   '_comment': 'Generation started @ 2018-09-11 02:23:54 UTC ended @ 2018-09-11 02:23:59 UTC'}]

# %%
# create dataframe from set of entries
df_2017 = pd.DataFrame(entries_2017[0]['games'])

# %%
# show summary of dataframe
df_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2431 entries, 0 to 2430
# Data columns (total 15 columns):
# attendance     2420 non-null float64
# away           2431 non-null object
# away_team      2431 non-null object
# broadcast      2431 non-null object
# coverage       2431 non-null object
# day_night      2431 non-null object
# duration       2431 non-null object
# game_number    2431 non-null int64
# home           2431 non-null object
# home_team      2431 non-null object
# id             2431 non-null object
# rescheduled    39 non-null object
# scheduled      2431 non-null object
# status         2431 non-null object
# venue          2431 non-null object
# dtypes: float64(1), int64(1), object(13)
# memory usage: 285.0+ KB

# %%
home_2016_ids = df_2016['home_team'].drop_duplicates().sort_values()
home_2016_ids
# Out:
# 22     03556285-bdbb-4576-a06d-42f71f46ddc5
# 3      12079497-e414-450a-8bf2-29f91de646bf
# 5      1d678440-b4b1-4954-9b39-70afb3ebbcfa
# 9      2142e1ba-3b40-445c-b8bb-f1f8b1054220
# 7      25507be1-6a68-4267-bd82-e097d94b359b
# 34     27a59d3b-ff7c-48ea-b016-4798f560f5e1
# 2      29dd9a87-5bcc-4774-80c3-7f50d985068b
# 66     43a39081-52b4-4f93-ad29-da7f329ea960
# 33     44671792-dc02-4fdd-a5ad-f5f17edaa9d7
# 11     47f490cd-2f58-4ef7-9dfd-2ad6ba6c1ae8
# 64     481dfe7e-5dab-46ab-a49f-9dcc2b6e2cfd
# 13     4f735188-37c8-473d-ae32-1f7e34ccf892
# 1      55714da8-fcaf-4574-8443-59bfb511a524
# 35     575c19b7-4052-41c2-9f0a-1c5813d02f99
# 73     75729d34-bca7-4a0f-b3df-6f26c6ad3719
# 79     80715d0d-0d2a-450f-a970-1b9a3b18c7e7
# 24     833a51a9-0d84-410f-bd77-da08c3e5e26e
# 65     93941372-eb4c-4c40-aced-fe3267174393
# 69     a09ec676-f887-43dc-bbb3-cf4bbaee9a18
# 124    a7723160-10b7-4277-a309-d8dd95a8ae65
# 4      aa34e0ed-f342-4ec6-b774-c79b47b60e2d
# 20     bdc11650-6f74-49c4-875e-778aeb7632d9
# 0      c874a065-c115-4e7d-b0f0-235584fb0e6f
# 16     d52d5339-cbdd-43f3-9dfa-a42fd588b9a3
# 38     d89bed32-3aee-4407-99e3-4103641b999a
# 56     d99f919b-1534-4516-8e8a-9cd106c6d8cd
# 26     dcfd5266-00ce-442c-bc09-264cd20cf455
# 31     dd59d49e-caee-4443-9220-f05d0d9bd1e1
# 6      eb21dadd-8f10-4095-8bf3-dfb3b779f107
# 8      ef64da7f-cfaf-4300-87b0-9313386b977c
# 57     f246a5e5-afdb-479c-9aaa-c68beeda7af6
# Name: home_team, dtype: object

# %%
dodgers_games = df_2016[(df_2016['away_team']=='ef64da7f-cfaf-4300-87b0-9313386b977c')]
dodgers_games.sort_values('scheduled')
# Out:
#       attendance                                               away  \
# 1989     44317.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 2108     28329.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 1911     30054.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 705      41940.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 2344     41742.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 887      41224.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 147      41656.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 786      14160.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 2195     16087.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 1471     18431.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 984      37153.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 2397     42179.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 167      35962.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 43       14116.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 1939     13226.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 125      42304.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 1577     47156.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 1091     46665.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 2412     44006.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 1118     45007.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 350      31836.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 1516     40221.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 2138     43100.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 577      43462.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 1549     42227.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 2143     42287.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 1513     41470.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 2098     34681.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 2316     36426.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 955      37422.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# ...          ...                                                ...
# 1097     41423.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 1350     32607.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 747      28682.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 2007     31117.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 212      28118.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 797      21137.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 738      29187.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 2055     28184.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 1247     29735.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 296      28752.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 2200     15690.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 29       24308.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 118      24790.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 1867     22683.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 1981     22940.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 1916     20933.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 740      20188.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 1482     32058.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 901      32615.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 1218     30254.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 495      27126.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 1784     28211.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 894      38255.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 943      26159.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 197      27376.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 339      29471.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 477      35804.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 397      41359.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 688      41320.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
# 2417     41445.0  {'name': 'Dodgers', 'market': 'Los Angeles', '...
#
#                                  away_team                    broadcast  \
# 1989  ef64da7f-cfaf-4300-87b0-9313386b977c          {'network': 'FSSD'}
# 2108  ef64da7f-cfaf-4300-87b0-9313386b977c          {'network': 'FSSD'}
# 1911  ef64da7f-cfaf-4300-87b0-9313386b977c          {'network': 'FSSD'}
# 705   ef64da7f-cfaf-4300-87b0-9313386b977c        {'network': 'CSN-BA'}
# 2344  ef64da7f-cfaf-4300-87b0-9313386b977c  {'network': 'NBC Bay Area'}
# 887   ef64da7f-cfaf-4300-87b0-9313386b977c  {'network': 'Fox Sports 1'}
# 147   ef64da7f-cfaf-4300-87b0-9313386b977c        {'network': 'CSN-BA'}
# 786   ef64da7f-cfaf-4300-87b0-9313386b977c          {'network': 'FSSO'}
# 2195  ef64da7f-cfaf-4300-87b0-9313386b977c          {'network': 'FSSO'}
# 1471  ef64da7f-cfaf-4300-87b0-9313386b977c          {'network': 'FSSO'}
# 984   ef64da7f-cfaf-4300-87b0-9313386b977c   {'network': 'ROOT SPORTS'}
# 2397  ef64da7f-cfaf-4300-87b0-9313386b977c   {'network': 'ROOT SPORTS'}
# 167   ef64da7f-cfaf-4300-87b0-9313386b977c   {'network': 'ROOT SPORTS'}
# 43    ef64da7f-cfaf-4300-87b0-9313386b977c    {'network': 'Sun Sports'}
# 1939  ef64da7f-cfaf-4300-87b0-9313386b977c    {'network': 'Sun Sports'}
# 125   ef64da7f-cfaf-4300-87b0-9313386b977c        {'network': 'SNET-1'}
# 1577  ef64da7f-cfaf-4300-87b0-9313386b977c          {'network': 'SNET'}
# 1091  ef64da7f-cfaf-4300-87b0-9313386b977c          {'network': 'SNET'}
# 2412  ef64da7f-cfaf-4300-87b0-9313386b977c          {'network': 'FS-W'}
# 1118  ef64da7f-cfaf-4300-87b0-9313386b977c          {'network': 'FS-W'}
# 350   ef64da7f-cfaf-4300-87b0-9313386b977c          {'network': 'FSSD'}
# 1516  ef64da7f-cfaf-4300-87b0-9313386b977c          {'network': 'FSSD'}
# 2138  ef64da7f-cfaf-4300-87b0-9313386b977c          {'network': 'FSSD'}
# 577   ef64da7f-cfaf-4300-87b0-9313386b977c           {'network': 'SNY'}
# 1549  ef64da7f-cfaf-4300-87b0-9313386b977c           {'network': 'FOX'}
# 2143  ef64da7f-cfaf-4300-87b0-9313386b977c         {'network': 'ESPN2'}
# 1513  ef64da7f-cfaf-4300-87b0-9313386b977c           {'network': 'WGN'}
# 2098  ef64da7f-cfaf-4300-87b0-9313386b977c         {'network': 'ABC 7'}
# 2316  ef64da7f-cfaf-4300-87b0-9313386b977c           {'network': 'CSN'}
# 955   ef64da7f-cfaf-4300-87b0-9313386b977c           {'network': 'CSN'}
# ...                                    ...                          ...
# 1097  ef64da7f-cfaf-4300-87b0-9313386b977c          {'network': 'ESPN'}
# 1350  ef64da7f-cfaf-4300-87b0-9313386b977c        {'network': 'ROOTRM'}
# 747   ef64da7f-cfaf-4300-87b0-9313386b977c        {'network': 'ROOTRM'}
# 2007  ef64da7f-cfaf-4300-87b0-9313386b977c        {'network': 'ROOTRM'}
# 212   ef64da7f-cfaf-4300-87b0-9313386b977c         {'network': 'CSN-P'}
# 797   ef64da7f-cfaf-4300-87b0-9313386b977c         {'network': 'CSN-P'}
# 738   ef64da7f-cfaf-4300-87b0-9313386b977c           {'network': 'TCN'}
# 2055  ef64da7f-cfaf-4300-87b0-9313386b977c          {'network': 'FS-O'}
# 1247  ef64da7f-cfaf-4300-87b0-9313386b977c          {'network': 'FS-O'}
# 296   ef64da7f-cfaf-4300-87b0-9313386b977c          {'network': 'FS-O'}
# 2200  ef64da7f-cfaf-4300-87b0-9313386b977c                           {}
# 29    ef64da7f-cfaf-4300-87b0-9313386b977c        {'network': 'ROOTRM'}
# 118   ef64da7f-cfaf-4300-87b0-9313386b977c                           {}
# 1867  ef64da7f-cfaf-4300-87b0-9313386b977c        {'network': 'ROOTRM'}
# 1981  ef64da7f-cfaf-4300-87b0-9313386b977c          {'network': 'FS-F'}
# 1916  ef64da7f-cfaf-4300-87b0-9313386b977c          {'network': 'FS-F'}
# 740   ef64da7f-cfaf-4300-87b0-9313386b977c          {'network': 'FS-F'}
# 1482  ef64da7f-cfaf-4300-87b0-9313386b977c           {'network': 'YES'}
# 901   ef64da7f-cfaf-4300-87b0-9313386b977c           {'network': 'YES'}
# 1218  ef64da7f-cfaf-4300-87b0-9313386b977c           {'network': 'YES'}
# 495   ef64da7f-cfaf-4300-87b0-9313386b977c    {'network': 'FS-A+(Sp.)'}
# 1784  ef64da7f-cfaf-4300-87b0-9313386b977c    {'network': 'FS-A+(Sp.)'}
# 894   ef64da7f-cfaf-4300-87b0-9313386b977c    {'network': 'FS-A+(Sp.)'}
# 943   ef64da7f-cfaf-4300-87b0-9313386b977c    {'network': 'FS-A+(Sp.)'}
# 197   ef64da7f-cfaf-4300-87b0-9313386b977c          {'network': 'FSSD'}
# 339   ef64da7f-cfaf-4300-87b0-9313386b977c          {'network': 'FSSD'}
# 477   ef64da7f-cfaf-4300-87b0-9313386b977c          {'network': 'FSSD'}
# 397   ef64da7f-cfaf-4300-87b0-9313386b977c          {'network': 'CSBA'}
# 688   ef64da7f-cfaf-4300-87b0-9313386b977c          {'network': 'CSBA'}
# 2417  ef64da7f-cfaf-4300-87b0-9313386b977c          {'network': 'CSBA'}
#
#      coverage day_night duration  game_number  \
# 1989     full         D     3:10            1
# 2108     full         N     2:36            1
# 1911     full         N     2:57            1
# 705      full         D     3:07            1
# 2344     full         N     2:58            1
# 887      full         D     3:22            1
# 147      full         D     3:07            1
# 786      full         N     2:57            1
# 2195     full         N     3:54            1
# 1471     full         D     3:28            1
# 984      full         N     3:27            1
# 2397     full         N     3:09            1
# 167      full         D     4:02            1
# 43       full         N     3:11            1
# 1939     full         N     3:21            1
# 125      full         N     2:53            1
# 1577     full         D     2:28            1
# 1091     full         D     3:10            1
# 2412     full         N     3:12            1
# 1118     full         N     3:06            1
# 350      full         N     3:25            1
# 1516     full         N     3:39            1
# 2138     full         D     5:47            1
# 577      full         N     3:03            1
# 1549     full         N     3:12            1
# 2143     full         N     3:05            1
# 1513     full         D     2:40            1
# 2098     full         N     2:57            1
# 2316     full         N     2:29            1
# 955      full         D     2:25            1
# ...       ...       ...      ...          ...
# 1097     full         N     3:49            1
# 1350     full         N     3:28            1
# 747      full         N     2:31            1
# 2007     full         N     3:08            1
# 212      full         N     3:30            1
# 797      full         N     3:23            1
# 738      full         N     2:54            1
# 2055     full         N     3:39            1
# 1247     full         N     2:53            1
# 296      full         D     2:55            1
# 2200     full         D     4:02            1
# 29       full         N     3:36            1
# 118      full         D     2:55            1
# 1867     full         N     3:36            2
# 1981     full         N     3:08            1
# 1916     full         N     2:52            1
# 740      full         D     2:26            1
# 1482     full         N     3:13            1
# 901      full         N     3:02            1
# 1218     full         D     2:57            1
# 495      full         N     2:39            1
# 1784     full         N     3:32            1
# 894      full         N     3:12            1
# 943      full         D     4:29            1
# 197      full         N     3:02            1
# 339      full         N     2:45            1
# 477      full         N     3:38            1
# 397      full         N     3:15            1
# 688      full         D     2:16            1
# 2417     full         D     3:04            1
#
#                                                    home  \
# 1989  {'name': 'Padres', 'market': 'San Diego', 'abb...
# 2108  {'name': 'Padres', 'market': 'San Diego', 'abb...
# 1911  {'name': 'Padres', 'market': 'San Diego', 'abb...
# 705   {'name': 'Giants', 'market': 'San Francisco', ...
# 2344  {'name': 'Giants', 'market': 'San Francisco', ...
# 887   {'name': 'Giants', 'market': 'San Francisco', ...
# 147   {'name': 'Giants', 'market': 'San Francisco', ...
# 786   {'name': 'Braves', 'market': 'Atlanta', 'abbr'...
# 2195  {'name': 'Braves', 'market': 'Atlanta', 'abbr'...
# 1471  {'name': 'Braves', 'market': 'Atlanta', 'abbr'...
# 984   {'name': 'Rockies', 'market': 'Colorado', 'abb...
# 2397  {'name': 'Rockies', 'market': 'Colorado', 'abb...
# 167   {'name': 'Rockies', 'market': 'Colorado', 'abb...
# 43    {'name': 'Rays', 'market': 'Tampa Bay', 'abbr'...
# 1939  {'name': 'Rays', 'market': 'Tampa Bay', 'abbr'...
# 125   {'name': 'Blue Jays', 'market': 'Toronto', 'ab...
# 1577  {'name': 'Blue Jays', 'market': 'Toronto', 'ab...
# 1091  {'name': 'Blue Jays', 'market': 'Toronto', 'ab...
# 2412  {'name': 'Angels', 'market': 'Los Angeles', 'a...
# 1118  {'name': 'Angels', 'market': 'Los Angeles', 'a...
# 350   {'name': 'Padres', 'market': 'San Diego', 'abb...
# 1516  {'name': 'Padres', 'market': 'San Diego', 'abb...
# 2138  {'name': 'Padres', 'market': 'San Diego', 'abb...
# 577   {'name': 'Mets', 'market': 'New York', 'abbr':...
# 1549  {'name': 'Mets', 'market': 'New York', 'abbr':...
# 2143  {'name': 'Mets', 'market': 'New York', 'abbr':...
# 1513  {'name': 'Cubs', 'market': 'Chicago', 'abbr': ...
# 2098  {'name': 'Cubs', 'market': 'Chicago', 'abbr': ...
# 2316  {'name': 'Cubs', 'market': 'Chicago', 'abbr': ...
# 955   {'name': 'Cubs', 'market': 'Chicago', 'abbr': ...
# ...                                                 ...
# 1097  {'name': 'Cardinals', 'market': 'St. Louis', '...
# 1350  {'name': 'Rockies', 'market': 'Colorado', 'abb...
# 747   {'name': 'Rockies', 'market': 'Colorado', 'abb...
# 2007  {'name': 'Rockies', 'market': 'Colorado', 'abb...
# 212   {'name': 'Phillies', 'market': 'Philadelphia',...
# 797   {'name': 'Phillies', 'market': 'Philadelphia',...
# 738   {'name': 'Phillies', 'market': 'Philadelphia',...
# 2055  {'name': 'Reds', 'market': 'Cincinnati', 'abbr...
# 1247  {'name': 'Reds', 'market': 'Cincinnati', 'abbr...
# 296   {'name': 'Reds', 'market': 'Cincinnati', 'abbr...
# 2200  {'name': 'Reds', 'market': 'Cincinnati', 'abbr...
# 29    {'name': 'Rockies', 'market': 'Colorado', 'abb...
# 118   {'name': 'Rockies', 'market': 'Colorado', 'abb...
# 1867  {'name': 'Rockies', 'market': 'Colorado', 'abb...
# 1981  {'name': 'Marlins', 'market': 'Miami', 'abbr':...
# 1916  {'name': 'Marlins', 'market': 'Miami', 'abbr':...
# 740   {'name': 'Marlins', 'market': 'Miami', 'abbr':...
# 1482  {'name': 'Yankees', 'market': 'New York', 'abb...
# 901   {'name': 'Yankees', 'market': 'New York', 'abb...
# 1218  {'name': 'Yankees', 'market': 'New York', 'abb...
# 495   {'name': 'Diamondbacks', 'market': 'Arizona', ...
# 1784  {'name': 'Diamondbacks', 'market': 'Arizona', ...
# 894   {'name': 'Diamondbacks', 'market': 'Arizona', ...
# 943   {'name': 'Diamondbacks', 'market': 'Arizona', ...
# 197   {'name': 'Padres', 'market': 'San Diego', 'abb...
# 339   {'name': 'Padres', 'market': 'San Diego', 'abb...
# 477   {'name': 'Padres', 'market': 'San Diego', 'abb...
# 397   {'name': 'Giants', 'market': 'San Francisco', ...
# 688   {'name': 'Giants', 'market': 'San Francisco', ...
# 2417  {'name': 'Giants', 'market': 'San Francisco', ...
#
#                                  home_team  \
# 1989  d52d5339-cbdd-43f3-9dfa-a42fd588b9a3
# 2108  d52d5339-cbdd-43f3-9dfa-a42fd588b9a3
# 1911  d52d5339-cbdd-43f3-9dfa-a42fd588b9a3
# 705   a7723160-10b7-4277-a309-d8dd95a8ae65
# 2344  a7723160-10b7-4277-a309-d8dd95a8ae65
# 887   a7723160-10b7-4277-a309-d8dd95a8ae65
# 147   a7723160-10b7-4277-a309-d8dd95a8ae65
# 786   12079497-e414-450a-8bf2-29f91de646bf
# 2195  12079497-e414-450a-8bf2-29f91de646bf
# 1471  12079497-e414-450a-8bf2-29f91de646bf
# 984   29dd9a87-5bcc-4774-80c3-7f50d985068b
# 2397  29dd9a87-5bcc-4774-80c3-7f50d985068b
# 167   29dd9a87-5bcc-4774-80c3-7f50d985068b
# 43    bdc11650-6f74-49c4-875e-778aeb7632d9
# 1939  bdc11650-6f74-49c4-875e-778aeb7632d9
# 125   1d678440-b4b1-4954-9b39-70afb3ebbcfa
# 1577  1d678440-b4b1-4954-9b39-70afb3ebbcfa
# 1091  1d678440-b4b1-4954-9b39-70afb3ebbcfa
# 2412  4f735188-37c8-473d-ae32-1f7e34ccf892
# 1118  4f735188-37c8-473d-ae32-1f7e34ccf892
# 350   d52d5339-cbdd-43f3-9dfa-a42fd588b9a3
# 1516  d52d5339-cbdd-43f3-9dfa-a42fd588b9a3
# 2138  d52d5339-cbdd-43f3-9dfa-a42fd588b9a3
# 577   f246a5e5-afdb-479c-9aaa-c68beeda7af6
# 1549  f246a5e5-afdb-479c-9aaa-c68beeda7af6
# 2143  f246a5e5-afdb-479c-9aaa-c68beeda7af6
# 1513  55714da8-fcaf-4574-8443-59bfb511a524
# 2098  55714da8-fcaf-4574-8443-59bfb511a524
# 2316  55714da8-fcaf-4574-8443-59bfb511a524
# 955   55714da8-fcaf-4574-8443-59bfb511a524
# ...                                    ...
# 1097  44671792-dc02-4fdd-a5ad-f5f17edaa9d7
# 1350  29dd9a87-5bcc-4774-80c3-7f50d985068b
# 747   29dd9a87-5bcc-4774-80c3-7f50d985068b
# 2007  29dd9a87-5bcc-4774-80c3-7f50d985068b
# 212   2142e1ba-3b40-445c-b8bb-f1f8b1054220
# 797   2142e1ba-3b40-445c-b8bb-f1f8b1054220
# 738   2142e1ba-3b40-445c-b8bb-f1f8b1054220
# 2055  c874a065-c115-4e7d-b0f0-235584fb0e6f
# 1247  c874a065-c115-4e7d-b0f0-235584fb0e6f
# 296   c874a065-c115-4e7d-b0f0-235584fb0e6f
# 2200  c874a065-c115-4e7d-b0f0-235584fb0e6f
# 29    29dd9a87-5bcc-4774-80c3-7f50d985068b
# 118   29dd9a87-5bcc-4774-80c3-7f50d985068b
# 1867  29dd9a87-5bcc-4774-80c3-7f50d985068b
# 1981  03556285-bdbb-4576-a06d-42f71f46ddc5
# 1916  03556285-bdbb-4576-a06d-42f71f46ddc5
# 740   03556285-bdbb-4576-a06d-42f71f46ddc5
# 1482  a09ec676-f887-43dc-bbb3-cf4bbaee9a18
# 901   a09ec676-f887-43dc-bbb3-cf4bbaee9a18
# 1218  a09ec676-f887-43dc-bbb3-cf4bbaee9a18
# 495   25507be1-6a68-4267-bd82-e097d94b359b
# 1784  25507be1-6a68-4267-bd82-e097d94b359b
# 894   25507be1-6a68-4267-bd82-e097d94b359b
# 943   25507be1-6a68-4267-bd82-e097d94b359b
# 197   d52d5339-cbdd-43f3-9dfa-a42fd588b9a3
# 339   d52d5339-cbdd-43f3-9dfa-a42fd588b9a3
# 477   d52d5339-cbdd-43f3-9dfa-a42fd588b9a3
# 397   a7723160-10b7-4277-a309-d8dd95a8ae65
# 688   a7723160-10b7-4277-a309-d8dd95a8ae65
# 2417  a7723160-10b7-4277-a309-d8dd95a8ae65
#
#                                         id  \
# 1989  d25cd731-0cc7-4eaf-b840-7bff9df0993b
# 2108  dd612e6d-4322-4301-90ef-2c53dd24af96
# 1911  c864566b-2367-48d7-8d51-d35e0f1d74e0
# 705   4bb5dc08-56cd-4c61-ac50-f8134b715233
# 2344  f5a902fb-aded-450d-89bd-34b4e25cbd41
# 887   5e5017d9-64bf-4300-b6a4-1edf17d6dd86
# 147   109f5759-3d03-4d82-8118-c579454bc305
# 786   536b6b1a-9489-43b3-ad7e-b3f7dc41d324
# 2195  e69bcfae-7c4e-4c11-b1ad-c7dcc4919aba
# 1471  9c2b51e4-eaeb-439b-8e1b-e0aef078d11b
# 984   68f9dc19-f3e1-4c88-bcce-0b38f61fb4bc
# 2397  fc44c7b0-a6bb-4d5e-9bbb-8468acd47c37
# 167   12e9f5c3-8923-4d36-af34-6e5cea690af8
# 43    055d2eff-e6d4-463f-90a7-c0b701b84b6a
# 1939  cb48ac48-8a89-4464-8868-f24215a5c7f4
# 125   0dac8d11-8ae5-46c6-9f06-ba2597db868c
# 1577  a6bfbd9a-73c0-4ca9-aa60-4b4067735e14
# 1091  73b14147-fe67-4f1e-ae1f-56869bdecad0
# 2412  fe401dd2-089c-4822-8657-4d510d460f38
# 1118  7700786c-0ae8-4901-9560-4ae8942f254d
# 350   26d4830c-3e63-4b9c-ae8b-def90d076332
# 1516  9f9ffb83-7454-403e-a68d-d2fa6f2c889a
# 2138  e11b5291-c229-43a9-99dc-f93d86f9b01f
# 577   3dde8679-dec3-4e40-9a11-f81600f60b36
# 1549  a366961c-eacd-451f-91c6-b79613f85f54
# 2143  e1b11111-de4b-44f6-93f6-63a80398be45
# 1513  9f398b33-1a5a-4a63-814d-9a013a8e57a0
# 2098  dc4d0010-78c1-4efb-b7ba-7812b0f4ce47
# 2316  f3ae52b8-237a-4f12-86d8-d6dca16eb679
# 955   65b456c1-2b85-4666-9bd2-014071ab96d8
# ...                                    ...
# 1097  74251547-1d48-442a-9d8e-46434b957380
# 1350  8e1b4084-b791-4969-bd41-026d1407d289
# 747   500ccf86-2929-48ac-a452-bcb9d03b767f
# 2007  d3b14df1-49a0-490f-af36-22d8fe9bc602
# 212   1813a189-e721-4dcb-a00b-dd832cc4b1d8
# 797   54e7d4be-d510-44e0-85b5-30f23c9b7d33
# 738   4f086577-3575-4b8c-a7c9-e6a05d674367
# 2055  d85050f6-aaf8-4abe-978f-f64f3166a14b
# 1247  830c4a73-bfa7-4e78-a959-825248255eb5
# 296   216425f1-bc32-4592-93f6-c85c2250705d
# 2200  e754ca59-799a-43af-b227-762c9c6617c2
# 29    035c76bd-7367-4fe6-b9f3-1a0b597b85e4
# 118   0c77c3b6-4ded-4962-be5c-44f8920b073d
# 1867  c337377e-39c9-44e0-8af3-b7ea9818a463
# 1981  d0d5daf9-2da6-438d-80b1-6362596fa89c
# 1916  c8bb54dc-e7c5-4182-aae7-ba6076fd3d7e
# 740   4f32f177-b197-4544-a167-aa546ef2c903
# 1482  9ce44b92-d669-4b9a-a78b-c4c1c501d08f
# 901   5fd6311f-06c5-4507-ad37-dd53e2705632
# 1218  80e40bb7-c800-4625-ae65-4b032b9f42c1
# 495   34b2b1ce-5b90-414f-82f2-8483d8bdf76e
# 1784  bb3c3c0a-9def-4349-9829-9adc0b414f36
# 894   5f0f89b1-6cb0-4be3-9b75-be744bb6842a
# 943   643316f8-025b-4536-aa38-574d4556c584
# 197   15d244c5-099d-4dbe-93c2-a1a7adac7357
# 339   25aa17e3-3d1e-4158-b076-3809bc4419b9
# 477   329cc253-d64f-4c83-a62a-fa313fdfa2c9
# 397   2b129c17-863b-4ede-94c9-8a260832d23b
# 688   494e5474-cb8f-4fdb-977a-15c50eb72a61
# 2417  feaf49b5-38a4-4248-a3df-b741099d79e0
#
#                                             rescheduled  \
# 1989                                                NaN
# 2108                                                NaN
# 1911                                                NaN
# 705                                                 NaN
# 2344                                                NaN
# 887                                                 NaN
# 147                                                 NaN
# 786                                                 NaN
# 2195                                                NaN
# 1471                                                NaN
# 984                                                 NaN
# 2397                                                NaN
# 167                                                 NaN
# 43                                                  NaN
# 1939                                                NaN
# 125                                                 NaN
# 1577                                                NaN
# 1091                                                NaN
# 2412                                                NaN
# 1118                                                NaN
# 350                                                 NaN
# 1516                                                NaN
# 2138                                                NaN
# 577                                                 NaN
# 1549                                                NaN
# 2143                                                NaN
# 1513                                                NaN
# 2098                                                NaN
# 2316                                                NaN
# 955                                                 NaN
# ...                                                 ...
# 1097                                                NaN
# 1350                                                NaN
# 747                                                 NaN
# 2007                                                NaN
# 212                                                 NaN
# 797                                                 NaN
# 738                                                 NaN
# 2055                                                NaN
# 1247                                                NaN
# 296                                                 NaN
# 2200                                                NaN
# 29                                                  NaN
# 118                                                 NaN
# 1867  [{'from': '2016-08-31T00:40:00+00:00', 'reason...
# 1981                                                NaN
# 1916                                                NaN
# 740                                                 NaN
# 1482                                                NaN
# 901                                                 NaN
# 1218                                                NaN
# 495                                                 NaN
# 1784                                                NaN
# 894                                                 NaN
# 943                                                 NaN
# 197                                                 NaN
# 339                                                 NaN
# 477                                                 NaN
# 397                                                 NaN
# 688                                                 NaN
# 2417                                                NaN
#
#                       scheduled  status  \
# 1989  2016-04-04T23:05:00+00:00  closed
# 2108  2016-04-06T02:10:00+00:00  closed
# 1911  2016-04-07T01:10:00+00:00  closed
# 705   2016-04-07T20:35:00+00:00  closed
# 2344  2016-04-09T02:15:00+00:00  closed
# 887   2016-04-09T20:05:00+00:00  closed
# 147   2016-04-10T20:05:00+00:00  closed
# 786   2016-04-19T23:10:00+00:00  closed
# 2195  2016-04-20T23:10:00+00:00  closed
# 1471  2016-04-21T16:10:00+00:00  closed
# 984   2016-04-23T00:40:00+00:00  closed
# 2397  2016-04-24T00:10:00+00:00  closed
# 167   2016-04-24T20:10:00+00:00  closed
# 43    2016-05-03T23:10:00+00:00  closed
# 1939  2016-05-04T23:10:00+00:00  closed
# 125   2016-05-06T23:07:00+00:00  closed
# 1577  2016-05-07T17:07:00+00:00  closed
# 1091  2016-05-08T17:07:00+00:00  closed
# 2412  2016-05-19T02:05:00+00:00  closed
# 1118  2016-05-20T02:05:00+00:00  closed
# 350   2016-05-21T02:40:00+00:00  closed
# 1516  2016-05-22T02:10:00+00:00  closed
# 2138  2016-05-22T20:40:00+00:00  closed
# 577   2016-05-27T23:10:00+00:00  closed
# 1549  2016-05-28T23:15:00+00:00  closed
# 2143  2016-05-30T00:00:00+00:00  closed
# 1513  2016-05-30T21:05:00+00:00  closed
# 2098  2016-06-01T00:05:00+00:00  closed
# 2316  2016-06-02T00:05:00+00:00  closed
# 955   2016-06-02T18:20:00+00:00  closed
# ...                         ...     ...
# 1097  2016-07-25T00:08:00+00:00  closed
# 1350  2016-08-03T00:40:00+00:00  closed
# 747   2016-08-04T00:40:00+00:00  closed
# 2007  2016-08-05T00:40:00+00:00  closed
# 212   2016-08-16T23:05:00+00:00  closed
# 797   2016-08-17T23:05:00+00:00  closed
# 738   2016-08-18T23:05:00+00:00  closed
# 2055  2016-08-19T23:10:00+00:00  closed
# 1247  2016-08-20T23:10:00+00:00  closed
# 296   2016-08-21T17:10:00+00:00  closed
# 2200  2016-08-22T16:35:00+00:00  closed
# 29    2016-08-30T00:40:00+00:00  closed
# 118   2016-08-31T19:10:00+00:00  closed
# 1867  2016-09-01T00:10:00+00:00  closed
# 1981  2016-09-09T23:10:00+00:00  closed
# 1916  2016-09-10T23:10:00+00:00  closed
# 740   2016-09-11T17:10:00+00:00  closed
# 1482  2016-09-12T23:05:00+00:00  closed
# 901   2016-09-13T23:05:00+00:00  closed
# 1218  2016-09-14T20:05:00+00:00  closed
# 495   2016-09-16T01:40:00+00:00  closed
# 1784  2016-09-17T01:40:00+00:00  closed
# 894   2016-09-18T00:10:00+00:00  closed
# 943   2016-09-18T20:10:00+00:00  closed
# 197   2016-09-28T02:10:00+00:00  closed
# 339   2016-09-29T02:10:00+00:00  closed
# 477   2016-09-30T01:10:00+00:00  closed
# 397   2016-10-01T02:15:00+00:00  closed
# 688   2016-10-01T20:05:00+00:00  closed
# 2417  2016-10-02T19:05:00+00:00  closed
#
#                                                   venue
# 1989  {'name': 'PETCO Park', 'market': 'San Diego', ...
# 2108  {'name': 'PETCO Park', 'market': 'San Diego', ...
# 1911  {'name': 'PETCO Park', 'market': 'San Diego', ...
# 705   {'name': 'AT&T Park', 'market': 'San Francisco...
# 2344  {'name': 'AT&T Park', 'market': 'San Francisco...
# 887   {'name': 'AT&T Park', 'market': 'San Francisco...
# 147   {'name': 'AT&T Park', 'market': 'San Francisco...
# 786   {'name': 'Turner Field', 'capacity': 49586, 's...
# 2195  {'name': 'Turner Field', 'capacity': 49586, 's...
# 1471  {'name': 'Turner Field', 'capacity': 49586, 's...
# 984   {'name': 'Coors Field', 'market': 'Colorado', ...
# 2397  {'name': 'Coors Field', 'market': 'Colorado', ...
# 167   {'name': 'Coors Field', 'market': 'Colorado', ...
# 43    {'name': 'Tropicana Field', 'market': 'Tampa B...
# 1939  {'name': 'Tropicana Field', 'market': 'Tampa B...
# 125   {'name': 'Rogers Centre', 'market': 'Toronto',...
# 1577  {'name': 'Rogers Centre', 'market': 'Toronto',...
# 1091  {'name': 'Rogers Centre', 'market': 'Toronto',...
# 2412  {'name': 'Angel Stadium of Anaheim', 'market':...
# 1118  {'name': 'Angel Stadium of Anaheim', 'market':...
# 350   {'name': 'PETCO Park', 'market': 'San Diego', ...
# 1516  {'name': 'PETCO Park', 'market': 'San Diego', ...
# 2138  {'name': 'PETCO Park', 'market': 'San Diego', ...
# 577   {'name': 'Citi Field', 'market': 'New York', '...
# 1549  {'name': 'Citi Field', 'market': 'New York', '...
# 2143  {'name': 'Citi Field', 'market': 'New York', '...
# 1513  {'name': 'Wrigley Field', 'market': 'Chicago',...
# 2098  {'name': 'Wrigley Field', 'market': 'Chicago',...
# 2316  {'name': 'Wrigley Field', 'market': 'Chicago',...
# 955   {'name': 'Wrigley Field', 'market': 'Chicago',...
# ...                                                 ...
# 1097  {'name': 'Busch Stadium', 'market': 'St. Louis...
# 1350  {'name': 'Coors Field', 'market': 'Colorado', ...
# 747   {'name': 'Coors Field', 'market': 'Colorado', ...
# 2007  {'name': 'Coors Field', 'market': 'Colorado', ...
# 212   {'name': 'Citizens Bank Park', 'market': 'Phil...
# 797   {'name': 'Citizens Bank Park', 'market': 'Phil...
# 738   {'name': 'Citizens Bank Park', 'market': 'Phil...
# 2055  {'name': 'Great American Ball Park', 'market':...
# 1247  {'name': 'Great American Ball Park', 'market':...
# 296   {'name': 'Great American Ball Park', 'market':...
# 2200  {'name': 'Great American Ball Park', 'market':...
# 29    {'name': 'Coors Field', 'market': 'Colorado', ...
# 118   {'name': 'Coors Field', 'market': 'Colorado', ...
# 1867  {'name': 'Coors Field', 'market': 'Colorado', ...
# 1981  {'name': 'Marlins Park', 'market': 'Miami', 'c...
# 1916  {'name': 'Marlins Park', 'market': 'Miami', 'c...
# 740   {'name': 'Marlins Park', 'market': 'Miami', 'c...
# 1482  {'name': 'Yankee Stadium', 'market': 'New York...
# 901   {'name': 'Yankee Stadium', 'market': 'New York...
# 1218  {'name': 'Yankee Stadium', 'market': 'New York...
# 495   {'name': 'Chase Field', 'market': 'Arizona', '...
# 1784  {'name': 'Chase Field', 'market': 'Arizona', '...
# 894   {'name': 'Chase Field', 'market': 'Arizona', '...
# 943   {'name': 'Chase Field', 'market': 'Arizona', '...
# 197   {'name': 'PETCO Park', 'market': 'San Diego', ...
# 339   {'name': 'PETCO Park', 'market': 'San Diego', ...
# 477   {'name': 'PETCO Park', 'market': 'San Diego', ...
# 397   {'name': 'AT&T Park', 'market': 'San Francisco...
# 688   {'name': 'AT&T Park', 'market': 'San Francisco...
# 2417  {'name': 'AT&T Park', 'market': 'San Francisco...
#
# [81 rows x 15 columns]

# %%
pd.DataFrame(dodgers_games['scheduled'])
# Out:
#                       scheduled
# 29    2016-08-30T00:40:00+00:00
# 43    2016-05-03T23:10:00+00:00
# 64    2016-06-27T16:35:00+00:00
# 118   2016-08-31T19:10:00+00:00
# 125   2016-05-06T23:07:00+00:00
# 147   2016-04-10T20:05:00+00:00
# 167   2016-04-24T20:10:00+00:00
# 197   2016-09-28T02:10:00+00:00
# 212   2016-08-16T23:05:00+00:00
# 261   2016-06-13T00:30:00+00:00
# 284   2016-07-17T00:10:00+00:00
# 288   2016-06-15T19:40:00+00:00
# 296   2016-08-21T17:10:00+00:00
# 339   2016-09-29T02:10:00+00:00
# 350   2016-05-21T02:40:00+00:00
# 397   2016-10-01T02:15:00+00:00
# 471   2016-06-30T00:10:00+00:00
# 477   2016-09-30T01:10:00+00:00
# 495   2016-09-16T01:40:00+00:00
# 497   2016-06-11T23:15:00+00:00
# 511   2016-06-11T02:15:00+00:00
# 577   2016-05-27T23:10:00+00:00
# 688   2016-10-01T20:05:00+00:00
# 705   2016-04-07T20:35:00+00:00
# 738   2016-08-18T23:05:00+00:00
# 740   2016-09-11T17:10:00+00:00
# 747   2016-08-04T00:40:00+00:00
# 786   2016-04-19T23:10:00+00:00
# 797   2016-08-17T23:05:00+00:00
# 818   2016-07-20T23:05:00+00:00
# ...                         ...
# 1471  2016-04-21T16:10:00+00:00
# 1482  2016-09-12T23:05:00+00:00
# 1513  2016-05-30T21:05:00+00:00
# 1516  2016-05-22T02:10:00+00:00
# 1549  2016-05-28T23:15:00+00:00
# 1577  2016-05-07T17:07:00+00:00
# 1587  2016-07-17T20:10:00+00:00
# 1598  2016-07-23T00:15:00+00:00
# 1630  2016-07-16T01:40:00+00:00
# 1784  2016-09-17T01:40:00+00:00
# 1867  2016-09-01T00:10:00+00:00
# 1911  2016-04-07T01:10:00+00:00
# 1916  2016-09-10T23:10:00+00:00
# 1939  2016-05-04T23:10:00+00:00
# 1959  2016-06-14T01:40:00+00:00
# 1981  2016-09-09T23:10:00+00:00
# 1989  2016-04-04T23:05:00+00:00
# 2007  2016-08-05T00:40:00+00:00
# 2055  2016-08-19T23:10:00+00:00
# 2098  2016-06-01T00:05:00+00:00
# 2108  2016-04-06T02:10:00+00:00
# 2138  2016-05-22T20:40:00+00:00
# 2143  2016-05-30T00:00:00+00:00
# 2195  2016-04-20T23:10:00+00:00
# 2200  2016-08-22T16:35:00+00:00
# 2316  2016-06-02T00:05:00+00:00
# 2344  2016-04-09T02:15:00+00:00
# 2397  2016-04-24T00:10:00+00:00
# 2412  2016-05-19T02:05:00+00:00
# 2417  2016-10-02T19:05:00+00:00
#
# [81 rows x 1 columns]

# %%
seven_hours_earlier = pd.to_timedelta(dodgers_games['scheduled']) - pd.Timedelta('7 hours')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/tslibs/timedeltas.pyx in pandas._libs.tslibs.timedeltas.array_to_timedelta64()
#
# pandas/_libs/tslibs/timedeltas.pyx in pandas._libs.tslibs.timedeltas.parse_timedelta_string()
#
# ValueError: only leading negative signs are allowed
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-222-cc9c7e4e62c1> in <module>()
# ----> 1 seven_hours_earlier = pd.to_timedelta(dodgers_games['scheduled']) - pd.Timedelta('7 hours')
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/tools/timedeltas.py in to_timedelta(arg, unit, box, errors)
#      81         from pandas import Series
#      82         values = _convert_listlike(arg._values, unit=unit,
# ---> 83                                    box=False, errors=errors)
#      84         return Series(values, index=arg.index, name=arg.name)
#      85     elif isinstance(arg, ABCIndexClass):
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/tools/timedeltas.py in _convert_listlike(arg, unit, box, errors, name)
#     173         try:
#     174             value = array_to_timedelta64(_ensure_object(arg),
# --> 175                                          unit=unit, errors=errors)
#     176             value = value.astype('timedelta64[ns]', copy=False)
#     177         except ValueError:
#
# pandas/_libs/tslibs/timedeltas.pyx in pandas._libs.tslibs.timedeltas.array_to_timedelta64()
#
# pandas/_libs/tslibs/timedeltas.pyx in pandas._libs.tslibs.timedeltas.array_to_timedelta64()
#
# pandas/_libs/tslibs/timedeltas.pyx in pandas._libs.tslibs.timedeltas.array_to_timedelta64()
#
# pandas/_libs/tslibs/timedeltas.pyx in pandas._libs.tslibs.timedeltas.convert_to_timedelta64()
#
# pandas/_libs/tslibs/timedeltas.pyx in pandas._libs.tslibs.timedeltas.parse_timedelta_string()
#
# ValueError: only leading negative signs are allowed

# %%
seven_hours_earlier
# Out:
# datetime.datetime(2018, 9, 11, 7, 29, 24, 596063)

# %%
home_2017_ids = df_2017['home_team'].drop_duplicates().sort_values()
home_2017_ids
# Out:
# 7       03556285-bdbb-4576-a06d-42f71f46ddc5
# 6       12079497-e414-450a-8bf2-29f91de646bf
# 17      1d678440-b4b1-4954-9b39-70afb3ebbcfa
# 27      2142e1ba-3b40-445c-b8bb-f1f8b1054220
# 15      25507be1-6a68-4267-bd82-e097d94b359b
# 14      27a59d3b-ff7c-48ea-b016-4798f560f5e1
# 3       29dd9a87-5bcc-4774-80c3-7f50d985068b
# 1947    3bbb3b39-b5cb-4fc9-bd22-522521f0f329
# 22      43a39081-52b4-4f93-ad29-da7f329ea960
# 40      44671792-dc02-4fdd-a5ad-f5f17edaa9d7
# 42      47f490cd-2f58-4ef7-9dfd-2ad6ba6c1ae8
# 102     481dfe7e-5dab-46ab-a49f-9dcc2b6e2cfd
# 10      4f735188-37c8-473d-ae32-1f7e34ccf892
# 1       55714da8-fcaf-4574-8443-59bfb511a524
# 9       575c19b7-4052-41c2-9f0a-1c5813d02f99
# 13      75729d34-bca7-4a0f-b3df-6f26c6ad3719
# 2       80715d0d-0d2a-450f-a970-1b9a3b18c7e7
# 76      833a51a9-0d84-410f-bd77-da08c3e5e26e
# 5       93941372-eb4c-4c40-aced-fe3267174393
# 66      a09ec676-f887-43dc-bbb3-cf4bbaee9a18
# 18      a7723160-10b7-4277-a309-d8dd95a8ae65
# 0       aa34e0ed-f342-4ec6-b774-c79b47b60e2d
# 23      bdc11650-6f74-49c4-875e-778aeb7632d9
# 4       c874a065-c115-4e7d-b0f0-235584fb0e6f
# 8       d52d5339-cbdd-43f3-9dfa-a42fd588b9a3
# 26      d89bed32-3aee-4407-99e3-4103641b999a
# 59      d99f919b-1534-4516-8e8a-9cd106c6d8cd
# 29      dcfd5266-00ce-442c-bc09-264cd20cf455
# 28      eb21dadd-8f10-4095-8bf3-dfb3b779f107
# 12      ef64da7f-cfaf-4300-87b0-9313386b977c
# 107     f246a5e5-afdb-479c-9aaa-c68beeda7af6
# Name: home_team, dtype: object

# %%
#def create_request_string(id_list, api_key):
#    """accepts list of team ids and sportradar api key, sends HTTP requests, 
#       collects team profiles and writes results to json file"""
#    for id in id_list:
#        conn = http.client.HTTPSConnection("api.sportradar.us")
#        request_str = "/mlb/trial/v6.5/en/teams/" + id + "/profile.json?api_key=" + api_key
#        conn.request("GET", request_str)
#        res = conn.getresponse()
#        data = res.read()
#        
#        json_result = json.loads(data.decode("utf-8"))
#        fname = json_result['name']
#        fname = fname.replace(" ", "_")
#         
#        out_str = fname + "_profile.json"
#        # write results to json output file
#        with open(out_str, 'w') as outfile:
#            json.dump(json_result, outfile)
#            
#        conn.close()
#        time.sleep(2)
#        
#        print(request_str)
#        print(out_str)
#
#create_request_string(home_2017_ids, api_key)

# %%
# open json file and use list comprehension to extract list of entries
path = 'Dodgers_profile.json'
profile = [json.loads(line) for line in open(path)]

# %%
#pitchers = [plyr['first_name'] for plyr in profile[0]['players'] if plyr['primary_position']='P']
df_players = pd.DataFrame(profile[0]['players'])

df_starting_pithers = df_players[(df_players['primary_position']=='SP') & (df_players['status']=='A')]

# %%
df_starting_pithers[['first_name', 'last_name', 'id']]
# Out:
#    first_name last_name                                    id
# 23     Walker   Buehler  3703319e-ec2e-4db7-9e86-59589e233f95
# 31    Richard      Hill  d9936d13-479d-43e0-a845-c74e17046622
# 34    Clayton   Kershaw  d3351c6e-12cf-4ab5-b651-ad23d49c4245
# 39   Hyun-Jin       Ryu  01d71849-6f8e-4394-ae98-155bd61c68e8
# 45     Robert      Wood  956280da-4ce3-41db-8830-e04ef52bb0f2

# %%
request_plyr_proile = "/mlb/trial/v6.5/en/players/d3351c6e-12cf-4ab5-b651-ad23d49c4245/profile.json?api_key=" + my_api_key

conn = http.client.HTTPSConnection("api.sportradar.us")

conn.request("GET", request_plyr_proile)

res = conn.getresponse()

json_player_data = json.loads(res.read().decode("utf-8"))

# %%
# write results to json output file
with open('Kershaw_Clayton_profile.json', 'w') as outfile:
    json.dump(json_player_data, outfile)

# %%
# open json file and use list comprehension to extract list of entries
path = 'Kershaw_Clayton_profile.json'
pitcher_profile = [json.loads(line) for line in open(path)]
df_pprofile = pd.DataFrame(pitcher_profile[0])

# %%
df_plyr_seasons = pd.DataFrame(df_pprofile['player']['seasons'])
df_plyr_totals = df_plyr_seasons[(df_plyr_seasons['type']=='REG') & (df_plyr_seasons['year']==2017)]

# %%
df_plyr_totals['totals'].apply(pd.Series)['statistics'].apply(pd.Series)['pitching'].apply(pd.Series)['starters'].apply(pd.Series)['games'].apply(pd.Series)
# Out:
#    start  play  finish  svo  qstart  shutout  complete  win  loss  save  hold  \
# 2     27    27       0    0      20        0         1   18     4     0     0
#
#    blown_save  team_win  team_loss
# 2           0        23          4

# %%
conn = http.client.HTTPSConnection("api.sportradar.us")
conn.request("GET", "/mlb/trial/v6.5/en/games/03d080ba-c18d-4587-9f9c-79a39ee9c00e/boxscore.json?api_key=5jm59pm84khcx588a5v2st8b")

res = conn.getresponse()
boxscores = res.read()

print(boxscores.decode("utf-8"))
# Out:
# {"game":{"id":"03d080ba-c18d-4587-9f9c-79a39ee9c00e","status":"closed","coverage":"full","game_number":1,"day_night":"N","scheduled":"2017-10-17T00:08:00+00:00","home_team":"a09ec676-f887-43dc-bbb3-cf4bbaee9a18","away_team":"eb21dadd-8f10-4095-8bf3-dfb3b779f107","ps_round":"ALCS","ps_game":"3","attendance":49373,"duration":"3:25","venue":{"name":"Yankee Stadium","market":"New York","capacity":49642,"surface":"grass","address":"One East 161st Street","city":"Bronx","state":"NY","zip":"10451","country":"USA","id":"706e9828-6687-4ac8-a409-3fb972e8bae9"},"broadcast":{"network":"FOX / FS1"},"final":{"inning":9,"inning_half":"T"},"home":{"name":"Yankees","market":"New York","abbr":"NYY","id":"a09ec676-f887-43dc-bbb3-cf4bbaee9a18","runs":8,"hits":7,"errors":1,"win":4,"loss":4,"probable_pitcher":{"preferred_name":"CC","first_name":"Carsten","last_name":"Sabathia","jersey_number":"52","id":"34c78a46-c798-4545-a05c-f9b693635e9b","win":0,"loss":0,"era":3.724},"starting_pitcher":{"preferred_name":"CC","first_name":"Carsten","last_name":"Sabathia","jersey_number":"52","id":"34c78a46-c798-4545-a05c-f9b693635e9b","win":0,"loss":0,"era":3.724},"scoring":[{"number":1,"sequence":1,"runs":0,"type":"inning"},{"number":2,"sequence":2,"runs":3,"type":"inning"},{"number":3,"sequence":3,"runs":0,"type":"inning"},{"number":4,"sequence":4,"runs":5,"type":"inning"},{"number":5,"sequence":5,"runs":0,"type":"inning"},{"number":6,"sequence":6,"runs":0,"type":"inning"},{"number":7,"sequence":7,"runs":0,"type":"inning"},{"number":8,"sequence":8,"runs":0,"type":"inning"},{"number":9,"sequence":9,"runs":"X","type":"inning"}],"events":[{"hitter_id":"c401dbb6-2208-45f4-9947-db11881daf4f","pitcher_id":"ff772241-8fdd-488c-a81e-49b44ce600fc","inning":2,"inning_half":"B","type":"pitch","hitter_outcome":"aHR","id":"e0ca2974-2dcf-4382-88ee-077631e5d3da","runners":[{"starting_base":0,"first_name":"Todd","last_name":"Frazier","preferred_name":"Todd","jersey_number":"29","id":"c401dbb6-2208-45f4-9947-db11881daf4f"},{"starting_base":1,"first_name":"Aaron","last_name":"Hicks","preferred_name":"Aaron","jersey_number":"31","id":"4ea710f8-d2b5-42d4-ba58-5cb6e4517dfa"},{"starting_base":2,"first_name":"Starlin","last_name":"Castro","preferred_name":"Starlin","jersey_number":"14","id":"5bf2b7fe-19db-41e7-927a-1898dd249be4"}]},{"hitter_id":"c43693d8-1c11-45c9-baa0-5fe6a517282c","pitcher_id":"ff772241-8fdd-488c-a81e-49b44ce600fc","inning":4,"inning_half":"B","type":"pitch","hitter_outcome":"aS","id":"2aaa7944-fd7c-499f-9e08-464f4efb4388","runners":[{"starting_base":3,"first_name":"Gregory","last_name":"Bird","preferred_name":"Greg","jersey_number":"33","id":"1881391a-a184-4410-af54-13007f989e74"}]},{"hitter_id":"86f7390e-61bd-4556-8325-a6705c7f693b","pitcher_id":"a788bab0-4d9b-4e90-806c-80736d0221c4","inning":4,"inning_half":"B","type":"pitch","hitter_outcome":"bB","id":"1ff721b9-135d-489f-8d59-c7898c3b6220","runners":[{"starting_base":3,"first_name":"Todd","last_name":"Frazier","preferred_name":"Todd","jersey_number":"29","id":"c401dbb6-2208-45f4-9947-db11881daf4f"}]},{"hitter_id":"86f7390e-61bd-4556-8325-a6705c7f693b","pitcher_id":"a788bab0-4d9b-4e90-806c-80736d0221c4","inning":4,"inning_half":"B","type":"pitch","hitter_outcome":"aHR","id":"673d3a3b-a573-495f-a33b-11a036511778","runners":[{"starting_base":0,"first_name":"Aaron","last_name":"Judge","preferred_name":"Aaron","jersey_number":"99","id":"86f7390e-61bd-4556-8325-a6705c7f693b"},{"starting_base":2,"first_name":"Brett","last_name":"Gardner","preferred_name":"Brett","jersey_number":"11","id":"32362986-6bba-443c-927d-8b87153caf0d"},{"starting_base":3,"first_name":"Chase","last_name":"Headley","preferred_name":"Chase","jersey_number":"12","id":"c43693d8-1c11-45c9-baa0-5fe6a517282c"}]}]},"away":{"name":"Astros","market":"Houston","abbr":"HOU","id":"eb21dadd-8f10-4095-8bf3-dfb3b779f107","runs":1,"hits":4,"errors":0,"win":5,"loss":1,"probable_pitcher":{"preferred_name":"Charlie","first_name":"Charles","last_name":"Morton","jers ...

# %%
json2_data = json.loads(boxscores)
data1 = json_normalize(json2_data)
ea_data = [i for i in data1]
ea_data
# Out:
# ['_comment',
#  'game.attendance',
#  'game.away.abbr',
#  'game.away.errors',
#  'game.away.events',
#  'game.away.hits',
#  'game.away.id',
#  'game.away.loss',
#  'game.away.market',
#  'game.away.name',
#  'game.away.probable_pitcher.era',
#  'game.away.probable_pitcher.first_name',
#  'game.away.probable_pitcher.id',
#  'game.away.probable_pitcher.jersey_number',
#  'game.away.probable_pitcher.last_name',
#  'game.away.probable_pitcher.loss',
#  'game.away.probable_pitcher.preferred_name',
#  'game.away.probable_pitcher.win',
#  'game.away.runs',
#  'game.away.scoring',
#  'game.away.starting_pitcher.era',
#  'game.away.starting_pitcher.first_name',
#  'game.away.starting_pitcher.id',
#  'game.away.starting_pitcher.jersey_number',
#  'game.away.starting_pitcher.last_name',
#  'game.away.starting_pitcher.loss',
#  'game.away.starting_pitcher.preferred_name',
#  'game.away.starting_pitcher.win',
#  'game.away.win',
#  'game.away_team',
#  'game.broadcast.network',
#  'game.coverage',
#  'game.day_night',
#  'game.duration',
#  'game.final.inning',
#  'game.final.inning_half',
#  'game.game_number',
#  'game.home.abbr',
#  'game.home.errors',
#  'game.home.events',
#  'game.home.hits',
#  'game.home.id',
#  'game.home.loss',
#  'game.home.market',
#  'game.home.name',
#  'game.home.probable_pitcher.era',
#  'game.home.probable_pitcher.first_name',
#  'game.home.probable_pitcher.id',
#  'game.home.probable_pitcher.jersey_number',
#  'game.home.probable_pitcher.last_name',
#  'game.home.probable_pitcher.loss',
#  'game.home.probable_pitcher.preferred_name',
#  'game.home.probable_pitcher.win',
#  'game.home.runs',
#  'game.home.scoring',
#  'game.home.starting_pitcher.era',
#  'game.home.starting_pitcher.first_name',
#  'game.home.starting_pitcher.id',
#  'game.home.starting_pitcher.jersey_number',
#  'game.home.starting_pitcher.last_name',
#  'game.home.starting_pitcher.loss',
#  'game.home.starting_pitcher.preferred_name',
#  'game.home.starting_pitcher.win',
#  'game.home.win',
#  'game.home_team',
#  'game.id',
#  'game.pitching.loss.blown_save',
#  'game.pitching.loss.first_name',
#  'game.pitching.loss.hold',
#  'game.pitching.loss.id',
#  'game.pitching.loss.jersey_number',
#  'game.pitching.loss.last_name',
#  'game.pitching.loss.loss',
#  'game.pitching.loss.position',
#  'game.pitching.loss.preferred_name',
#  'game.pitching.loss.primary_position',
#  'game.pitching.loss.save',
#  'game.pitching.loss.status',
#  'game.pitching.loss.win',
#  'game.pitching.win.blown_save',
#  'game.pitching.win.first_name',
#  'game.pitching.win.hold',
#  'game.pitching.win.id',
#  'game.pitching.win.jersey_number',
#  'game.pitching.win.last_name',
#  'game.pitching.win.loss',
#  'game.pitching.win.position',
#  'game.pitching.win.preferred_name',
#  'game.pitching.win.primary_position',
#  'game.pitching.win.save',
#  'game.pitching.win.status',
#  'game.pitching.win.win',
#  'game.ps_game',
#  'game.ps_round',
#  'game.scheduled',
#  'game.status',
#  'game.venue.address',
#  'game.venue.capacity',
#  'game.venue.city',
#  'game.venue.country',
#  'game.venue.id',
#  'game.venue.market',
#  'game.venue.name',
#  'game.venue.state',
#  'game.venue.surface',
#  'game.venue.zip']

# %%
data1[['game.away.starting_pitcher.first_name', 'game.away.starting_pitcher.id','game.away.starting_pitcher.jersey_number', 'game.away.starting_pitcher.last_name', 'game.home.starting_pitcher.first_name', 'game.home.starting_pitcher.id','game.home.starting_pitcher.jersey_number', 'game.home.starting_pitcher.last_name']]
# Out:
#   game.away.starting_pitcher.first_name         game.away.starting_pitcher.id  \
# 0                               Charles  ff772241-8fdd-488c-a81e-49b44ce600fc
#
#   game.away.starting_pitcher.jersey_number  \
# 0                                       50
#
#   game.away.starting_pitcher.last_name game.home.starting_pitcher.first_name  \
# 0                               Morton                               Carsten
#
#           game.home.starting_pitcher.id  \
# 0  34c78a46-c798-4545-a05c-f9b693635e9b
#
#   game.home.starting_pitcher.jersey_number  \
# 0                                       52
#
#   game.home.starting_pitcher.last_name
# 0                             Sabathia

# %%
conn = http.client.HTTPSConnection("api.sportradar.us")

conn.request("GET", "/mlb/trial/v6.5/en/games/03d080ba-c18d-4587-9f9c-79a39ee9c00e/pbp.json?api_key=5jm59pm84khcx588a5v2st8b")

res = conn.getresponse()
pbp = res.read()

#print(pbp.decode("utf-8"))

# %%
json3_data = json.loads(pbp)
data3 = json_normalize(json3_data)
innings = json3_data['game']['innings']
inning_data = pd.DataFrame(innings)
halfs = [h for h in inning_data['halfs']]
halfs_data = pd.DataFrame(halfs)
halfs_data
# Out:
#                                                    0  \
# 0  {'half': 'T', 'events': [{'lineup': {'player_i...
# 1  {'half': 'T', 'events': [{'at_bat': {'hitter_i...
# 2  {'half': 'T', 'events': [{'at_bat': {'hitter_i...
# 3  {'half': 'T', 'events': [{'at_bat': {'hitter_i...
# 4  {'half': 'T', 'events': [{'at_bat': {'hitter_i...
# 5  {'half': 'T', 'events': [{'at_bat': {'hitter_i...
# 6  {'half': 'T', 'events': [{'at_bat': {'hitter_i...
# 7  {'half': 'T', 'events': [{'lineup': {'player_i...
# 8  {'half': 'T', 'events': [{'at_bat': {'hitter_i...
# 9  {'half': 'T', 'events': [{'lineup': {'player_i...
#
#                                                    1
# 0  {'half': 'B', 'events': [{'lineup': {'player_i...
# 1  {'half': 'B', 'events': [{'at_bat': {'hitter_i...
# 2  {'half': 'B', 'events': [{'at_bat': {'hitter_i...
# 3  {'half': 'B', 'events': [{'at_bat': {'hitter_i...
# 4  {'half': 'B', 'events': [{'at_bat': {'hitter_i...
# 5  {'half': 'B', 'events': [{'lineup': {'player_i...
# 6  {'half': 'B', 'events': [{'at_bat': {'hitter_i...
# 7  {'half': 'B', 'events': [{'at_bat': {'hitter_i...
# 8  {'half': 'B', 'events': [{'at_bat': {'hitter_i...
# 9                        {'half': 'B', 'events': []}
