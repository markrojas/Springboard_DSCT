# %%
import os
import json
import numpy as np
import pandas as pd
from pandas.io.json import json_normalize
import time
from datetime import datetime, timedelta
from dateutil import tz

import matplotlib.pyplot as plt

#import warnings
#warnings.filterwarnings('ignore')

# %%
# base path with subfolders for each pitcher of interest
basepath = 'data/pbp_files'

# list of years to clean and merge play-by-play data
years = ['2016', '2017']

# list of pitchers of interest
pitchers = ['aaron_nola', 'carlos_carrasco', 'carlos_martinez', 'chris_archer', 'chris_sale', 
            'clayton_kershaw', 'corey_kluber', 'dallas_keuchel', 'david_price', 'gerrit_cole',
            'jacob_degrom', 'jake_arrieta', 'jose_quintana', 'marcus_stroman', 'justin_verlander', 
            'max_scherzer', 'michael_fulmer', 'stephen_strasburg', 'yu_darvish', 'zack_greinke']

# %%
def convert_dtypes(df, cols_list=[]):
    """
    converts numerical or object data types to dtype
    returns dataframe with converted data types
    """
    for col in cols_list:
        if col in df.columns:
            if df[col].dtype == 'int64' or df[col].dtype == 'float64':
                df[col] = df[col].astype(np.int8)
            elif df[col].dtype == 'object':
                df[col] = df[col].astype('category')
    return df

# %%
def merge_dfs(basepath, years, pitchers, use_cols=[]):
    """
    iterate through list of pitchers for each year in list to open play-by-play file
    then call clean_dfs() to merge de-nest and merge play-by-play data into a single csv
    
    Note: some pitchers pitched during a double-header (two games on same day) so some 
          play-by-play files are skipped if pitcher of interest did not pitch the game
    
    returns true if completed without errors 
    """
    # path to pitcher_ids.csv file
    pitcher_ids_path = 'data/pitcher_logs/pitcher_ids.csv'
    # open pitcher_ids.csv file, set 'id' as index
    df_pitcher_ids = pd.read_csv(pitcher_ids_path, index_col='id')
    
    filelist = []
    
    for year in years:
        for pitcher in pitchers:         
            file_path = basepath + '/' + year + '/merged_by_player/' + pitcher + '_' + year + '_merged_games.csv'
            f_name, l_name = pitcher.split(sep='_')
            filelist.append(file_path)
    
    first_file = filelist.pop(0)
    if len(use_cols)==0:
        df_first = pd.read_csv(first_file)
    else:
        df_first = pd.read_csv(first_file, usecols=use_cols)
    
    ## compare memory usage of dataframe BEFORE and AFTER converting data types ##
    # store total memory usage and number of files
    tot_orig_mem = tot_new_mem = tot_num_files = 0
    # list of columns with data types that should be converted, if present in dataframe
    list_cnvrt_cols = ['half', 'inning', 'pitcher.hitter_hand', 'hit_type', 'pitcher.pitcher_hand', 
                       'outcome_id', 'count.balls', 'count.outs', 'count.strikes', 'pitcher.pitch_type', 
                       'count.pitch_count', 'pitcher.pitch_speed']
    
    # check memory usage of dataframe BEFORE converting dtypes
    original_mem = round(sum((df_first.memory_usage(deep=True)/1024)/1024), 2)
    tot_orig_mem += original_mem
    # convert datatypes
    df_merged = convert_dtypes(df_first, list_cnvrt_cols)
    # check memory usage of dataframe AFTER converting dtypes and compute difference
    new_mem = round(sum((df_merged.memory_usage(deep=True)/1024)/1024), 2)
    tot_new_mem += new_mem
    diff_mem = round(original_mem - new_mem,2)
    
    print("Memory usage BEFORE converting data types: {} mb".format(original_mem))
    print("Memory usage AFTER converting data types: {} mb".format(new_mem))
    print("Memory usage recovered: {} mb".format(diff_mem))
    print("file: ", first_file, '\n')
    
    for file in filelist:
        if len(use_cols)==0:
            # open merged_games.csv file for each player
            df_temp = pd.read_csv(file)
            
            # check memory usage of dataframe BEFORE converting dtypes
            original_mem = round(sum((df_temp.memory_usage(deep=True)/1024)/1024), 2)
            tot_orig_mem += original_mem
            # convert datatypes
            df_temp_cnvrt = convert_dtypes(df_temp, list_cnvrt_cols)
            # check memory usage of dataframe AFTER converting dtypes and compute difference
            new_mem = round(sum((df_temp_cnvrt.memory_usage(deep=True)/1024)/1024), 2)
            tot_new_mem += new_mem
            diff_mem = round(original_mem - new_mem,2)
        else:
            # open merged_games.csv file for each player
            df_temp = pd.read_csv(file, usecols=use_cols)
            
            # check memory usage of dataframe BEFORE converting dtypes
            original_mem = round(sum((df_temp.memory_usage(deep=True)/1024)/1024), 2)
            tot_orig_mem += original_mem
            # convert datatypes
            df_temp_cnvrt = convert_dtypes(df_temp, list_cnvrt_cols)
            # check memory usage of dataframe AFTER converting dtypes and compute difference
            new_mem = round(sum((df_temp_cnvrt.memory_usage(deep=True)/1024)/1024), 2)
            tot_new_mem += new_mem
            diff_mem = round(original_mem - new_mem,2)
        
        print("Memory usage BEFORE converting data types: {} mb".format(original_mem))
        print("Memory usage AFTER converting data types: {} mb".format(new_mem))
        print("Memory usage recovered: {} mb".format(diff_mem))
        print("file: ", file, '\n')
            
        df_merged = pd.concat([df_merged, df_temp_cnvrt], ignore_index=True, sort=False)
    
    tot_diff_mem = round(tot_orig_mem - tot_new_mem, 2)
    
    print("\n\n\tTotal memory usage BEFORE converting data types: {} mb".format(round(tot_orig_mem,2)))
    print("\tTotal memory usage AFTER converting data types: {} mb".format(round(tot_new_mem,2)))
    print("\tTotal Memory usage recovered: {} mb\n\n".format(tot_diff_mem))
    
    return df_merged

# %%
cols_list = ['date', 'half', 'inning', 'count.pitch_count', 'count.balls', 'count.strikes', 'count.outs', 
             'pitcher.hitter_hand', 'pitcher.first_name', 'pitcher.last_name', 'pitcher_id', 
             'pitcher.pitch_count', 'pitcher.pitch_speed', 'pitcher.pitch_type', 'pitcher.pitch_type', 
             'pitcher.pitch_zone', 'pitcher.pitcher_hand', 'outcome_id']

# call to make/merge play-by-play data into single dataframe and write to csv
#df = merge_dfs(basepath, years, pitchers, cols_list)
df = merge_dfs(basepath, years, pitchers)
# Out:
# Memory usage BEFORE converting data types: 2.75 mb
# Memory usage AFTER converting data types: 2.09 mb
# Memory usage recovered: 0.66 mb
# file:  data/pbp_files/2016/merged_by_player/aaron_nola_2016_merged_games.csv
#
# Memory usage BEFORE converting data types: 3.37 mb
# Memory usage AFTER converting data types: 2.54 mb
# Memory usage recovered: 0.83 mb
# file:  data/pbp_files/2016/merged_by_player/carlos_carrasco_2016_merged_games.csv
#
# Memory usage BEFORE converting data types: 4.72 mb
# Memory usage AFTER converting data types: 3.6 mb
# Memory usage recovered: 1.12 mb
# file:  data/pbp_files/2016/merged_by_player/carlos_martinez_2016_merged_games.csv
#
# Memory usage BEFORE converting data types: 5.16 mb
# Memory usage AFTER converting data types: 3.9 mb
# Memory usage recovered: 1.26 mb
# file:  data/pbp_files/2016/merged_by_player/chris_archer_2016_merged_games.csv
#
# Memory usage BEFORE converting data types: 5.13 mb
# Memory usage AFTER converting data types: 3.86 mb
# Memory usage recovered: 1.27 mb
# file:  data/pbp_files/2016/merged_by_player/chris_sale_2016_merged_games.csv
#
# Memory usage BEFORE converting data types: 3.02 mb
# Memory usage AFTER converting data types: 2.26 mb
# Memory usage recovered: 0.76 mb
# file:  data/pbp_files/2016/merged_by_player/clayton_kershaw_2016_merged_games.csv
#
# Memory usage BEFORE converting data types: 4.75 mb
# Memory usage AFTER converting data types: 3.57 mb
# Memory usage recovered: 1.18 mb
# file:  data/pbp_files/2016/merged_by_player/corey_kluber_2016_merged_games.csv
#
# Memory usage BEFORE converting data types: 4.05 mb
# Memory usage AFTER converting data types: 3.07 mb
# Memory usage recovered: 0.98 mb
# file:  data/pbp_files/2016/merged_by_player/dallas_keuchel_2016_merged_games.csv
#
# Memory usage BEFORE converting data types: 5.5 mb
# Memory usage AFTER converting data types: 4.17 mb
# Memory usage recovered: 1.33 mb
# file:  data/pbp_files/2016/merged_by_player/david_price_2016_merged_games.csv
#
# Memory usage BEFORE converting data types: 3.0 mb
# Memory usage AFTER converting data types: 2.29 mb
# Memory usage recovered: 0.71 mb
# file:  data/pbp_files/2016/merged_by_player/gerrit_cole_2016_merged_games.csv
#
# Memory usage BEFORE converting data types: 3.59 mb
# Memory usage AFTER converting data types: 2.72 mb
# Memory usage recovered: 0.87 mb
# file:  data/pbp_files/2016/merged_by_player/jacob_degrom_2016_merged_games.csv
#
# Memory usage BEFORE converting data types: 4.7 mb
# Memory usage AFTER converting data types: 3.54 mb
# Memory usage recovered: 1.16 mb
# file:  data/pbp_files/2016/merged_by_player/jake_arrieta_2016_merged_games.csv
#
# Memory usage BEFORE converting data types: 5.11 mb
# Memory usage AFTER converting data types: 3.89 mb
# Memory usage recovered: 1.22 mb
# file:  data/pbp_files/2016/merged_by_player/jose_quintana_2016_merged_games.csv
#
# Memory usage BEFORE converting data types: 4.73 mb
# Memory usage AFTER converting data types: 3.58 mb
# Memory usage recovered: 1.15 mb
# file:  data/pbp_files/2016/merged_by_player/marcus_stroman_2016_merged_games.csv
#
# Memory usage BEFORE converting data types: 5.44 mb
# Memory usage AFTER converting data types: 4.08 mb
# Memory usage recovered: 1.36 mb
# file:  data/pbp_files/2016/merged_by_player/justin_verlander_2016_merged_games.csv
#
# Memory usage BEFORE converting data types: 5.27 mb
# Memory usage AFTER converting data types: 3.95 mb
# Memory usage recovered: 1.32 mb
# file:  data/pbp_files/2016/merged_by_player/max_scherzer_2016_merged_games.csv
#
# Memory usage BEFORE converting data types: 3.72 mb
# Memory usage AFTER converting data types: 2.8 mb
# Memory usage recovered: 0.92 mb
# file:  data/pbp_files/2016/merged_by_player/michael_fulmer_2016_merged_games.csv
#
# Memory usage BEFORE converting data types: 3.55 mb
# Memory usage AFTER converting data types: 2.67 mb
# Memory usage recovered: 0.88 mb
# file:  data/pbp_files/2016/merged_by_player/stephen_strasburg_2016_merged_games.csv
#
# Memory usage BEFORE converting data types: 2.36 mb
# Memory usage AFTER converting data types: 1.78 mb
# Memory usage recovered: 0.58 mb
# file:  data/pbp_files/2016/merged_by_player/yu_darvish_2016_merged_games.csv
#
# Memory usage BEFORE converting data types: 3.74 mb
# Memory usage AFTER converting data types: 2.82 mb
# Memory usage recovered: 0.92 mb
# file:  data/pbp_files/2016/merged_by_player/zack_greinke_2016_merged_games.csv
#
# Memory usage BEFORE converting data types: 3.75 mb
# Memory usage AFTER converting data types: 2.76 mb
# Memory usage recovered: 0.99 mb
# file:  data/pbp_files/2017/merged_by_player/aaron_nola_2017_merged_games.csv
#
# Memory usage BEFORE converting data types: 4.39 mb
# Memory usage AFTER converting data types: 3.26 mb
# Memory usage recovered: 1.13 mb
# file:  data/pbp_files/2017/merged_by_player/carlos_carrasco_2017_merged_games.csv
#
# Memory usage BEFORE converting data types: 4.59 mb
# Memory usage AFTER converting data types: 3.43 mb
# Memory usage recovered: 1.16 mb
# file:  data/pbp_files/2017/merged_by_player/carlos_martinez_2017_merged_games.csv
#
# Memory usage BEFORE converting data types: 4.96 mb
# Memory usage AFTER converting data types: 3.7 mb
# Memory usage recovered: 1.26 mb
# file:  data/pbp_files/2017/merged_by_player/chris_archer_2017_merged_games.csv
#
# Memory usage BEFORE converting data types: 4.85 mb
# Memory usage AFTER converting data types: 3.58 mb
# Memory usage recovered: 1.27 mb
# file:  data/pbp_files/2017/merged_by_player/chris_sale_2017_merged_games.csv
#
# Memory usage BEFORE converting data types: 3.62 mb
# Memory usage AFTER converting data types: 2.71 mb
# Memory usage recovered: 0.91 mb
# file:  data/pbp_files/2017/merged_by_player/clayton_kershaw_2017_merged_games.csv
#
# Memory usage BEFORE converting data types: 4.02 mb
# Memory usage AFTER converting data types: 2.93 mb
# Memory usage recovered: 1.09 mb
# file:  data/pbp_files/2017/merged_by_player/corey_kluber_2017_merged_games.csv
#
# Memory usage BEFORE converting data types: 3.18 mb
# Memory usage AFTER converting data types: 2.37 mb
# Memory usage recovered: 0.81 mb
# file:  data/pbp_files/2017/merged_by_player/dallas_keuchel_2017_merged_games.csv
#
# Memory usage BEFORE converting data types: 1.87 mb
# Memory usage AFTER converting data types: 1.4 mb
# Memory usage recovered: 0.47 mb
# file:  data/pbp_files/2017/merged_by_player/david_price_2017_merged_games.csv
#
# Memory usage BEFORE converting data types: 4.75 mb
# Memory usage AFTER converting data types: 3.53 mb
# Memory usage recovered: 1.22 mb
# file:  data/pbp_files/2017/merged_by_player/gerrit_cole_2017_merged_games.csv
#
# Memory usage BEFORE converting data types: 4.56 mb
# Memory usage AFTER converting data types: 3.38 mb
# Memory usage recovered: 1.18 mb
# file:  data/pbp_files/2017/merged_by_player/jacob_degrom_2017_merged_games.csv
#
# Memory usage BEFORE converting data types: 4.02 mb
# Memory usage AFTER converting data types: 3.0 mb
# Memory usage recovered: 1.02 mb
# file:  data/pbp_files/2017/merged_by_player/jake_arrieta_2017_merged_games.csv
#
# Memory usage BEFORE converting data types: 4.65 mb
# Memory usage AFTER converting data types: 3.48 mb
# Memory usage recovered: 1.17 mb
# file:  data/pbp_files/2017/merged_by_player/jose_quintana_2017_merged_games.csv
#
# Memory usage BEFORE converting data types: 4.56 mb
# Memory usage AFTER converting data types: 3.39 mb
# Memory usage recovered: 1.17 mb
# file:  data/pbp_files/2017/merged_by_player/marcus_stroman_2017_merged_games.csv
#
# Memory usage BEFORE converting data types: 5.06 mb
# Memory usage AFTER converting data types: 3.76 mb
# Memory usage recovered: 1.3 mb
# file:  data/pbp_files/2017/merged_by_player/justin_verlander_2017_merged_games.csv
#
# Memory usage BEFORE converting data types: 4.42 mb
# Memory usage AFTER converting data types: 3.27 mb
# Memory usage recovered: 1.15 mb
# file:  data/pbp_files/2017/merged_by_player/max_scherzer_2017_merged_games.csv
#
# Memory usage BEFORE converting data types: 3.67 mb
# Memory usage AFTER converting data types: 2.75 mb
# Memory usage recovered: 0.92 mb
# file:  data/pbp_files/2017/merged_by_player/michael_fulmer_2017_merged_games.csv
#
# Memory usage BEFORE converting data types: 4.01 mb
# Memory usage AFTER converting data types: 2.99 mb
# Memory usage recovered: 1.02 mb
# file:  data/pbp_files/2017/merged_by_player/stephen_strasburg_2017_merged_games.csv
#
# Memory usage BEFORE converting data types: 4.44 mb
# Memory usage AFTER converting data types: 3.31 mb
# Memory usage recovered: 1.13 mb
# file:  data/pbp_files/2017/merged_by_player/yu_darvish_2017_merged_games.csv
# Memory usage BEFORE converting data types: 4.52 mb
# Memory usage AFTER converting data types: 3.35 mb
# Memory usage recovered: 1.17 mb
# file:  data/pbp_files/2017/merged_by_player/zack_greinke_2017_merged_games.csv
#
#
#
# 	Total memory usage BEFORE converting data types: 167.55 mb
# 	Total memory usage AFTER converting data types: 125.53 mb
# 	Total Memory usage recovered: 42.02 mb

# %%
df
# Out:
#         count.balls  count.outs  count.pitch_count  count.strikes        date  \
# 0                 0           0                  1              1  2016-04-06
# 1                 0           0                  2              2  2016-04-06
# 2                 0           1                  3              2  2016-04-06
# 3                 1           1                  1              0  2016-04-06
# 4                 1           1                  2              0  2016-04-06
# 5                 0           1                  1              1  2016-04-06
# 6                 1           1                  2              1  2016-04-06
# 7                 1           1                  3              2  2016-04-06
# 8                 1           1                  4              2  2016-04-06
# 9                 2           1                  5              2  2016-04-06
# 10                2           2                  6              2  2016-04-06
# 19                   Scott Schebler strikes out swinging.    NaN
# 20                    Ivan De Jesus strikes out swinging.    NaN
# 21                    Ivan De Jesus strikes out swinging.    NaN
# 22                    Ivan De Jesus strikes out swinging.    NaN
# 23                    Ivan De Jesus strikes out swinging.    NaN
# 24      Brandon Finnegan pops out to shortstop to Fred...    NaN
# 25      Brandon Finnegan pops out to shortstop to Fred...    NaN
# 26                   Billy Hamilton strikes out swinging.    NaN
# 27                   Billy Hamilton strikes out swinging.    NaN
# 28                   Billy Hamilton strikes out swinging.    NaN
# 29      Zack Cozart lines out to center field to Odube...    NaN
# ...                                                   ...    ...
# 113645  Melky Cabrera grounds out to shallow infield t...    NaN
# 113646  Melky Cabrera grounds out to shallow infield t...    NaN
# 113647  Melky Cabrera grounds out to shallow infield t...    NaN
# 113648  Eric Hosmer grounds out to shortstop, Jake Lam...    NaN
# 113649       Mike Moustakas singles to left center field.    NaN
# 113650       Mike Moustakas singles to left center field.    NaN
# 113651                 Brandon Moss strikes out swinging.    NaN
# 113652                 Brandon Moss strikes out swinging.    NaN
# 113653                 Brandon Moss strikes out swinging.    NaN
# 113654                 Brandon Moss strikes out swinging.    NaN
# 113655                 Brandon Moss strikes out swinging.    NaN
# 113656  Alcides Escobar grounds out to shallow infield...    NaN
# 113657  Alcides Escobar grounds out to shallow infield...    NaN
# 113658  Alcides Escobar grounds out to shallow infield...    NaN
# 113659  Alcides Escobar grounds out to shallow infield...    NaN
# 113660                                 Alex Gordon walks.    NaN
# 113661                                 Alex Gordon walks.    NaN
# 113662                                 Alex Gordon walks.    NaN
# 113663                                 Alex Gordon walks.    NaN
# 113664                                 Alex Gordon walks.    NaN
# 113665                                 Alex Gordon walks.    NaN
# 113666                                 Alex Gordon walks.    NaN
# 113667          Drew Butera walks. Alex Gordon to second.    NaN
# 113668          Drew Butera walks. Alex Gordon to second.    NaN
# 113669          Drew Butera walks. Alex Gordon to second.    NaN
# 113670          Drew Butera walks. Alex Gordon to second.    NaN
# 113671          Drew Butera walks. Alex Gordon to second.    NaN
# 113672          Drew Butera walks. Alex Gordon to second.    NaN
# 113673          Drew Butera walks. Alex Gordon to second.    NaN
# 113674          Drew Butera walks. Alex Gordon to second.    NaN
#
#         flags.is_ab_over  flags.is_bunt  flags.is_bunt_shown       ...        \
# 0                  False          False                False       ...
# 1                  False          False                False       ...
# 2                   True          False                False       ...
# 3                  False          False                False       ...
# 4                   True          False                False       ...
# 5                  False          False                False       ...
# 6                  False          False                False       ...
# 7                  False          False                False       ...
# 8                  False          False                False       ...
# 9                  False          False                False       ...
# 10                  True          False                False       ...
# 11                 False          False                False       ...
# 12                 False          False                False       ...
# 13                 False          False                False       ...
# 14                 False          False                False       ...
# 15                  True          False                False       ...
# 16                  True          False                False       ...
# 17                 False          False                False       ...
# 18                 False          False                False       ...
# 19                  True          False                False       ...
# 20                 False          False                False       ...
# 21                 False          False                False       ...
# 22                 False          False                False       ...
# 23                  True          False                False       ...
# 24                 False          False                False       ...
# 25                  True          False                False       ...
# 26                 False          False                 True       ...
# 27                 False          False                False       ...
# 28                  True          False                False       ...
# 29                 False          False                False       ...
# ...                  ...            ...                  ...       ...
# 113645             False          False                False       ...
# 113646             False          False                False       ...
# 113647              True          False                False       ...
# 113648              True          False                False       ...
# 113649             False          False                False       ...
# 113650              True          False                False       ...
# 113651             False          False                False       ...
# 113652             False          False                False       ...
# 113653             False          False                False       ...
# 113654             False          False                False       ...
# 113655              True          False                False       ...
# 113656             False          False                False       ...
# 113657             False          False                False       ...
# 113658             False          False                False       ...
# 113659              True          False                False       ...
# 113660             False          False                False       ...
# 113661             False          False                False       ...
# 113662             False          False                False       ...
# 113663             False          False                False       ...
# 113664             False          False                False       ...
# 113665             False          False                False       ...
# 113666              True          False                False       ...
# 113667             False          False                False       ...
# 113668             False          False                False       ...
# 113669             False          False                False       ...
# 113670             False          False                False       ...
# 113671             False          False                False       ...
# 113672             False          False                False       ...
# 113673             False          False                False       ...
# 113674              True          False                False       ...
#
#         pitcher.pitch_zone  pitcher.pitcher_hand  pitcher.preferred_name  \
# 0                      6.0                     R                   Aaron
# 1                      7.0                     R                   Aaron
# 2                      7.0                     R                   Aaron
# 3                     13.0                     R                   Aaron
# 4                      5.0                     R                   Aaron
# 5                      8.0                     R                   Aaron
# 6                     13.0                     R                   Aaron
# 7                      8.0                     R                   Aaron
# 8                      7.0                     R                   Aaron
# 9                     13.0                     R                   Aaron
# 10                     8.0                     R                   Aaron
# 11                    12.0                     R                   Aaron
# 12                    13.0                     R                   Aaron
# 13                     9.0                     R                   Aaron
# 14                    13.0                     R                   Aaron
# 15                     3.0                     R                   Aaron
# 16                    11.0                     R                   Aaron
# 17                     6.0                     R                   Aaron
# 18                     6.0                     R                   Aaron
# 19                     9.0                     R                   Aaron
# 20                     8.0                     R                   Aaron
# 21                    13.0                     R                   Aaron
# 22                     2.0                     R                   Aaron
# 23                    13.0                     R                   Aaron
# 24                     8.0                     R                   Aaron
# 25                     3.0                     R                   Aaron
# 26                     8.0                     R                   Aaron
# 27                     8.0                     R                   Aaron
# 28                    12.0                     R                   Aaron
# 29                     2.0                     R                   Aaron
# ...                    ...                   ...                     ...
# 113645                11.0                     R                     NaN
# 113646                13.0                     R                     NaN
# 113647                 9.0                     R                     NaN
# 113648                 2.0                     R                     NaN
# 113649                 9.0                     R                     NaN
# 113650                11.0                     R                     NaN
# 113651                11.0                     R                     NaN
# 113652                 9.0                     R                     NaN
# 113653                12.0                     R                     NaN
# 113654                11.0                     R                     NaN
# 113655                12.0                     R                     NaN
# 113656                13.0                     R                     NaN
# 113657                 6.0                     R                     NaN
# 113658                 4.0                     R                     NaN
# 113659                13.0                     R                     NaN
# 113660                12.0                     R                     NaN
# 113661                10.0                     R                     NaN
# 113662                12.0                     R                     NaN
# 113663                13.0                     R                     NaN
# 113664                 6.0                     R                     NaN
# 113665                 5.0                     R                     NaN
# 113666                13.0                     R                     NaN
# 113667                 8.0                     R                     NaN
# 113668                 5.0                     R                     NaN
# 113669                 7.0                     R                     NaN
# 113670                12.0                     R                     NaN
# 113671                11.0                     R                     NaN
# 113672                 8.0                     R                     NaN
# 113673                 6.0                     R                     NaN
# 113674                10.0                     R                     NaN
#
#                                   pitcher_id  \
# 0       ded1b30d-52ca-4eec-bce6-251b15b085ac
#
{'starting_base': 1, 'ending_base': 1, 'out': ...
# 113673  {'starting_base': 1, 'ending_base': 1, 'out': ...
# 113674  {'starting_base': 0, 'ending_base': 1, 'out': ...
#
#                                                  runner_2 runner_3 runner_4  \
# 0                                                     NaN      NaN      NaN
# 1                                                     NaN      NaN      NaN
# 2                                                     NaN      NaN      NaN
# 3                                                     NaN      NaN      NaN
# 4                                                     NaN      NaN      NaN
# 5                                                     NaN      NaN      NaN
# 6                                                     NaN      NaN      NaN
# 7                                                     NaN      NaN      NaN
# 8                                                     NaN      NaN      NaN
# 9                                                     NaN      NaN      NaN
# 10                                                    NaN      NaN      NaN
# 11                                                    NaN      NaN      NaN
# 12                                                    NaN      NaN      NaN
# 13                                                    NaN      NaN      NaN
# 14                                                    NaN      NaN      NaN
# 15                                                    NaN      NaN      NaN
# 16                                                    NaN      NaN      NaN
# 17                                                    NaN      NaN      NaN
# 18                                                    NaN      NaN      NaN
# 19                                                    NaN      NaN      NaN
# 20                                                    NaN      NaN      NaN
# 21                                                    NaN      NaN      NaN
# 22                                                    NaN      NaN      NaN
# 23                                                    NaN      NaN      NaN
# 24                                                    NaN      NaN      NaN
# 25                                                    NaN      NaN      NaN
# 26                                                    NaN      NaN      NaN
# 27                                                    NaN      NaN      NaN
# 28                                                    NaN      NaN      NaN
# 29                                                    NaN      NaN      NaN
# ...                                                   ...      ...      ...
# 113645                                                NaN      NaN      NaN
# 113646                                                NaN      NaN      NaN
# 113647                                                NaN      NaN      NaN
# 113648                                                NaN      NaN      NaN
# 113649                                                NaN      NaN      NaN
# 113650                                                NaN      NaN      NaN
# 113651                                                NaN      NaN      NaN
# 113652                                                NaN      NaN      NaN
# 113653                                                NaN      NaN      NaN
# 113654                                                NaN      NaN      NaN
# 113655                                                NaN      NaN      NaN
# 113656                                                NaN      NaN      NaN
# 113657                                                NaN      NaN      NaN
# 113658                                                NaN      NaN      NaN
# 113659                                                NaN      NaN      NaN
# 113660                                                NaN      NaN      NaN
# 113661                                                NaN      NaN      NaN
# 113662                                                NaN      NaN      NaN
# 113663                                                NaN      NaN      NaN
# 113664                                                NaN      NaN      NaN
# 113665                                                NaN      NaN      NaN
# 113666                                                NaN      NaN      NaN
# 113667                                                NaN      NaN      NaN
# 113668                                                NaN      NaN      NaN
# 113669                                                NaN      NaN      NaN
# 113670                                                NaN      NaN      NaN
# 113671                                                NaN      NaN      NaN
# 113672                                                NaN      NaN      NaN
# 113673                                                NaN      NaN      NaN
# 113674  {'starting_base': 1, 'ending_base': 2, 'out': ...      NaN      NaN
#
#        pitcher.pitch_x pitcher.pitch_y
# 0                  NaN             NaN
# 1                  NaN             NaN
# 2                  NaN             NaN
# 3                  NaN             NaN
# 4                  NaN             NaN
# 5                  NaN             NaN
# 6                  NaN             NaN
# 7                  NaN             NaN
# 8                  NaN             NaN
# 9                  NaN             NaN
# 10                 NaN             NaN
# 11                 NaN             NaN
# 12                 NaN             NaN
# 13                 NaN             NaN
# 14                 NaN             NaN
# 15                 NaN             NaN
# 16                 NaN             NaN
# 17                 NaN             NaN
# 18                 NaN             NaN
# 19                 NaN             NaN
# 20                 NaN             NaN
# 21                 NaN             NaN
# 22                 NaN             NaN
# 23                 NaN             NaN
# 24                 NaN             NaN
# 25                 NaN             NaN
# 26                 NaN             NaN
# 27                 NaN             NaN
# 28                 NaN             NaN
# 29                 NaN             NaN
# ...                ...             ...
# 113645           170.0           -95.0
# 113646          -176.0             4.0
# 113647            76.0           -47.0
# 113648            11.0            47.0
# 113649            82.0           -47.0
# 113650           182.0           -52.0
# 113651           211.0            47.0
# 113652            41.0          -100.0
# 113653            11.0          -169.0
# 113654           164.0           -86.0
# 113655             5.0          -117.0
# 113656          -188.0          -178.0
# 113657            52.0             4.0
# 113658           -47.0           -17.0
# 113659          -152.0           -69.0
# 113660            35.0          -108.0
# 113661           -70.0           117.0
# 113662            11.0          -178.0
# 113663          -129.0             0.0
# 113664            52.0            -4.0
# 113665           -11.0           -30.0
# 113666          -164.0          -156.0
# 113667           -29.0           -86.0
# 113668             0.0           -17.0
# 113669           -70.0           -69.0
# 113670           -11.0          -169.0
# 113671           129.0          -108.0
# 113672           -17.0           -69.0
# 113673            41.0            26.0
# 113674             0.0           121.0
#
# [113675 rows x 41 columns]

# %%
df.describe(include=[np.number]).T
# Out:
#                         count       mean        std    min   25%   50%   75%  \
# count.balls          113675.0   1.191432   1.013089    0.0   0.0   1.0   2.0
# count.outs           113675.0   1.157466   0.907483    0.0   0.0   1.0   2.0
# count.pitch_count    113675.0   2.887530   1.724005    0.0   1.0   3.0   4.0
# count.strikes        113675.0   1.320123   0.853961    0.0   1.0   1.0   2.0
# inning               113675.0   3.777488   2.013685    1.0   2.0   4.0   5.0
# pitcher.pitch_count  113675.0  51.034132  29.859060    1.0  25.0  50.0  76.0
# pitcher.pitch_speed  113675.0  89.451304   5.709224    8.0  86.0  91.0  94.0
# pitcher.pitch_zone   113613.0   8.706257   3.669220    1.0   6.0  10.0  12.0
# pitcher.pitch_x       58185.0  -7.885469  97.913334 -300.0 -82.0  -5.0  70.0
# pitcher.pitch_y       58185.0 -31.001942  87.461161 -221.0 -95.0 -34.0  30.0
#
#                        max
# count.balls            4.0
# count.outs             3.0
# count.pitch_count     13.0
# count.strikes          3.0
# inning                 9.0
# pitcher.pitch_count  125.0
# pitcher.pitch_speed  101.0
# pitcher.pitch_zone    13.0
# pitcher.pitch_x      300.0
# pitcher.pitch_y      217.0

# %%
df.describe(include=[np.object, pd.Categorical]).T
# Out:
#                          count unique  \
# date                    113675    348
# description             113437  20982
# errors                     376    240
# half                    113675      2
# hit_location             19927     71
# hit_type                 17531      4
# hitter.first_name        87797    386
# hitter.id                87797    786
# hitter.last_name         87797    678
# hitter.preferred_name    87797    413
# outcome_id              113675     39
# pitcher.first_name      113675     22
# pitcher.hitter_hand     113675      2
# pitcher.id              113675     20
# pitcher.last_name       113675     22
# pitcher.pitch_type      113675     12
# pitcher.pitcher_hand    113675      2
# pitcher.preferred_name   87797     18
# pitcher_id              113675     20
# runner_1                 47815   5322
# runner_2                 14384   3381
# runner_3                  2366   1001
# runner_4                   134    120
#
#                                                                       top  \
# date                                                           2016-04-26
# description                             Eric Hosmer strikes out swinging.
# errors                  [{'type': 'fielding', 'preferred_name': 'Matt'...
# half                                                                    B
# hit_location                                                           22
# hit_type                                                               GB
# hitter.first_name                                                 Michael
# hitter.id                            6ef878e2-1f2d-4855-a250-2ec7c97f961c
# hitter.last_name                                                  Cabrera
# hitter.preferred_name                                                José
# outcome_id                                                             bB
# pitcher.first_name                                                 Carlos
# pitcher.hitter_hand                                                     R
# pitcher.id                           2fe6cb9b-c41e-4ee2-9b22-f8b27bf6c5be
# pitcher.last_name                                               Verlander
# pitcher.pitch_type                                                     FA
# pitcher.pitcher_hand                                                    R
# pitcher.preferred_name                                              Chris
# pitcher_id                           2fe6cb9b-c41e-4ee2-9b22-f8b27bf6c5be
# runner_1                {'starting_base': 1, 'ending_base': 1, 'out': ...
# runner_2                {'starting_base': 2, 'ending_base': 2, 'out': ...
# runner_3                {'starting_base': 3, 'ending_base': 3, 'out': ...
# runner_4                {'starting_base': 3, 'ending_base': 4, 'out': ...
#
#                          freq
# date                      749
# description               157
# errors                      6
# half                    57543
# hit_location             2249
# hit_type                 8296
# hitter.first_name        2426
# hitter.id                 501
# hitter.last_name         1109
# hitter.preferred_name    2040
# outcome_id              36782
# pitcher.first_name      11482
# pitcher.hitter_hand     65249
# pitcher.id               7203
# pitcher.last_name        7203
# pitcher.pitch_type      57406
# pitcher.pitcher_hand    86108
# pitcher.preferred_name  10611
# pitcher_id               7203
# runner_1                  193
# runner_2                   95
# runner_3                   28
# runner_4                    3

# %%
df.describe(include=['bool']).T
# Out:
#                        count unique    top    freq
# flags.is_ab_over      113675      2  False   84203
# flags.is_bunt         113675      2  False  112996
# flags.is_bunt_shown   113675      2  False  113061
# flags.is_double_play  113675      2  False  112994
# flags.is_hit          113675      2  False  107423
# flags.is_passed_ball  113675      2  False  113615
# flags.is_triple_play  113675      2  False  113673
# flags.is_wild_pitch   113675      2  False  113435

# %%
df.dtypes
# Out:
# count.balls                   int8
# count.outs                    int8
# count.pitch_count             int8
# count.strikes                 int8
# date                        object
# description                 object
# errors                      object
# flags.is_ab_over              bool
# flags.is_bunt                 bool
# flags.is_bunt_shown           bool
# flags.is_double_play          bool
# flags.is_hit                  bool
# flags.is_passed_ball          bool
# flags.is_triple_play          bool
# flags.is_wild_pitch           bool
# half                      category
# hit_location                object
# hit_type                  category
# hitter.first_name           object
# hitter.id                   object
# hitter.last_name            object
# hitter.preferred_name       object
# inning                        int8
# outcome_id                  object
# pitcher.first_name          object
# pitcher.hitter_hand       category
# pitcher.id                  object
# pitcher.last_name           object
# pitcher.pitch_count          int64
# pitcher.pitch_speed           int8
# pitcher.pitch_type          object
# pitcher.pitch_zone         float64
# pitcher.pitcher_hand        object
# pitcher.preferred_name      object
# pitcher_id                  object
# runner_1                    object
# runner_2                    object
# runner_3                    object
# runner_4                    object
# pitcher.pitch_x            float64
# pitcher.pitch_y            float64
# dtype: object

# %%
original_mem = df.memory_usage(deep=True)
original_mem
# Out:
# Index                           80
# count.balls                 113675
# count.outs                  113675
# count.pitch_count           113675
# count.strikes               113675
# date                       7616225
# description               12471091
# errors                     3710502
# flags.is_ab_over            113675
# flags.is_bunt               113675
# flags.is_bunt_shown         113675
# flags.is_double_play        113675
# flags.is_hit                113675
# flags.is_passed_ball        113675
# flags.is_triple_play        113675
# flags.is_wild_pitch         113675
# half                        113887
# hit_location               3669714
# hit_type                    114071
# hitter.first_name          6452766
# hitter.id                  8993217
# hitter.last_name           6602269
# hitter.preferred_name      6393359
# inning                      113675
# outcome_id                 6758931
# pitcher.first_name         7280305
# pitcher.hitter_hand         113887
# pitcher.id                10571775
# pitcher.last_name          7354048
# pitcher.pitch_count         909400
# pitcher.pitch_speed         113675
# pitcher.pitch_type         6706825
# pitcher.pitch_zone          909400
# pitcher.pitcher_hand       7502550
# pitcher.preferred_name     6401381
# pitcher_id                10571775
# runner_1                  15642092
# runner_2                   7448870
# runner_3                   4269871
# runner_4                   3677128
# pitcher.pitch_x             909400
# pitcher.pitch_y             909400
# dtype: int64

# %%
sum((original_mem/1024)/1024)
# Out:
# 148.45435047149658

# %%
list_cat_cols = ['half', 'pitcher.hitter_hand', 'pitcher.pitcher_hand', 'hit_type', 'hitter_hand', 'pitcher.pitch_type', 'pitcher_hand', 'outcome_id', 'hit_location']
list_num_cols = ['count.balls', 'count.outs', 'count.strikes', 'count.pitch_count', 'pitcher.pitch_speed', 'inning']

for category in list_cat_cols:
    if category in df.columns:
        df[category] = df[category].astype('category')

for number in list_num_cols:
    if number in df.columns:
        df[number] = df[number].astype(np.int8)

# %%
df.dtypes
# Out:
# count.balls                   int8
# count.outs                    int8
# count.pitch_count             int8
# count.strikes                 int8
# date                        object
# description                 object
# errors                      object
# flags.is_ab_over              bool
# flags.is_bunt                 bool
# flags.is_bunt_shown           bool
# flags.is_double_play          bool
# flags.is_hit                  bool
# flags.is_passed_ball          bool
# flags.is_triple_play          bool
# flags.is_wild_pitch           bool
# half                      category
# hit_location              category
# hit_type                  category
# hitter.first_name           object
# hitter.id                   object
# hitter.last_name            object
# hitter.preferred_name       object
# inning                        int8
# outcome_id                category
# pitcher.first_name          object
# pitcher.hitter_hand       category
# pitcher.id                  object
# pitcher.last_name           object
# pitcher.pitch_count          int64
# pitcher.pitch_speed           int8
# pitcher.pitch_type        category
# pitcher.pitch_zone         float64
# pitcher.pitcher_hand      category
# pitcher.preferred_name      object
# pitcher_id                  object
# runner_1                    object
# runner_2                    object
# runner_3                    object
# runner_4                    object
# pitcher.pitch_x            float64
# pitcher.pitch_y            float64
# dtype: object

# %%
new_mem = df.memory_usage(deep=True)
new_mem
# Out:
# Index                           80
# count.balls                 113675
# count.outs                  113675
# count.pitch_count           113675
# count.strikes               113675
# date                       7616225
# description               12471091
# errors                     3710502
# flags.is_ab_over            113675
# flags.is_bunt               113675
# flags.is_bunt_shown         113675
# flags.is_double_play        113675
# flags.is_hit                113675
# flags.is_passed_ball        113675
# flags.is_triple_play        113675
# flags.is_wild_pitch         113675
# half                        113887
# hit_location                119541
# hit_type                    114071
# hitter.first_name          6452766
# hitter.id                  8993217
# hitter.last_name           6602269
# hitter.preferred_name      6393359
# inning                      113675
# outcome_id                  117328
# pitcher.first_name         7280305
# pitcher.hitter_hand         113887
# pitcher.id                10571775
# pitcher.last_name          7354048
# pitcher.pitch_count         909400
# pitcher.pitch_speed         113675
# pitcher.pitch_type          114703
# pitcher.pitch_zone          909400
# pitcher.pitcher_hand        113887
# pitcher.preferred_name     6401381
# pitcher_id                10571775
# runner_1                  15642092
# runner_2                   7448870
# 6      Dustin Pedroia doubles to deep right center fi...    NaN
# 7      Dustin Pedroia doubles to deep right center fi...    NaN
# 8                                 Xander Bogaerts walks.    NaN
# 9                                 Xander Bogaerts walks.    NaN
# 10                                Xander Bogaerts walks.    NaN
# 11                                Xander Bogaerts walks.    NaN
# 12                                Xander Bogaerts walks.    NaN
# 13                                Xander Bogaerts walks.    NaN
# 14                                Xander Bogaerts walks.    NaN
# 15                                Xander Bogaerts walks.    NaN
# 16     David Ortiz lines out to left field to Jose Ra...    NaN
# 17     David Ortiz lines out to left field to Jose Ra...    NaN
# 18     Hanley Ramirez grounds out to shallow infield,...    NaN
# 19     Hanley Ramirez grounds out to shallow infield,...    NaN
# 20     Hanley Ramirez grounds out to shallow infield,...    NaN
# 21     Hanley Ramirez grounds out to shallow infield,...    NaN
# 22            Travis Shaw singles to shallow left field.    NaN
# 23            Travis Shaw singles to shallow left field.    NaN
# 24     Brock Holt homers to right field. Travis Shaw ...    NaN
# 25     Brock Holt homers to right field. Travis Shaw ...    NaN
# 26     Brock Holt homers to right field. Travis Shaw ...    NaN
# 27     Brock Holt homers to right field. Travis Shaw ...    NaN
# 28     Brock Holt homers to right field. Travis Shaw ...    NaN
# 29     Brock Holt homers to right field. Travis Shaw ...    NaN
# ...                                                  ...    ...
# 53615  Travis Jankowski grounds out to first base, Pa...    NaN
# 53616  Travis Jankowski grounds out to first base, Pa...    NaN
# 53617  Travis Jankowski grounds out to first base, Pa...    NaN
# 53618  Travis Jankowski grounds out to first base, Pa...    NaN
# 53619  Jon Jay grounds out to shortstop, Chris Owings...    NaN
# 53620  Jon Jay grounds out to shortstop, Chris Owings...    NaN
# 53621  Jon Jay grounds out to shortstop, Chris Owings...    NaN
# 53622  Jon Jay grounds out to shortstop, Chris Owings...    NaN
# 53623  Jon Jay grounds out to shortstop, Chris Owings...    NaN
# 53624  Jon Jay grounds out to shortstop, Chris Owings...    NaN
# 53625  Jon Jay grounds out to shortstop, Chris Owings...    NaN
# 53626  Wil Myers lines out to deep left center field ...    NaN
# 53627  Wil Myers lines out to deep left center field ...    NaN
# 53628  Wil Myers lines out to deep left center field ...    NaN
# 53629                 Ryan Schimpf strikes out swinging.    NaN
# 53630                 Ryan Schimpf strikes out swinging.    NaN
# 53631                 Ryan Schimpf strikes out swinging.    NaN
# 53632                 Ryan Schimpf strikes out swinging.    NaN
# 53633                 Ryan Schimpf strikes out swinging.    NaN
# 53634               Alex Dickerson strikes out swinging.    NaN
# 53635               Alex Dickerson strikes out swinging.    NaN
# 53636               Alex Dickerson strikes out swinging.    NaN
# 53637               Alex Dickerson strikes out swinging.    NaN
# 53638               Alex Dickerson strikes out swinging.    NaN
# 53639               Alex Dickerson strikes out swinging.    NaN
# 53640               Alex Dickerson strikes out swinging.    NaN
# 53641               Alex Dickerson strikes out swinging.    NaN
# 53642  Alexi Amarista grounds out to shortstop, Chris...    NaN
# 53643  Alexi Amarista grounds out to shortstop, Chris...    NaN
# 53644  Alexi Amarista grounds out to shortstop, Chris...    NaN
#
#        flags.is_ab_over  flags.is_bunt  flags.is_bunt_shown   ...     \
# 0                 False          False                False   ...
# 1                 False          False                False   ...
# 2                 False          False                False   ...
# 3                 False          False                False   ...
# 4                  True          False                False   ...
# 5                 False          False                False   ...
# 6                 False          False                False   ...
# 7                  True          False                False   ...
# 8                 False          False                False   ...
# 9                 False          False                False   ...
# 10                False          False                False   ...
# 11                False          False                False   ...
# 12                False          False                False   ...
# 13                False          False                False   ...
# 14                False          False                False   ...
# 15                 True          False                False   ...
# 16                False          False                False   ...
# 17                 True          False                False   ...
# 18                False          False                False   ...
# 19                False          False                False   ...
# 20                False          False                False   ...
# 21                 True          False                False   ...
# 22                False          False                False   ...
# 23                 True          False                False   ...
# 24                False          False                False   ...
# 25                False          False                False   ...
# 26                False          False                False   ...
# 27                False          False                False   ...
# 28                False          False                False   ...
# 29                False          False                False   ...
# ...                 ...            ...                  ...   ...
# 53615             False          False                False   ...
# 53616             False          False                False   ...
# 53617             False          False                False   ...
# 53618              True          False                False   ...
# 53619             False          False                False   ...
# 53620             False          False                False   ...
# 53621             False          False                False   ...
# 53622             False          False                False   ...
# 53623             False          False                False   ...
# 53624             False          False                False   ...
# 53625              True          False                False   ...
# 53626             False          False                False   ...
# 53627             False          False                False   ...
# 53628              True          False                False   ...
# 53629             False          False                False   ...
# 53630             False          False                False   ...
# 53631             False          False                False   ...
# 53632             False          False                False   ...
# 53633              True          False                False   ...
# 53634             False          False                False   ...
# 53635             False          False                False   ...
# 53636             False          False                False   ...
# 53637             False          False                False   ...
# 53638             False          False                False   ...
# 53639             False          False                False   ...
# 53640             False          False                False   ...
# 53641              True          False                False   ...
# 53642             False          False                False   ...
# 53643             False          False                False   ...
# 53644              True          False                False   ...
#
#        pitcher.pitch_type  pitcher.pitch_zone  pitcher.pitcher_hand  \
# 0                      FA                10.0                     R
# 1                      FA                 4.0                     R
# 2                      FA                11.0                     R
# 3                      FA                 2.0                     R
# 4                      FA                 4.0                     R
# 5                      FA                10.0                     R
# 6                      FA                 2.0                     R
# 7                      FA                 3.0                     R
# 8                      FA                11.0                     R
# 9                      FA                 3.0                     R
# 10                     SL                 7.0                     R
# 11                     SL                12.0                     R
# 12                     FA                 7.0                     R
# 13                     CH                13.0                     R
# 14                     FA                 4.0                     R
# 15                     FA                10.0                     R
# 16                     FA                10.0                     R
# 17                     FA                 6.0                     R
# 18                     FA                11.0                     R
# 19                     FA                10.0                     R
# 20                     FA                13.0                     R
# 21                     FA                 4.0                     R
# 22                     FA                 8.0                     R
# 23                     CH                 9.0                     R
# 24                     CH                 9.0                     R
# 25                     FA                11.0                     R
# 26                     CH                12.0                     R
# 27                     FA                10.0                     R
# 28                     FA                 6.0                     R
# 29                     FA                 1.0                     R
# ...                   ...                 ...                   ...
# 53615                  FA                 6.0                     R
# 53616                  CH                12.0                     R
# 53617                  CH                11.0                     R
# 53618                  FA                 5.0                     R
# 53619                  FA                 2.0                     R
# 53620                  FA                 1.0                     R
# 53621                  CU                12.0                     R
# 53622                  SL                12.0                     R
# 53623                  FA                 8.0                     R
# 53624                  SL                 5.0                     R
# 53625                  CU                11.0                     R
# 53626                  FA                13.0                     R
# 53627                  FA                 6.0                     R
# 53628                  CU                13.0                     R
# 53629                  CU                 9.0                     R
# 53630                  FA                 9.0                     R
# 53631                  SL                12.0                     R
# 53632                  FA                 4.0                     R
# 53633                  SL                12.0                     R
# 53634                  FA                11.0                     R
# 53635                  CH                 8.0                     R
# 53636                  FA                13.0                     R
# 53637                  FA                 9.0                     R
# 53638                  CH                12.0                     R
# 53639                  FA                 5.0                     R
# 53640                  CH                12.0                     R
# 53641                  CH                 9.0                     R
# 53642                  CU                12.0                     R
# 53643                  FA                 9.0                     R
# 53644                  FA                12.0                     R
#
#        pitcher.preferred_name  pitcher_hand  \
# 0                      Carlos           NaN
# 1                      Carlos           NaN
# 2                      Carlos           NaN
# 3                      Carlos           NaN
# 4                      Carlos           NaN
# 5                      Carlos           NaN
# 6                      Carlos           NaN
# 7                      Carlos           NaN
# 8                      Carlos           NaN
# 9                      Carlos           NaN
# 10                     Carlos           NaN
# 11                     Carlos           NaN
# 12                     Carlos           NaN
# 13                     Carlos           NaN
# 14                     Carlos           NaN
# 15                     Carlos           NaN
# 16                     Carlos           NaN
# 17                     Carlos           NaN
# 18                     Carlos           NaN
# 19                     Carlos           NaN
# 20                     Carlos           NaN
# 21                     Carlos           NaN
# 22                     Carlos           NaN
# 23                     Carlos           NaN
# 24                     Carlos           NaN
# 25                     Carlos           NaN
# 26                     Carlos           NaN
# 27                     Carlos           NaN
# 28                     Carlos           NaN
# 29                     Carlos           NaN
# ...                       ...           ...
# 53615                    Zack             R
# 53616                    Zack             R
# 53617                    Zack             R
# 53618                    Zack             R
# 53619                    Zack             R
# 53620                    Zack             R
# 53621                    Zack             R
# 53622                    Zack             R
# 53623                    Zack             R
# 53624                    Zack             R
# 53625                    Zack             R
# 53626                    Zack             R
# 53627                    Zack             R
# 53628                    Zack             R
# 53629                    Zack             R
# 53630                    Zack             R
# 53631                    Zack             R
# 53632                    Zack             R
# 53633                    Zack             R
# 53634                    Zack             R
# 53635                    Zack             R
# 53636                    Zack             R
# 53637                    Zack             R
# 53638                    Zack             R
# 53639                    Zack             R
# 53640                    Zack             R
# 53641                    Zack             R
# 53642                    Zack             R
# 53643                    Zack             R
# 53644                    Zack             R
#
#                                  pitcher_id  \
# 0      683ac24d-7777-478b-8417-d0eb3cb04e83
# 1      683ac24d-7777-478b-8417-d0eb3cb04e83
# 2      683ac24d-7777-478b-8417-d0eb3cb04e83
# 3      683ac24d-7777-478b-8417-d0eb3cb04e83
# 4      683ac24d-7777-478b-8417-d0eb3cb04e83
# 5      683ac24d-7777-478b-8417-d0eb3cb04e83
# 6      683ac24d-7777-478b-8417-d0eb3cb04e83
# 7      683ac24d-7777-478b-8417-d0eb3cb04e83
# 8      683ac24d-7777-478b-8417-d0eb3cb04e83
# 9      683ac24d-7777-478b-8417-d0eb3cb04e83
# 10     683ac24d-7777-478b-8417-d0eb3cb04e83
# 11     683ac24d-7777-478b-8417-d0eb3cb04e83
# 12     683ac24d-7777-478b-8417-d0eb3cb04e83
# 13     683ac24d-7777-478b-8417-d0eb3cb04e83
# 14     683ac24d-7777-478b-8417-d0eb3cb04e83
# 15     683ac24d-7777-478b-8417-d0eb3cb04e83
# 16     683ac24d-7777-478b-8417-d0eb3cb04e83
# 17     683ac24d-7777-478b-8417-d0eb3cb04e83
# 18     683ac24d-7777-478b-8417-d0eb3cb04e83
# 19     683ac24d-7777-478b-8417-d0eb3cb04e83
{'starting_base': 1, 'ending_base': 1, 'out': ...
# 28     {'starting_base': 1, 'ending_base': 1, 'out': ...
# 29     {'starting_base': 1, 'ending_base': 1, 'out': ...
# ...                                                  ...
# 53615                                                NaN
# 53616                                                NaN
# 53617                                                NaN
# 53618                                                NaN
# 53619                                                NaN
# 53620                                                NaN
# 53621                                                NaN
# 53622                                                NaN
# 53623                                                NaN
# 53624                                                NaN
# 53625                                                NaN
# 53626                                                NaN
# 53627                                                NaN
# 53628                                                NaN
# 53629                                                NaN
# 53630                                                NaN
# 53631                                                NaN
# 53632                                                NaN
# 53633                                                NaN
# 53634                                                NaN
# 53635                                                NaN
# 53636                                                NaN
# 53637                                                NaN
# 53638                                                NaN
# 53639                                                NaN
# 53640                                                NaN
# 53641                                                NaN
# 53642                                                NaN
# 53643                                                NaN
# 53644                                                NaN
#
#                                                 runner_2 runner_3 runner_4
# 0                                                    NaN      NaN      NaN
# 1                                                    NaN      NaN      NaN
# 2                                                    NaN      NaN      NaN
# 3                                                    NaN      NaN      NaN
# 4                                                    NaN      NaN      NaN
# 5                                                    NaN      NaN      NaN
# 6                                                    NaN      NaN      NaN
# 7                                                    NaN      NaN      NaN
# 8                                                    NaN      NaN      NaN
# 9                                                    NaN      NaN      NaN
# 10                                                   NaN      NaN      NaN
# 11                                                   NaN      NaN      NaN
# 12                                                   NaN      NaN      NaN
# 13                                                   NaN      NaN      NaN
# 14                                                   NaN      NaN      NaN
# 15     {'starting_base': 2, 'ending_base': 2, 'out': ...      NaN      NaN
# 16     {'starting_base': 2, 'ending_base': 2, 'out': ...      NaN      NaN
# 17     {'starting_base': 2, 'ending_base': 2, 'out': ...      NaN      NaN
# 18     {'starting_base': 2, 'ending_base': 2, 'out': ...      NaN      NaN
# 19     {'starting_base': 2, 'ending_base': 2, 'out': ...      NaN      NaN
# 20     {'starting_base': 2, 'ending_base': 2, 'out': ...      NaN      NaN
# 21     {'starting_base': 2, 'ending_base': 2, 'out': ...      NaN      NaN
# 22                                                   NaN      NaN      NaN
# 23                                                   NaN      NaN      NaN
# 24                                                   NaN      NaN      NaN
# 25                                                   NaN      NaN      NaN
# 26                                                   NaN      NaN      NaN
# 27                                                   NaN      NaN      NaN
# 28                                                   NaN      NaN      NaN
# 29                                                   NaN      NaN      NaN
# ...                                                  ...      ...      ...
# 53615                                                NaN      NaN      NaN
# 53616                                                NaN      NaN      NaN
# 53617                                                NaN      NaN      NaN
# 53618                                                NaN      NaN      NaN
# 53619                                                NaN      NaN      NaN
# 53620                                                NaN      NaN      NaN
# 53621                                                NaN      NaN      NaN
# 53622                                                NaN      NaN      NaN
# 53623                                                NaN      NaN      NaN
# 53624                                                NaN      NaN      NaN
# 53625                                                NaN      NaN      NaN
# 53626                                                NaN      NaN      NaN
# 53627                                                NaN      NaN      NaN
# 53628                                                NaN      NaN      NaN
# 53629                                                NaN      NaN      NaN
# 53630                                                NaN      NaN      NaN
# 53631                                                NaN      NaN      NaN
# 53632                                                NaN      NaN      NaN
# 53633                                                NaN      NaN      NaN
# 53634                                                NaN      NaN      NaN
# 53635                                                NaN      NaN      NaN
# 53636                                                NaN      NaN      NaN
# 53637                                                NaN      NaN      NaN
# 53638                                                NaN      NaN      NaN
# 53639                                                NaN      NaN      NaN
# 53640                                                NaN      NaN      NaN
# 53641                                                NaN      NaN      NaN
# 53642                                                NaN      NaN      NaN
# 53643                                                NaN      NaN      NaN
# 53644                                                NaN      NaN      NaN
#
# [53645 rows x 43 columns]

# %%
df_pitches = df.groupby(['pitcher.last_name', 'pitcher.first_name'])['pitcher.pitch_speed'].agg(['count','mean', 'std'])

# %%
#df_pitches['percent'] = round(df_pitches/df_pitches.sum()*100,2)

# %%
df.groupby(['count.pitch_count', 'pitcher.pitch_type'])['pitcher.pitch_type'].agg('count')
# Out:
# count.pitch_count  pitcher.pitch_type
# 0                  UN                       2
# 1                  CH                    1268
#                    CT                     468
#                    CU                    1481
#                    FA                    8424
#                    IB                      19
#                    KN                       1
#                    PI                       3
#                    SI                     820
#                    SL                    1976
#                    SP                       9
#                    UN                       5
# 2                  CH                    1744
#                    CT                     519
#                    CU                    1414
#                    FA                    6400
#                    IB                      20
#                    KN                       1
#                    PI                       1
#                    SI                     619
#                    SL                    2102
#                    SP                      13
#                    UN                       4
# 3                  CH                    1269
#                    CT                     375
#                    CU                    1221
#                    FA                    5198
#                    IB                      24
#                    PI                       1
#                    SI                     496
#                                          ...
# 7                  SI                      32
#                    SL                     284
# 8                  CH                      65
#                    CT                      12
#                    CU                      52
#                    FA                     211
#                    SI                      17
#                    SL                      92
# 9                  CH                      33
#                    CT                       7
#                    CU                      18
#                    FA                      88
#                    SI                       6
#                    SL                      30
# 10                 CH                      10
#                    CU                      10
#                    FA                      31
#                    SI                       2
#                    SL                      13
# 11                 CH                       3
#                    CT                       1
#                    CU                       2
#                    FA                      12
#                    SL                       2
# 12                 CH                       3
#                    CU                       1
#                    FA                       4
#                    SI                       1
# 13                 FA                       1
#                    SL                       1
# Name: pitcher.pitch_type, Length: 92, dtype: int64

# %%
df.head()
# Out:
#    count.balls  count.outs  count.pitch_count  count.strikes        date half  \
# 0            0           0                  1              1  2016-04-06    B
# 1            0           0                  2              2  2016-04-06    B
# 2            0           1                  3              2  2016-04-06    B
# 3            1           1                  1              0  2016-04-06    B
# 4            1           1                  2              0  2016-04-06    B
#
#    inning outcome_id pitcher.first_name pitcher.hitter_hand pitcher.last_name  \
# 0       1        kKL              Aaron                   R              Nola
# 1       1         kF              Aaron                   R              Nola
# 2       1        oGO              Aaron                   R              Nola
# 3       1         bB              Aaron                   R              Nola
# 4       1        aHR              Aaron                   R              Nola
#
#    pitcher.pitch_count  pitcher.pitch_speed pitcher.pitch_type  \
# 0                    1                 91.0                 FA
# 1                    2                 89.0                 FA
# 2                    3                 77.0                 CU
# 3                    4                 91.0                 FA
# 4                    5                 89.0                 FA
#
#    pitcher.pitch_zone pitcher.pitcher_hand  \
# 0                 6.0                    R
# 1                 7.0                    R
# 2                 7.0                    R
# 3                13.0                    R
# 4                 5.0                    R
#
#                              pitcher_id
# 0  ded1b30d-52ca-4eec-bce6-251b15b085ac
# 1  ded1b30d-52ca-4eec-bce6-251b15b085ac
# 2  ded1b30d-52ca-4eec-bce6-251b15b085ac
# 3  ded1b30d-52ca-4eec-bce6-251b15b085ac
# 4  ded1b30d-52ca-4eec-bce6-251b15b085ac

# %%
df_hitterCount = df[(df['count.balls']==3) & (df['count.strikes']==2)]

# %%
df_hitterCount.groupby('pitcher.pitch_type')['pitcher.pitch_speed'].agg(['count', 'mean'])
# Out:
#                     count       mean
# pitcher.pitch_type
# CH                    341  86.340176
# CT                     96  87.937500
# CU                    284  80.306338
# FA                   1730  93.612139
# SI                    138  93.557971
# SL                    635  86.867717
# UN                      1  85.000000
